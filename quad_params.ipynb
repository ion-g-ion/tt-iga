# %%
from webbrowser import get
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
        
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    # Dc = 32e-3
    # hc = 7e-3
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.sin((np.pi-np.abs(alpha2(params)+np.pi*3/4))/2)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc-blc)*(hi+params[...,3])+0.5*(bli+params[...,2])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()
print(surface(np.array([0.0,0.0,0.0,0.0])))

var1 = 0.00075
var2 = 0.00075
var3 = 0.00075
var4 = 0.00075
pts = control_points([0,0,0,0])
plt.figure()
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)
pts = control_points([0,-0.003,0,0])
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)


basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 8
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param)
# Out:
# 0.0002177263404511999

# %%
plt.figure()

for i in range(20):
    paramz = [tn.tensor([np.random.uniform()*2*var1-var1]),tn.tensor([np.random.uniform()*2*var2-var2]),tn.tensor([np.random.uniform()*2*var3-var3]),tn.tensor([np.random.uniform()*2*var4-var4])]
    line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

    # line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_params.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r')

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
plt.text(0.03*1e3,0.035*1e3,r'$\Gamma_D$')
plt.text(0.014*1e3,0.0008*1e3,r'$\Gamma_N$')
plt.text(0.045*1e3,0.025*1e3,r'iron')
plt.text(0.041*1e3,0.005*1e3,r'Cu')
plt.text(0.015*1e3,0.005*1e3,r'air')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_section.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

pts = control_points([0,0,0,0])

plt.scatter(pts[0,...]*1e3, pts[1,...]*1e3)

plt.plot(pts[0,:,1]*1e3, pts[1,:,1]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,2]*1e3, pts[1,:,2]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,3]*1e3, pts[1,:,3]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,1,:]*1e3, pts[1,1,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,2,:]*1e3, pts[1,2,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,3,:]*1e3, pts[1,3,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,4,:]*1e3, pts[1,4,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,5,:]*1e3, pts[1,5,:]*1e3,'gray',linewidth=0.5)

for i in range(5): 
    for j in range(7): 
        plt.text(pts[0,j,i]*1e3+1,pts[1,j,i]*1e3,'(%d,%d)'%(j+1,i+1), fontsize = 10)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
tikzplotlib.save('quad_points.tex')

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))

tme = datetime.datetime.now()
Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
tme = datetime.datetime.now() - tme
print('Time mass ', tme)
tme = datetime.datetime.now()
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-9, func_reference=mu_ref, qtt = True, verb = True)
tme = datetime.datetime.now() - tme
print('Time stiffness ', tme)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[0])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4) / Mass_tt.N[0]

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-11)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-11)

print('System matrix... ',flush=True)

print('Rank Stiff', Stiff_tt.R, ' storage [MB] ',tntt.numel(Stiff_tt)*8/1e6)
print('Rank Mass', Mass_tt.R, ' storage [MB] ',tntt.numel(Mass_tt)*8/1e6)
print('Rank Mtt ',M_tt.R, ' storage [MB] ',tntt.numel(M_tt)*8/1e6)
print('Rank rhstt ',rhs_tt.R, ' storage [MB] ',tntt.numel(rhs_tt)*8/1e6)
# Out:
# Time mass  0:00:01.772228
# time omega 0:00:01.575339
# rank omega, [1, 17, 20, 11, 4, 2, 1]
# QTT enabled:
# [240, 236, 8, 8, 8, 8]
#   ||
#   \/
# [2, 2, 2, 2, 3, 5, 2, 2, 59, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# rank of Ftt is  [1, 3, 1, 1, 1, 1, 1]
# alpha, beta =  0 0
# 	time 1  0:00:00.445047
# 	time 2  0:00:06.931027  rank  [1, 4, 16, 64, 176, 432, 249, 396, 618, 89, 190, 170, 78, 158, 146, 64, 64, 16, 7, 8, 2, 1]
# 		time  0:00:00.094889
# 	time 4  0:00:00.098798
# alpha, beta =  0 1
# 	time 1  0:00:00.432773
# 	time 2  0:00:07.621805  rank  [1, 4, 16, 64, 176, 432, 249, 396, 648, 91, 194, 174, 79, 158, 146, 64, 64, 16, 7, 8, 2, 1]
# 		time  0:00:00.104325
# 	time 4  0:00:00.173624
# 	time ROUND  0:00:00.594487
# alpha, beta =  1 0
# 	time 1  0:00:00.443709
# 	time 2  0:00:07.749075  rank  [1, 4, 16, 64, 176, 432, 249, 396, 648, 91, 194, 174, 79, 158, 146, 64, 64, 16, 7, 8, 2, 1]
# 		time  0:00:00.100241
# 	time 4  0:00:00.147990
# alpha, beta =  1 1
# 	time 1  0:00:00.485938
# 	time 2  0:00:05.605928  rank  [1, 4, 16, 64, 176, 432, 213, 344, 594, 78, 168, 150, 68, 142, 130, 61, 64, 16, 7, 8, 2, 1]
# 		time  0:00:00.082337
# 	time 4  0:00:00.185948
# 	time ROUND  0:00:00.716741
# Time stiffness  0:00:36.831154
# System matrix...
# Rank Stiff [1, 82, 67, 49, 22, 6, 1]  storage [MB]  185.017856
# Rank Mass [1, 18, 22, 11, 4, 2, 1]  storage [MB]  13.717504
# Rank Mtt  [1, 83, 67, 49, 22, 6, 1]  storage [MB]  187.24608
# Rank rhstt  [1, 3, 6, 6, 10, 4, 1]  storage [MB]  0.019712

# %%
tme = datetime.datetime.now() 
# dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp = 50, kickrank = 4, preconditioner = 'c', verbose = False).cpu()
# dofs_tt = tntt.reshape(tntt.solvers.amen_solve(tntt.reshape(M_tt,[(2,2)]*21).round(1e-12).cuda(), tntt.reshape(rhs_tt,[2]*21).round(1e-12).cuda(), x0 = tntt.reshape(tntt.ones(rhs_tt.N),[2]*21).cuda(), eps = 1e-6, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True),rhs_tt.N).round(1e-12)
# dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), rmax = 300, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 64)....
# 		dx = 399.428, res_now = 9.14384e-14, res_old = 0.999716
# 	Core 1
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00746501 (from 1.704e-08)
# 		Time needed  0:00:00.264035
# 		dx = 0.350942, res_now = 0.00746501, res_old = 11.9791
# 	Core 2
# 		Choosing direct solver (local size 72)....
# 		dx = 0.032076, res_now = 1.65473e-16, res_old = 0.591968
# 	Core 3
# 		Choosing direct solver (local size 72)....
# 		dx = 0.0204375, res_now = 4.0793e-16, res_old = 1.52148
# 	Core 4
# 		Choosing direct solver (local size 72)....
# 		dx = 0.00250164, res_now = 1.08963e-16, res_old = 0.294128
# 	Core 5
# 		Choosing direct solver (local size 72)....
# 		dx = 0.00240843, res_now = 2.0572e-16, res_old = 0.583522
# Solution rank is [1, 9, 9, 9, 9, 9, 1]
# Maxres  tensor(11.9791, device='cuda:0')
# Time  0:00:00.356659
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00131109 (from 3.4189e-08)
# 		Time needed  0:00:00.220066
# 		dx = 0.0634185, res_now = 0.00131109, res_old = 5.97046
# 	Core 1
# 		Choosing iterative solver GMRES (local size 9792)....
# 		Finished with flag 0 after 80 iterations with relres 0.00530361 (from 1.23116e-07)
# 		Time needed  0:00:01.667389
# 		dx = 0.0206706, res_now = 0.00530361, res_old = 1.65799
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1224)....
# 		Finished with flag 1 after 25 iterations with relres 1.8006e-07 (from 4.48582e-06)
# 		Time needed  0:00:00.066358
# 		dx = 0.000921021, res_now = 1.8006e-07, res_old = 0.0455043
# 	Core 3
# 		Choosing iterative solver GMRES (local size 1224)....
# 		Finished with flag 1 after 33 iterations with relres 1.65887e-07 (from 5.11889e-06)
# 		Time needed  0:00:00.078014
# 		dx = 0.000443379, res_now = 1.65887e-07, res_old = 0.0398767
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 1 after 37 iterations with relres 1.54711e-07 (from 1.74452e-05)
# 		Time needed  0:00:00.089759
# 		dx = 0.000120912, res_now = 1.54711e-07, res_old = 0.0117009
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.5905e-10, res_now = 2.68053e-16, res_old = 1.60129e-07
# Solution rank is [1, 17, 17, 17, 17, 16, 1]
# Maxres  tensor(5.9705, device='cuda:0')
# Time  0:00:02.294991
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 0 after 80 iterations with relres 0.000604415 (from 2.33215e-06)
# 		Time needed  0:00:00.219986
# 		dx = 0.00929678, res_now = 0.000604415, res_old = 0.0875263
# 	Core 1
# 		Choosing iterative solver GMRES (local size 27200)....
# 		Finished with flag 0 after 80 iterations with relres 0.00127898 (from 2.12947e-06)
# 		Time needed  0:00:03.701288
# 		dx = 0.0047893, res_now = 0.00127898, res_old = 0.0958569
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3400)....
# 		Finished with flag 1 after 80 iterations with relres 2.01368e-07 (from 0.00011935)
# 		Time needed  0:00:00.238073
# 		dx = 0.000227736, res_now = 2.01368e-07, res_old = 0.0017103
# 	Core 3
# 		Choosing iterative solver GMRES (local size 3400)....
# 		Finished with flag 1 after 60 iterations with relres 2.03947e-07 (from 0.000980163)
# 		Time needed  0:00:00.138033
# 		dx = 8.91614e-06, res_now = 2.03947e-07, res_old = 0.000208255
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 1 after 3 iterations with relres 1.93287e-07 (from 0.200514)
# 		Time needed  0:00:00.006158
# 		dx = 1.84793e-08, res_now = 1.93287e-07, res_old = 1.018e-06
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 6.91493e-08, res_now = 1.41938e-16, res_old = 2.01262e-07
# Solution rank is [1, 25, 25, 25, 25, 16, 1]
# Maxres  tensor(0.0959, device='cuda:0')
# Time  0:00:04.569629
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 0 after 80 iterations with relres 9.8259e-05 (from 1.67687e-05)
# 		Time needed  0:00:00.218657
# 		dx = 0.000647363, res_now = 9.8259e-05, res_old = 0.0121729
# 	Core 1
# 		Choosing iterative solver GMRES (local size 52800)....
# 		Finished with flag 0 after 80 iterations with relres 0.000358583 (from 1.34528e-05)
# 		Time needed  0:00:06.778416
# 		dx = 0.00144089, res_now = 0.000358583, res_old = 0.0151734
# 	Core 2
# 		Choosing iterative solver GMRES (local size 6600)....
# 		Finished with flag 0 after 80 iterations with relres 5.75975e-07 (from 0.000501335)
# 		Time needed  0:00:00.264398
# 		dx = 0.000203037, res_now = 5.75975e-07, res_old = 0.000407161
# 	Core 3
# 		Choosing iterative solver GMRES (local size 6600)....
# 		Finished with flag 1 after 30 iterations with relres 1.94065e-07 (from 0.0210724)
# 		Time needed  0:00:00.071322
# 		dx = 8.36823e-07, res_now = 1.94065e-07, res_old = 9.6868e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 1 after 1 iterations with relres 1.81699e-07 (from 0.836351)
# 		Time needed  0:00:00.004156
# 		dx = 8.06125e-09, res_now = 1.81699e-07, res_old = 2.44065e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 3.79041e-08, res_now = 1.57849e-16, res_old = 1.87162e-07
# Solution rank is [1, 33, 33, 33, 33, 16, 1]
# Maxres  tensor(0.0152, device='cuda:0')
# Time  0:00:07.721943
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 0 after 80 iterations with relres 3.95906e-05 (from 0.000133059)
# 		Time needed  0:00:00.221870
# 		dx = 0.000224656, res_now = 3.95906e-05, res_old = 0.00153408
# 	Core 1
# 		Choosing iterative solver GMRES (local size 86592)....
# 		Finished with flag 0 after 80 iterations with relres 0.00012379 (from 5.03139e-05)
# 		Time needed  0:00:11.407485
# 		dx = 0.000301469, res_now = 0.00012379, res_old = 0.00405701
# 	Core 2
# 		Choosing iterative solver GMRES (local size 10824)....
# 		Finished with flag 0 after 80 iterations with relres 1.13866e-06 (from 0.00149786)
# 		Time needed  0:00:00.302949
# 		dx = 0.000102005, res_now = 1.13866e-06, res_old = 0.000136278
# 	Core 3
# 		Choosing iterative solver GMRES (local size 10824)....
# 		Finished with flag 1 after 49 iterations with relres 1.99385e-07 (from 0.046601)
# 		Time needed  0:00:00.129828
# 		dx = 2.32754e-06, res_now = 1.99385e-07, res_old = 4.38025e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 1 after 5 iterations with relres 1.99688e-07 (from 0.759422)
# 		Time needed  0:00:00.008597
# 		dx = 8.45778e-08, res_now = 1.99688e-07, res_old = 2.68789e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 7.47375e-08, res_now = 9.81805e-17, res_old = 2.07952e-07
# Solution rank is [1, 41, 41, 41, 41, 16, 1]
# Maxres  tensor(0.0041, device='cuda:0')
# Time  0:00:12.622212
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 0 after 80 iterations with relres 1.13215e-05 (from 0.000526513)
# 		Time needed  0:00:00.222100
# 		dx = 0.000131606, res_now = 1.13215e-05, res_old = 0.00038769
# 	Core 1
# 		Choosing iterative solver GMRES (local size 128576)....
# 		Finished with flag 0 after 80 iterations with relres 5.88774e-05 (from 0.000174692)
# 		Time needed  0:00:16.922422
# 		dx = 0.000116675, res_now = 5.88774e-05, res_old = 0.00116848
# 	Core 2
# 		Choosing iterative solver GMRES (local size 16072)....
# 		Finished with flag 0 after 80 iterations with relres 7.11385e-07 (from 0.00324369)
# 		Time needed  0:00:00.356646
# 		dx = 4.91455e-05, res_now = 7.11385e-07, res_old = 6.29296e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 16072)....
# 		Finished with flag 1 after 32 iterations with relres 1.99088e-07 (from 0.209719)
# 		Time needed  0:00:00.093279
# 		dx = 9.49271e-07, res_now = 1.99088e-07, res_old = 9.73324e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 1 after 0 iterations with relres 1.97673e-07 (from 1.00185)
# 		Time needed  0:00:00.003431
# 		dx = 3.12985e-09, res_now = 1.97673e-07, res_old = 2.03747e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 9.65989e-08, res_now = 1.84828e-16, res_old = 2.09357e-07
# Solution rank is [1, 49, 49, 49, 49, 16, 1]
# Maxres  tensor(0.0012, device='cuda:0')
# Time  0:00:18.353889
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 0 after 80 iterations with relres 4.34461e-06 (from 0.00128804)
# 		Time needed  0:00:00.223727
# 		dx = 4.48402e-05, res_now = 4.34461e-06, res_old = 0.000158476
# 	Core 1
# 		Choosing iterative solver GMRES (local size 178752)....
# 		Finished with flag 0 after 80 iterations with relres 3.17127e-05 (from 0.000516656)
# 		Time needed  0:00:22.912352
# 		dx = 4.62142e-05, res_now = 3.17127e-05, res_old = 0.000395087
# 	Core 2
# 		Choosing iterative solver GMRES (local size 22344)....
# 		Finished with flag 0 after 80 iterations with relres 6.17603e-07 (from 0.00614641)
# 		Time needed  0:00:00.433128
# 		dx = 1.7209e-05, res_now = 6.17603e-07, res_old = 3.32103e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 22344)....
# 		Finished with flag 1 after 52 iterations with relres 2.01854e-07 (from 0.312916)
# 		Time needed  0:00:00.161891
# 		dx = 2.17399e-06, res_now = 2.01854e-07, res_old = 6.52329e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 1 after 3 iterations with relres 2.03833e-07 (from 0.973041)
# 		Time needed  0:00:00.006275
# 		dx = 2.48958e-08, res_now = 2.03833e-07, res_old = 2.0978e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.15936e-07, res_now = 1.70111e-16, res_old = 2.12742e-07
# Solution rank is [1, 57, 57, 57, 57, 16, 1]
# Maxres  tensor(0.0004, device='cuda:0')
# Time  0:00:24.733673
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 0 after 80 iterations with relres 1.91757e-06 (from 0.00212305)
# 		Time needed  0:00:00.219346
# 		dx = 1.87341e-05, res_now = 1.91757e-06, res_old = 9.61465e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 233472)....
# 		Finished with flag 0 after 80 iterations with relres 1.9765e-05 (from 0.000805276)
# 		Time needed  0:00:30.316357
# 		dx = 2.13792e-05, res_now = 1.9765e-05, res_old = 0.000253484
# 	Core 2
# 		Choosing iterative solver GMRES (local size 29640)....
# 		Finished with flag 0 after 80 iterations with relres 5.56173e-07 (from 0.00993161)
# 		Time needed  0:00:00.514525
# 		dx = 8.55141e-06, res_now = 5.56173e-07, res_old = 2.0553e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 29640)....
# 		Finished with flag 1 after 62 iterations with relres 2.02519e-07 (from 0.355074)
# 		Time needed  0:00:00.225607
# 		dx = 2.19271e-06, res_now = 2.02519e-07, res_old = 5.74878e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4160)....
# 		Finished with flag 1 after 5 iterations with relres 2.00705e-07 (from 0.966019)
# 		Time needed  0:00:00.008892
# 		dx = 4.55975e-08, res_now = 2.00705e-07, res_old = 2.11304e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.11799e-07, res_now = 1.33259e-16, res_old = 2.11448e-07
# Solution rank is [1, 64, 65, 65, 65, 16, 1]
# Maxres  tensor(0.0003, device='cuda:0')
# Time  0:00:32.547586
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 1.21866e-06 (from 0.00281904)
# 		Time needed  0:00:00.220412
# 		dx = 1.1135e-05, res_now = 1.21866e-06, res_old = 7.24092e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 266240)....
# 		Finished with flag 0 after 80 iterations with relres 1.27807e-05 (from 0.00158822)
# 		Time needed  0:00:34.664814
# 		dx = 1.3671e-05, res_now = 1.27807e-05, res_old = 0.000128524
# 	Core 2
# 		Choosing iterative solver GMRES (local size 37960)....
# 		Finished with flag 0 after 80 iterations with relres 6.02749e-07 (from 0.0155044)
# 		Time needed  0:00:00.754529
# 		dx = 6.36459e-06, res_now = 6.02749e-07, res_old = 1.31655e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 37376)....
# 		Finished with flag 1 after 61 iterations with relres 2.01562e-07 (from 0.329058)
# 		Time needed  0:00:00.259573
# 		dx = 1.25436e-06, res_now = 2.01562e-07, res_old = 6.2033e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 2 iterations with relres 1.9842e-07 (from 0.975815)
# 		Time needed  0:00:00.006024
# 		dx = 1.01869e-08, res_now = 1.9842e-07, res_old = 2.09183e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.52207e-07, res_now = 1.94291e-16, res_old = 2.09813e-07
# Solution rank is [1, 64, 73, 73, 72, 16, 1]
# Maxres  tensor(0.0001, device='cuda:0')
# Time  0:00:37.385347
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 6.31263e-07 (from 0.00378384)
# 		Time needed  0:00:00.221035
# 		dx = 6.39136e-06, res_now = 6.31263e-07, res_old = 5.39463e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 299008)....
# 		Finished with flag 0 after 80 iterations with relres 8.58893e-06 (from 0.00239308)
# 		Time needed  0:00:38.856176
# 		dx = 7.21069e-06, res_now = 8.58893e-06, res_old = 8.52976e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 47304)....
# 		Finished with flag 0 after 80 iterations with relres 5.02925e-07 (from 0.0229366)
# 		Time needed  0:00:00.883039
# 		dx = 3.5897e-06, res_now = 5.02925e-07, res_old = 8.8995e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 41472)....
# 		Finished with flag 1 after 51 iterations with relres 2.04001e-07 (from 0.368499)
# 		Time needed  0:00:00.232318
# 		dx = 7.19989e-07, res_now = 2.04001e-07, res_old = 5.53934e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 2 iterations with relres 2.03575e-07 (from 0.962906)
# 		Time needed  0:00:00.005540
# 		dx = 5.7112e-09, res_now = 2.03575e-07, res_old = 2.11988e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.23307e-07, res_now = 2.06876e-16, res_old = 2.1506e-07
# Solution rank is [1, 64, 81, 81, 72, 16, 1]
# Maxres  tensor(8.5298e-05, device='cuda:0')
# Time  0:00:41.831537
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 3.15296e-07 (from 0.00490895)
# 		Time needed  0:00:00.220811
# 		dx = 2.91268e-06, res_now = 3.15296e-07, res_old = 4.15821e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 331776)....
# 		Finished with flag 0 after 80 iterations with relres 5.8204e-06 (from 0.00356997)
# 		Time needed  0:00:43.045336
# 		dx = 4.40679e-06, res_now = 5.8204e-06, res_old = 5.71782e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 57672)....
# 		Finished with flag 0 after 80 iterations with relres 4.93866e-07 (from 0.0326367)
# 		Time needed  0:00:01.083543
# 		dx = 2.02098e-06, res_now = 4.93866e-07, res_old = 6.25443e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 45568)....
# 		Finished with flag 1 after 64 iterations with relres 2.03391e-07 (from 0.381816)
# 		Time needed  0:00:00.300734
# 		dx = 5.73778e-07, res_now = 2.03391e-07, res_old = 5.34613e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 2 iterations with relres 2.02397e-07 (from 0.967989)
# 		Time needed  0:00:00.006110
# 		dx = 3.80406e-09, res_now = 2.02397e-07, res_old = 2.10874e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.21339e-07, res_now = 1.82948e-16, res_old = 2.12748e-07
# Solution rank is [1, 64, 89, 89, 72, 16, 1]
# Maxres  tensor(5.7178e-05, device='cuda:0')
# Time  0:00:46.444838
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.3061e-07 (from 0.00673444)
# 		Time needed  0:00:00.220027
# 		dx = 1.38853e-06, res_now = 2.3061e-07, res_old = 3.03105e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 364544)....
# 		Finished with flag 0 after 80 iterations with relres 4.00894e-06 (from 0.00512732)
# 		Time needed  0:00:47.217815
# 		dx = 2.27962e-06, res_now = 4.00894e-06, res_old = 3.98111e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 69064)....
# 		Finished with flag 0 after 80 iterations with relres 4.35196e-07 (from 0.0460238)
# 		Time needed  0:00:01.162929
# 		dx = 1.14497e-06, res_now = 4.35196e-07, res_old = 4.43519e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 49664)....
# 		Finished with flag 1 after 78 iterations with relres 2.03262e-07 (from 0.447894)
# 		Time needed  0:00:00.412806
# 		dx = 7.50282e-07, res_now = 2.03262e-07, res_old = 4.55742e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 2 iterations with relres 1.9786e-07 (from 0.965309)
# 		Time needed  0:00:00.005749
# 		dx = 5.2044e-09, res_now = 1.9786e-07, res_old = 2.1146e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 5.17702e-08, res_now = 1.4275e-16, res_old = 2.08927e-07
# Solution rank is [1, 64, 97, 97, 72, 16, 1]
# Maxres  tensor(3.9811e-05, device='cuda:0')
# Time  0:00:50.951054
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 70 iterations with relres 2.04009e-07 (from 0.00996799)
# 		Time needed  0:00:00.180959
# 		dx = 9.58064e-07, res_now = 2.04009e-07, res_old = 2.0478e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 397312)....
# 		Finished with flag 0 after 80 iterations with relres 2.48331e-06 (from 0.00832253)
# 		Time needed  0:00:51.705371
# 		dx = 1.71955e-06, res_now = 2.48331e-06, res_old = 2.45267e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 81480)....
# 		Finished with flag 0 after 80 iterations with relres 3.66918e-07 (from 0.0517463)
# 		Time needed  0:00:01.446776
# 		dx = 8.7359e-07, res_now = 3.66918e-07, res_old = 3.94471e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 53760)....
# 		Finished with flag 1 after 39 iterations with relres 2.03115e-07 (from 0.544719)
# 		Time needed  0:00:00.224778
# 		dx = 1.64649e-07, res_now = 2.03115e-07, res_old = 3.74733e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 1 iterations with relres 2.03049e-07 (from 0.959403)
# 		Time needed  0:00:00.004396
# 		dx = 1.4458e-09, res_now = 2.03049e-07, res_old = 2.12762e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.83781e-08, res_now = 1.99832e-16, res_old = 2.14226e-07
# Solution rank is [1, 64, 105, 105, 72, 16, 1]
# Maxres  tensor(2.4527e-05, device='cuda:0')
# Time  0:00:55.662822
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 62 iterations with relres 2.00881e-07 (from 0.0144973)
# 		Time needed  0:00:00.156946
# 		dx = 5.15435e-07, res_now = 2.00881e-07, res_old = 1.40802e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 430080)....
# 		Finished with flag 0 after 80 iterations with relres 1.19597e-06 (from 0.0126868)
# 		Time needed  0:00:55.914703
# 		dx = 9.74163e-07, res_now = 1.19597e-06, res_old = 1.60895e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 94920)....
# 		Finished with flag 0 after 80 iterations with relres 2.77116e-07 (from 0.105266)
# 		Time needed  0:00:01.700106
# 		dx = 6.24767e-07, res_now = 2.77116e-07, res_old = 1.93912e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 57856)....
# 		Finished with flag 1 after 13 iterations with relres 2.03267e-07 (from 0.721159)
# 		Time needed  0:00:00.092010
# 		dx = 1.43183e-08, res_now = 2.03267e-07, res_old = 2.8305e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 2.03847e-07 (from 0.956257)
# 		Time needed  0:00:00.003461
# 		dx = 6.14653e-10, res_now = 2.03847e-07, res_old = 2.13462e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 5.85721e-08, res_now = 1.40805e-16, res_old = 2.14549e-07
# Solution rank is [1, 64, 113, 113, 72, 16, 1]
# Maxres  tensor(1.6089e-05, device='cuda:0')
# Time  0:01:00.122885
#
# Starting sweep 14 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 29 iterations with relres 2.03508e-07 (from 0.0272508)
# 		Time needed  0:00:00.077053
# 		dx = 3.05676e-07, res_now = 2.03508e-07, res_old = 7.49057e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 462848)....
# 		Finished with flag 0 after 80 iterations with relres 8.33006e-07 (from 0.021353)
# 		Time needed  0:01:00.124003
# 		dx = 7.95714e-07, res_now = 8.33006e-07, res_old = 9.55949e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 109384)....
# 		Finished with flag 1 after 71 iterations with relres 2.03108e-07 (from 0.226378)
# 		Time needed  0:00:01.758397
# 		dx = 2.86287e-07, res_now = 2.03108e-07, res_old = 9.01695e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 61952)....
# 		Finished with flag 1 after 0 iterations with relres 2.01329e-07 (from 0.991107)
# 		Time needed  0:00:00.029435
# 		dx = 1.33845e-10, res_now = 2.01329e-07, res_old = 2.05956e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 2.00724e-07 (from 0.958307)
# 		Time needed  0:00:00.003478
# 		dx = 5.55455e-10, res_now = 2.00724e-07, res_old = 2.13005e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 2.25797e-08, res_now = 1.7445e-16, res_old = 2.12526e-07
# Solution rank is [1, 64, 121, 121, 72, 16, 1]
# Maxres  tensor(9.5595e-06, device='cuda:0')
# Time  0:01:04.406166
#
# Starting sweep 15 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 18 iterations with relres 1.96507e-07 (from 0.0618189)
# 		Time needed  0:00:00.046964
# 		dx = 1.60974e-07, res_now = 1.96507e-07, res_old = 3.30197e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 495616)....
# 		Finished with flag 0 after 80 iterations with relres 6.58557e-07 (from 0.0345324)
# 		Time needed  0:01:04.336653
# 		dx = 4.00813e-07, res_now = 6.58557e-07, res_old = 5.9111e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 124872)....
# 		Finished with flag 1 after 53 iterations with relres 2.03856e-07 (from 0.297855)
# 		Time needed  0:00:01.541605
# 		dx = 1.21706e-07, res_now = 2.03856e-07, res_old = 6.85313e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 66048)....
# 		Finished with flag 1 after 0 iterations with relres 2.01873e-07 (from 0.987946)
# 		Time needed  0:00:00.031795
# 		dx = 1.06722e-10, res_now = 2.01873e-07, res_old = 2.06615e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 2.02267e-07 (from 0.951742)
# 		Time needed  0:00:00.003516
# 		dx = 6.10628e-10, res_now = 2.02267e-07, res_old = 2.14474e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.93741e-08, res_now = 1.726e-16, res_old = 2.13816e-07
# Solution rank is [1, 64, 129, 129, 72, 16, 1]
# Maxres  tensor(5.9111e-06, device='cuda:0')
# Time  0:01:08.537595
#
# Starting sweep 16 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 14 iterations with relres 1.87894e-07 (from 0.0861204)
# 		Time needed  0:00:00.038065
# 		dx = 1.27067e-07, res_now = 1.87894e-07, res_old = 2.37022e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 528384)....
# 		Finished with flag 0 after 80 iterations with relres 4.68006e-07 (from 0.0538457)
# 		Time needed  0:01:09.349341
# 		dx = 6.37178e-07, res_now = 4.68006e-07, res_old = 3.79091e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 141384)....
# 		Finished with flag 1 after 29 iterations with relres 2.03574e-07 (from 0.414293)
# 		Time needed  0:00:01.018049
# 		dx = 6.52436e-08, res_now = 2.03574e-07, res_old = 4.92705e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 70144)....
# 		Finished with flag 1 after 0 iterations with relres 2.00288e-07 (from 0.991262)
# 		Time needed  0:00:00.034825
# 		dx = 1.21416e-10, res_now = 2.00288e-07, res_old = 2.05924e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.79885e-07 (from 0.958694)
# 		Time needed  0:00:00.003495
# 		dx = 1.11997e-09, res_now = 1.79885e-07, res_old = 2.12919e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 8.70824e-09, res_now = 1.45859e-16, res_old = 1.90561e-07
# Solution rank is [1, 64, 137, 137, 72, 16, 1]
# Maxres  tensor(3.7909e-06, device='cuda:0')
# Time  0:01:13.215754
#
# Starting sweep 17 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 8 iterations with relres 2.0183e-07 (from 0.141327)
# 		Time needed  0:00:00.026849
# 		dx = 7.28303e-08, res_now = 2.0183e-07, res_old = 1.44434e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 561152)....
# 		Finished with flag 0 after 80 iterations with relres 3.26439e-07 (from 0.0818742)
# 		Time needed  0:01:13.572306
# 		dx = 4.73632e-07, res_now = 3.26439e-07, res_old = 2.49314e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 158920)....
# 		Finished with flag 1 after 5 iterations with relres 2.01982e-07 (from 0.519267)
# 		Time needed  0:00:00.348882
# 		dx = 3.1297e-09, res_now = 2.01982e-07, res_old = 3.93101e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 74240)....
# 		Finished with flag 1 after 0 iterations with relres 1.96698e-07 (from 1.00545)
# 		Time needed  0:00:00.036389
# 		dx = 9.52985e-11, res_now = 1.96698e-07, res_old = 2.03018e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.77173e-07 (from 0.975944)
# 		Time needed  0:00:00.003451
# 		dx = 9.48472e-10, res_now = 1.77173e-07, res_old = 2.09156e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 8.37131e-09, res_now = 1.45096e-16, res_old = 1.87862e-07
# Solution rank is [1, 64, 145, 145, 72, 16, 1]
# Maxres  tensor(2.4931e-06, device='cuda:0')
# Time  0:01:16.920201
#
# Starting sweep 18 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 3 iterations with relres 1.92096e-07 (from 0.391583)
# 		Time needed  0:00:00.020624
# 		dx = 3.1106e-08, res_now = 1.92096e-07, res_old = 5.2128e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 593920)....
# 		Finished with flag 0 after 80 iterations with relres 2.57447e-07 (from 0.164825)
# 		Time needed  0:01:17.862273
# 		dx = 2.01872e-07, res_now = 2.57447e-07, res_old = 1.23843e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 177480)....
# 		Finished with flag 1 after 4 iterations with relres 2.02714e-07 (from 0.739319)
# 		Time needed  0:00:00.354194
# 		dx = 1.84283e-09, res_now = 2.02714e-07, res_old = 2.76097e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 78336)....
# 		Finished with flag 1 after 0 iterations with relres 1.9659e-07 (from 1.00382)
# 		Time needed  0:00:00.037775
# 		dx = 1.12054e-10, res_now = 1.9659e-07, res_old = 2.03346e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.64832e-07 (from 0.978128)
# 		Time needed  0:00:00.003612
# 		dx = 9.44318e-10, res_now = 1.64832e-07, res_old = 2.08689e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 5.98847e-09, res_now = 1.30468e-16, res_old = 1.749e-07
# Solution rank is [1, 64, 153, 153, 72, 16, 1]
# Maxres  tensor(1.2384e-06, device='cuda:0')
# Time  0:01:21.379552
#
# Starting sweep 19 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 1 iterations with relres 1.92162e-07 (from 0.571416)
# 		Time needed  0:00:00.018615
# 		dx = 1.86942e-08, res_now = 1.92162e-07, res_old = 3.57225e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 626688)....
# 		Finished with flag 0 after 80 iterations with relres 2.04465e-07 (from 0.208837)
# 		Time needed  0:01:22.125178
# 		dx = 2.25245e-07, res_now = 2.04465e-07, res_old = 9.77434e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 197064)....
# 		Finished with flag 1 after 0 iterations with relres 2.00128e-07 (from 0.963543)
# 		Time needed  0:00:00.228427
# 		dx = 1.15586e-10, res_now = 2.00128e-07, res_old = 2.11847e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 82432)....
# 		Finished with flag 1 after 0 iterations with relres 1.86308e-07 (from 1.00926)
# 		Time needed  0:00:00.041570
# 		dx = 1.75231e-10, res_now = 1.86308e-07, res_old = 2.02251e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.46498e-07 (from 1.03453)
# 		Time needed  0:00:00.004313
# 		dx = 6.4796e-10, res_now = 1.46498e-07, res_old = 1.9731e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 2.71985e-09, res_now = 2.31913e-16, res_old = 1.55958e-07
# Solution rank is [1, 64, 161, 161, 72, 16, 1]
# Maxres  tensor(9.7743e-07, device='cuda:0')
# Time  0:01:25.689622
#
# Starting sweep 20 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.47174e-07 (from 0.949095)
# 		Time needed  0:00:00.004554
# 		dx = 7.3807e-09, res_now = 1.47174e-07, res_old = 2.15072e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 659456)....
# 		Finished with flag 1 after 4 iterations with relres 2.00276e-07 (from 0.276267)
# 		Time needed  0:00:08.941411
# 		dx = 2.65354e-09, res_now = 2.00276e-07, res_old = 7.38864e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 207368)....
# 		Finished with flag 1 after 0 iterations with relres 1.44217e-07 (from 1.3703)
# 		Time needed  0:00:00.228292
# 		dx = 8.5975e-11, res_now = 1.44217e-07, res_old = 1.48963e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 82432)....
# 		Finished with flag 1 after 0 iterations with relres 1.06285e-07 (from 1.85463)
# 		Time needed  0:00:00.041845
# 		dx = 9.83522e-11, res_now = 1.06285e-07, res_old = 1.10062e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 4.4555e-08 (from 4.44882)
# 		Time needed  0:00:00.003589
# 		dx = 1.94739e-10, res_now = 4.4555e-08, res_old = 4.58827e-08
# 	Core 5
# 		Choosing direct solver (local size 64)....
# 		dx = 1.51302e-09, res_now = 1.19029e-16, res_old = 4.98252e-09
# Solution rank is [1, 64, 161, 161, 64, 8, 1]
# Maxres  tensor(7.3886e-07, device='cuda:0')
# Time  0:00:12.453637
#
# Finished after 20  sweeps and  0:14:18.223831
#
# Time system solve  0:14:21.770249

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt

plt.figure()
y1, y2 = basis_solution[0].collocation_points(3)[0], basis_solution[1].collocation_points(3)[0]
w1, w2 = basis_solution[0].collocation_points(3)[1], basis_solution[1].collocation_points(3)[1]
ws = np.einsum('i,j->ij',w1,w2)
X1,X2 = geom([y1,y2]+[tn.tensor([0.0])]*4)
u = fspace([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
plt.contourf(X1.numpy().squeeze(), X2.numpy().squeeze(),u.numpy().squeeze(),levels=32)
plt.colorbar()



    
u = fspace([tn.tensor([0.05]),tn.tensor([0.0]), tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10), tn.linspace(-0.001,0.001,10)])

def get_in_reference(x, param1):
    return 0.4*x/(3.27640e-2+param1)
    # return 0.1*x/(geom([tn.tensor([0.1]),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([param1]), tn.tensor([0.0])])[0].numpy().squeeze())

# %%
y1, y2 = np.linspace(0,1,32), np.linspace(0.,1,32)

grad1, grad2 = geom.gradient_physical(basis_solution, fspace)

g2 = -grad1([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
g1 = grad2([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
x1,x2 = geom([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)

plt.figure()
plt.quiver(x1.numpy().flatten(),x2.numpy().flatten(),g1.numpy().flatten(),g2.numpy().flatten(),np.sqrt(g1.numpy().flatten()**2+g2.numpy().flatten()**2))
plt.colorbar()

# %%
import pickle

results = []

Nr = 32
omega_fspace = tt_iga.Function(basis_param)
for i in range(Nr):
    params = np.random.uniform([-var1,-var2,-var3,-var4],[var1,var2,var3,var4])
    if i==0: params = params*0
    
    y1 = basis_solution[0].collocation_points(2)[0]
    y2 = basis_solution[1].collocation_points(2)[0]
    omega = geom.eval_omega([tn.tensor(y1),tn.tensor(y2)]).mprod([tn.tensor(basis_param[k](tn.tensor([params[k]])).T) for k in range(4)],[2,3,4,5]).numpy().squeeze()

    w = np.outer(basis_solution[0].collocation_points(2)[1], basis_solution[1].collocation_points(2)[1])*omega 
    
    
    x1, x2 = geom([tn.tensor(y1),tn.tensor(y2)] + [ tn.tensor([p]) for p in params])

    x1 = x1.numpy().squeeze()
    x2 = x2.numpy().squeeze()

    A = fspace([tn.tensor(y1),tn.tensor(y2)] + [ tn.tensor([p]) for p in params]).numpy().squeeze()
    B2 = -grad1([tn.tensor(y1),tn.tensor(y2)] + [ tn.tensor([p]) for p in params]).numpy().squeeze()
    B1 =  grad2([tn.tensor(y1),tn.tensor(y2)] + [ tn.tensor([p]) for p in params]).numpy().squeeze()

    results.append({'thetas' : params.copy(), 'x1' : x1.copy(), 'x2' : x2.copy(), 'B1' : B1.copy(), 'B2' : B2.copy(), 'A' : A.copy(), 'w' : w.copy(), 'J0' : 24*45/surface(params)})

with open('quad_parameters3.pkl','wb') as f:
    pickle.dump(results, f)

# %%
print(geom([tn.tensor([0.4]),tn.tensor([0.0]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.4]),tn.tensor([0.0]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
print(geom([tn.tensor([0.4]),tn.tensor([0.3]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.4]),tn.tensor([0.3]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
print(geom([tn.tensor([0.4]),tn.tensor([0.5]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.4]),tn.tensor([0.5]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.5]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.5]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.3]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.3]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.0]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[0].numpy().squeeze())
print(geom([tn.tensor([0.6]),tn.tensor([0.0]), tn.tensor([results[1]['thetas'][0]]), tn.tensor([results[1]['thetas'][1]]),tn.tensor([results[1]['thetas'][2]]),tn.tensor([results[1]['thetas'][3]])])[1].numpy().squeeze())
# Out:
# 0.033184682970958376
# -1.3042798661526593e-17
# 0.033184682970958425
# 0.007551760000000118
# 0.03821223999999978
# 0.012396933114866355
# 0.04799999999999968
# 0.012396933114866312
# 0.05085988816558854
# 0.010000000000000106
# 0.05085988816558859
# -4.326585970077741e-18
