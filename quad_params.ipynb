# %%
from webbrowser import get
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
    
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    # Dc = 3.27640e-2                                                           
    Dc = 32e-3
    hc = 7e-3
    # hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),             ((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+params[2]-bli+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.abs(alpha2(params)+np.pi*3/4)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc+blc)*(hi+params[...,3])+0.5*(bli+params[...,3])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()
print(surface(np.array([0.0,0.0,0.0,0.0])))

var1 = 0.00075
var2 = 0.00075
var3 = 0.00075
var4 = 0.00075
pts = control_points([0,0,0,0])
plt.figure()
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)
pts = control_points([0,-0.003,0,0])
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)


basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 8
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param)
# Out:
# 0.00038049999999999987
# /home/yonnss/anaconda3/envs/pytorch2/lib/python3.9/site-packages/torch/functional.py:1660: UserWarning: torch.lu is deprecated in favor of torch.linalg.lu_factor / torch.linalg.lu_factor_ex and will be removed in a future PyTorch release.
# LU, pivots = torch.lu(A, compute_pivots)
# should be replaced with
# LU, pivots = torch.linalg.lu_factor(A, compute_pivots)
# and
# LU, pivots, info = torch.lu(A, compute_pivots, get_infos=True)
# should be replaced with
# LU, pivots, info = torch.linalg.lu_factor_ex(A, compute_pivots) (Triggered internally at /opt/conda/conda-bld/pytorch_1661584324933/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1906.)
#   return torch._lu_with_info(A, pivot=pivot, check_errors=(not get_infos))

# %%
plt.figure()

for i in range(20):
    paramz = [tn.tensor([np.random.uniform()*2*var1-var1]),tn.tensor([np.random.uniform()*2*var2-var2]),tn.tensor([np.random.uniform()*2*var3-var3]),tn.tensor([np.random.uniform()*2*var4-var4])]
    line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

    # line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_params.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r')

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
plt.text(0.03*1e3,0.035*1e3,r'$\Gamma_D$')
plt.text(0.014*1e3,0.0008*1e3,r'$\Gamma_N$')
plt.text(0.045*1e3,0.025*1e3,r'iron')
plt.text(0.041*1e3,0.005*1e3,r'Cu')
plt.text(0.015*1e3,0.005*1e3,r'air')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_section.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

pts = control_points([0,0,0,0])

plt.scatter(pts[0,...]*1e3, pts[1,...]*1e3)

plt.plot(pts[0,:,1]*1e3, pts[1,:,1]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,2]*1e3, pts[1,:,2]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,3]*1e3, pts[1,:,3]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,1,:]*1e3, pts[1,1,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,2,:]*1e3, pts[1,2,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,3,:]*1e3, pts[1,3,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,4,:]*1e3, pts[1,4,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,5,:]*1e3, pts[1,5,:]*1e3,'gray',linewidth=0.5)

for i in range(5): 
    for j in range(7): 
        plt.text(pts[0,j,i]*1e3+1,pts[1,j,i]*1e3,'(%d,%d)'%(j+1,i+1), fontsize = 10)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
tikzplotlib.save('quad_points.tex')

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))


Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-8, func_reference=mu_ref, qtt = True, verb = True)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[0])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4)

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-10)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-10)

print('System matrix... ',flush=True)


print('Rank Mtt ',M_tt.R)
print('Rank rhstt ',rhs_tt.R)


tme = datetime.datetime.now() 
# dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp = 50, kickrank = 4, preconditioner = 'c', verbose = False).cpu()
# dofs_tt = tntt.reshape(tntt.solvers.amen_solve(tntt.reshape(M_tt,[(2,2)]*21).round(1e-12).cuda(), tntt.reshape(rhs_tt,[2]*21).round(1e-12).cuda(), x0 = tntt.reshape(tntt.ones(rhs_tt.N),[2]*21).cuda(), eps = 1e-6, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True),rhs_tt.N).round(1e-12)
# dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), rmax = 200, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# time omega 0:00:05.297272
# QTT enabled:
# [240, 236, 8, 8, 8, 8]
#   ||
#   \/
# [2, 2, 2, 2, 3, 5, 2, 2, 59, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# rank of Ftt is  [1, 3, 1, 1, 1, 1, 1]
# alpha, beta =  0 0
# 	time 1  0:00:01.866180
# 	time 2  0:00:12.117157  rank  [1, 4, 16, 56, 144, 384, 201, 340, 552, 78, 168, 152, 70, 128, 114, 53, 64, 32, 6, 8, 4, 1]
# 		time  0:00:00.366067
# 	time 4  0:00:00.053577
# alpha, beta =  0 1
# 	time 1  0:00:02.063555
# 	time 2  0:00:14.390237  rank  [1, 4, 16, 56, 144, 384, 201, 336, 576, 82, 170, 154, 70, 128, 114, 53, 64, 32, 7, 8, 4, 1]
# 		time  0:00:00.364950
# 	time 4  0:00:00.158723
# 	time ROUND  0:00:01.600041
# alpha, beta =  1 0
# 	time 1  0:00:01.853464
# 	time 2  0:00:14.282484  rank  [1, 4, 16, 56, 144, 384, 201, 336, 576, 82, 170, 154, 70, 128, 114, 53, 64, 32, 7, 8, 4, 1]
# 		time  0:00:00.404052
# 	time 4  0:00:00.154695
# alpha, beta =  1 1
# 	time 1  0:00:02.142029
# 	time 2  0:00:09.469111  rank  [1, 4, 16, 56, 144, 384, 165, 280, 516, 68, 146, 134, 62, 112, 98, 45, 64, 32, 7, 8, 4, 1]
# 		time  0:00:00.218306
# 	time 4  0:00:00.221202
# 	time ROUND  0:00:01.955499
# System matrix...
# Rank Mtt  [1, 76, 59, 41, 19, 6, 1]
# Rank rhstt  [1, 3, 6, 6, 8, 4, 1]
#
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 64)....
# 		dx = 682.592, res_now = 1.03903e-13, res_old = 1.16579
# 	Core 1
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00905718 (from 1.69104e-08)
# 		Time needed  0:00:00.396751
# 		dx = 0.350991, res_now = 0.00905718, res_old = 12.0709
# 	Core 2
# 		Choosing direct solver (local size 72)....
# 		dx = 0.032691, res_now = 2.35346e-16, res_old = 0.634883
# 	Core 3
# 		Choosing direct solver (local size 72)....
# 		dx = 0.0109774, res_now = 1.91115e-12, res_old = 1.54677
# 	Core 4
# 		Choosing direct solver (local size 72)....
# 		dx = 0.0285369, res_now = 1.17606e-16, res_old = 0.268107
# 	Core 5
# 		Choosing direct solver (local size 72)....
# 		dx = 0.0205455, res_now = 2.85285e-16, res_old = 0.6372
# Solution rank is [1, 9, 9, 9, 9, 9, 1]
# Maxres  tensor(12.0709, device='cuda:0')
# Time  0:00:00.519147
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.0014553 (from 3.22484e-08)
# 		Time needed  0:00:00.167518
# 		dx = 0.0622054, res_now = 0.0014553, res_old = 6.32974
# 	Core 1
# 		Choosing iterative solver GMRES (local size 9792)....
# 		Finished with flag 0 after 80 iterations with relres 0.00743123 (from 1.1121e-07)
# 		Time needed  0:00:03.349855
# 		dx = 0.0202492, res_now = 0.00743123, res_old = 1.83548
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1224)....
# 		Finished with flag 1 after 28 iterations with relres 8.51887e-08 (from 2.44538e-06)
# 		Time needed  0:00:00.075103
# 		dx = 0.00107447, res_now = 8.51887e-08, res_old = 0.0834733
# 	Core 3
# 		Choosing iterative solver GMRES (local size 1224)....
# 		Finished with flag 1 after 29 iterations with relres 1.95069e-07 (from 7.30541e-06)
# 		Time needed  0:00:00.042750
# 		dx = 0.000590486, res_now = 1.95069e-07, res_old = 0.0279415
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 1 after 36 iterations with relres 1.86534e-07 (from 2.60073e-05)
# 		Time needed  0:00:00.061026
# 		dx = 0.000161599, res_now = 1.86534e-07, res_old = 0.00784872
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 5.15624e-10, res_now = 6.52128e-15, res_old = 1.91924e-07
# Solution rank is [1, 17, 17, 17, 17, 16, 1]
# Maxres  tensor(6.3297, device='cuda:0')
# Time  0:00:03.948487
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 0 after 80 iterations with relres 0.000948785 (from 2.27079e-06)
# 		Time needed  0:00:00.181313
# 		dx = 0.0141405, res_now = 0.000948785, res_old = 0.0898911
# 	Core 1
# 		Choosing iterative solver GMRES (local size 27200)....
# 		Finished with flag 0 after 80 iterations with relres 0.00218467 (from 1.9052e-06)
# 		Time needed  0:00:06.313406
# 		dx = 0.00448823, res_now = 0.00218467, res_old = 0.10714
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3400)....
# 		Finished with flag 1 after 67 iterations with relres 1.97238e-07 (from 5.27343e-05)
# 		Time needed  0:00:00.176203
# 		dx = 0.000154419, res_now = 1.97238e-07, res_old = 0.0038708
# 	Core 3
# 		Choosing iterative solver GMRES (local size 3400)....
# 		Finished with flag 1 after 35 iterations with relres 1.80047e-07 (from 0.000487598)
# 		Time needed  0:00:00.058555
# 		dx = 5.84106e-06, res_now = 1.80047e-07, res_old = 0.000418632
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 1 after 2 iterations with relres 2.03367e-07 (from 0.139496)
# 		Time needed  0:00:00.003166
# 		dx = 2.02897e-08, res_now = 2.03367e-07, res_old = 1.46329e-06
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.66345e-08, res_now = 2.83282e-16, res_old = 2.1108e-07
# Solution rank is [1, 25, 25, 25, 25, 16, 1]
# Maxres  tensor(0.1071, device='cuda:0')
# Time  0:00:07.129579
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 0 after 80 iterations with relres 9.62957e-05 (from 2.14291e-05)
# 		Time needed  0:00:00.176193
# 		dx = 0.000784081, res_now = 9.62957e-05, res_old = 0.00952556
# 	Core 1
# 		Choosing iterative solver GMRES (local size 52800)....
# 		Finished with flag 0 after 80 iterations with relres 0.000692961 (from 6.34484e-06)
# 		Time needed  0:00:10.328483
# 		dx = 0.00162922, res_now = 0.000692961, res_old = 0.0321717
# 	Core 2
# 		Choosing iterative solver GMRES (local size 6600)....
# 		Finished with flag 0 after 80 iterations with relres 1.95998e-06 (from 0.000241375)
# 		Time needed  0:00:00.251733
# 		dx = 0.000254171, res_now = 1.95998e-06, res_old = 0.000845673
# 	Core 3
# 		Choosing iterative solver GMRES (local size 6600)....
# 		Finished with flag 1 after 59 iterations with relres 2.00897e-07 (from 0.00287506)
# 		Time needed  0:00:00.100807
# 		dx = 3.98658e-06, res_now = 2.00897e-07, res_old = 7.09982e-05
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 1 after 3 iterations with relres 1.95334e-07 (from 0.29592)
# 		Time needed  0:00:00.004455
# 		dx = 2.35739e-08, res_now = 1.95334e-07, res_old = 6.89795e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 3.99167e-08, res_now = 1.62293e-16, res_old = 2.00009e-07
# Solution rank is [1, 33, 33, 33, 33, 16, 1]
# Maxres  tensor(0.0322, device='cuda:0')
# Time  0:00:11.414978
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 0 after 80 iterations with relres 5.14831e-05 (from 8.43857e-05)
# 		Time needed  0:00:00.179550
# 		dx = 0.000358686, res_now = 5.14831e-05, res_old = 0.00241894
# 	Core 1
# 		Choosing iterative solver GMRES (local size 86592)....
# 		Finished with flag 0 after 80 iterations with relres 0.000247431 (from 2.50159e-05)
# 		Time needed  0:00:17.383867
# 		dx = 0.000430517, res_now = 0.000247431, res_old = 0.00815978
# 	Core 2
# 		Choosing iterative solver GMRES (local size 10824)....
# 		Finished with flag 0 after 80 iterations with relres 2.2503e-06 (from 0.000752145)
# 		Time needed  0:00:00.365653
# 		dx = 0.000192474, res_now = 2.2503e-06, res_old = 0.000271389
# 	Core 3
# 		Choosing iterative solver GMRES (local size 10824)....
# 		Finished with flag 1 after 70 iterations with relres 1.9663e-07 (from 0.0365687)
# 		Time needed  0:00:00.163538
# 		dx = 6.76394e-06, res_now = 1.9663e-07, res_old = 5.58194e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 1 after 2 iterations with relres 1.88455e-07 (from 0.953364)
# 		Time needed  0:00:00.003168
# 		dx = 1.78462e-08, res_now = 1.88455e-07, res_old = 2.14109e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 2.82245e-07, res_now = 5.76745e-16, res_old = 1.96189e-07
# Solution rank is [1, 41, 41, 41, 41, 16, 1]
# Maxres  tensor(0.0082, device='cuda:0')
# Time  0:00:18.901986
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 0 after 80 iterations with relres 2.92549e-05 (from 0.000235042)
# 		Time needed  0:00:00.188641
# 		dx = 0.000168684, res_now = 2.92549e-05, res_old = 0.000868457
# 	Core 1
# 		Choosing iterative solver GMRES (local size 128576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00012343 (from 5.18386e-05)
# 		Time needed  0:00:24.643572
# 		dx = 0.000172583, res_now = 0.00012343, res_old = 0.00393768
# 	Core 2
# 		Choosing iterative solver GMRES (local size 16072)....
# 		Finished with flag 0 after 80 iterations with relres 2.23309e-06 (from 0.00151313)
# 		Time needed  0:00:00.493046
# 		dx = 7.47593e-05, res_now = 2.23309e-06, res_old = 0.000134902
# 	Core 3
# 		Choosing iterative solver GMRES (local size 16072)....
# 		Finished with flag 0 after 80 iterations with relres 3.73066e-07 (from 0.0797217)
# 		Time needed  0:00:00.279396
# 		dx = 2.18794e-05, res_now = 3.73066e-07, res_old = 2.56046e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 1 after 22 iterations with relres 1.98638e-07 (from 0.541792)
# 		Time needed  0:00:00.028006
# 		dx = 1.33427e-06, res_now = 1.98638e-07, res_old = 3.76758e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 7.52063e-08, res_now = 1.73697e-16, res_old = 2.10434e-07
# Solution rank is [1, 49, 49, 49, 49, 16, 1]
# Maxres  tensor(0.0039, device='cuda:0')
# Time  0:00:26.715845
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 0 after 80 iterations with relres 1.59702e-05 (from 0.000393852)
# 		Time needed  0:00:00.181039
# 		dx = 8.50482e-05, res_now = 1.59702e-05, res_old = 0.000518277
# 	Core 1
# 		Choosing iterative solver GMRES (local size 178752)....
# 		Finished with flag 0 after 80 iterations with relres 6.66815e-05 (from 9.02005e-05)
# 		Time needed  0:00:34.050225
# 		dx = 6.76876e-05, res_now = 6.66815e-05, res_old = 0.002263
# 	Core 2
# 		Choosing iterative solver GMRES (local size 22344)....
# 		Finished with flag 0 after 80 iterations with relres 1.5759e-06 (from 0.00288772)
# 		Time needed  0:00:00.623300
# 		dx = 3.35396e-05, res_now = 1.5759e-06, res_old = 7.0687e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 22344)....
# 		Finished with flag 0 after 80 iterations with relres 2.38154e-07 (from 0.120473)
# 		Time needed  0:00:00.318344
# 		dx = 9.11414e-06, res_now = 2.38154e-07, res_old = 1.69436e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 1 after 8 iterations with relres 1.98839e-07 (from 0.835477)
# 		Time needed  0:00:00.008240
# 		dx = 2.53879e-07, res_now = 1.98839e-07, res_old = 2.4432e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.11318e-07, res_now = 9.78573e-16, res_old = 2.06201e-07
# Solution rank is [1, 57, 57, 57, 57, 16, 1]
# Maxres  tensor(0.0023, device='cuda:0')
# Time  0:00:36.605530
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 0 after 80 iterations with relres 7.67752e-06 (from 0.000595566)
# 		Time needed  0:00:00.181874
# 		dx = 2.08407e-05, res_now = 7.67752e-06, res_old = 0.00034274
# 	Core 1
# 		Choosing iterative solver GMRES (local size 233472)....
# 		Finished with flag 0 after 80 iterations with relres 5.37798e-05 (from 0.000228203)
# 		Time needed  0:00:44.231323
# 		dx = 1.11764e-05, res_now = 5.37798e-05, res_old = 0.000894483
# 	Core 2
# 		Choosing iterative solver GMRES (local size 29640)....
# 		Finished with flag 0 after 80 iterations with relres 1.51833e-06 (from 0.00365087)
# 		Time needed  0:00:00.793218
# 		dx = 1.69844e-05, res_now = 1.51833e-06, res_old = 5.59111e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 29640)....
# 		Finished with flag 1 after 52 iterations with relres 2.0311e-07 (from 0.131348)
# 		Time needed  0:00:00.273384
# 		dx = 1.20501e-06, res_now = 2.0311e-07, res_old = 1.55407e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4160)....
# 		Finished with flag 1 after 3 iterations with relres 2.02431e-07 (from 0.971348)
# 		Time needed  0:00:00.003923
# 		dx = 1.56494e-08, res_now = 2.02431e-07, res_old = 2.10145e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 9.31114e-08, res_now = 1.72811e-16, res_old = 2.10296e-07
# Solution rank is [1, 64, 65, 65, 65, 16, 1]
# Maxres  tensor(0.0009, device='cuda:0')
# Time  0:00:47.288613
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 5.48901e-06 (from 0.000700944)
# 		Time needed  0:00:00.183192
# 		dx = 1.3716e-05, res_now = 5.48901e-06, res_old = 0.000291213
# 	Core 1
# 		Choosing iterative solver GMRES (local size 266240)....
# 		Finished with flag 0 after 80 iterations with relres 3.46258e-05 (from 0.000285926)
# 		Time needed  0:00:51.298703
# 		dx = 2.67751e-05, res_now = 3.46258e-05, res_old = 0.000713906
# 	Core 2
# 		Choosing iterative solver GMRES (local size 37960)....
# 		Finished with flag 0 after 80 iterations with relres 2.00997e-06 (from 0.00571956)
# 		Time needed  0:00:01.024923
# 		dx = 2.07775e-05, res_now = 2.00997e-06, res_old = 3.56888e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 37376)....
# 		Finished with flag 1 after 64 iterations with relres 2.01807e-07 (from 0.100273)
# 		Time needed  0:00:00.357857
# 		dx = 1.90383e-06, res_now = 2.01807e-07, res_old = 2.03568e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 1 iterations with relres 2.00851e-07 (from 0.980301)
# 		Time needed  0:00:00.002667
# 		dx = 6.59489e-09, res_now = 2.00851e-07, res_old = 2.08226e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.44237e-08, res_now = 1.53952e-16, res_old = 2.12332e-07
# Solution rank is [1, 64, 73, 73, 72, 16, 1]
# Maxres  tensor(0.0007, device='cuda:0')
# Time  0:00:54.975715
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 4.18272e-06 (from 0.00125214)
# 		Time needed  0:00:00.183934
# 		dx = 1.25764e-05, res_now = 4.18272e-06, res_old = 0.00016302
# 	Core 1
# 		Choosing iterative solver GMRES (local size 299008)....
# 		Finished with flag 0 after 80 iterations with relres 2.19551e-05 (from 0.000459635)
# 		Time needed  0:00:57.552143
# 		dx = 1.50292e-05, res_now = 2.19551e-05, res_old = 0.000444101
# 	Core 2
# 		Choosing iterative solver GMRES (local size 47304)....
# 		Finished with flag 0 after 80 iterations with relres 1.14937e-06 (from 0.00905313)
# 		Time needed  0:00:01.237492
# 		dx = 1.12149e-05, res_now = 1.14937e-06, res_old = 2.25474e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 41472)....
# 		Finished with flag 1 after 55 iterations with relres 2.02936e-07 (from 0.173961)
# 		Time needed  0:00:00.357702
# 		dx = 1.01741e-06, res_now = 2.02936e-07, res_old = 1.17339e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 1 iterations with relres 2.03333e-07 (from 0.980889)
# 		Time needed  0:00:00.002615
# 		dx = 3.94824e-09, res_now = 2.03333e-07, res_old = 2.08101e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.9066e-08, res_now = 3.96344e-16, res_old = 2.13607e-07
# Solution rank is [1, 64, 81, 81, 72, 16, 1]
# Maxres  tensor(0.0004, device='cuda:0')
# Time  0:01:01.666521
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 1.49045e-06 (from 0.00251877)
# 		Time needed  0:00:00.183544
# 		dx = 7.78599e-06, res_now = 1.49045e-06, res_old = 8.10411e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 331776)....
# 		Finished with flag 0 after 80 iterations with relres 1.3958e-05 (from 0.00103589)
# 		Time needed  0:01:03.773893
# 		dx = 1.19029e-05, res_now = 1.3958e-05, res_old = 0.000197052
# 	Core 2
# 		Choosing iterative solver GMRES (local size 57672)....
# 		Finished with flag 0 after 80 iterations with relres 7.06672e-07 (from 0.0144333)
# 		Time needed  0:00:01.521503
# 		dx = 5.74295e-06, res_now = 7.06672e-07, res_old = 1.41426e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 45568)....
# 		Finished with flag 1 after 40 iterations with relres 2.0373e-07 (from 0.279669)
# 		Time needed  0:00:00.291998
# 		dx = 7.15983e-07, res_now = 2.0373e-07, res_old = 7.29877e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 1 iterations with relres 2.02161e-07 (from 0.975409)
# 		Time needed  0:00:00.002652
# 		dx = 6.3492e-09, res_now = 2.02161e-07, res_old = 2.0927e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.71332e-08, res_now = 1.63223e-16, res_old = 2.12369e-07
# Solution rank is [1, 64, 89, 89, 72, 16, 1]
# Maxres  tensor(0.0002, device='cuda:0')
# Time  0:01:08.339104
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 6.87239e-07 (from 0.00481653)
# 		Time needed  0:00:00.183981
# 		dx = 3.51385e-06, res_now = 6.87239e-07, res_old = 4.23799e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 364544)....
# 		Finished with flag 0 after 80 iterations with relres 9.31017e-06 (from 0.00197937)
# 		Time needed  0:01:10.016102
# 		dx = 5.86074e-06, res_now = 9.31017e-06, res_old = 0.000103126
# 	Core 2
# 		Choosing iterative solver GMRES (local size 69064)....
# 		Finished with flag 0 after 80 iterations with relres 5.35499e-07 (from 0.0213921)
# 		Time needed  0:00:01.838207
# 		dx = 3.26718e-06, res_now = 5.35499e-07, res_old = 9.54205e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 49664)....
# 		Finished with flag 1 after 25 iterations with relres 2.03449e-07 (from 0.360937)
# 		Time needed  0:00:00.198721
# 		dx = 2.59057e-07, res_now = 2.03449e-07, res_old = 5.6554e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 2.02042e-07 (from 0.964277)
# 		Time needed  0:00:00.002019
# 		dx = 2.46836e-09, res_now = 2.02042e-07, res_old = 2.11686e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.06277e-08, res_now = 1.72423e-16, res_old = 2.13783e-07
# Solution rank is [1, 64, 97, 97, 72, 16, 1]
# Maxres  tensor(0.0001, device='cuda:0')
# Time  0:01:15.036607
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 4.12345e-07 (from 0.00630199)
# 		Time needed  0:00:00.184292
# 		dx = 1.87687e-06, res_now = 4.12345e-07, res_old = 3.23904e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 397312)....
# 		Finished with flag 0 after 80 iterations with relres 6.50487e-06 (from 0.00316007)
# 		Time needed  0:01:16.317378
# 		dx = 3.94836e-06, res_now = 6.50487e-06, res_old = 6.45948e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 81480)....
# 		Finished with flag 0 after 80 iterations with relres 4.71804e-07 (from 0.0308301)
# 		Time needed  0:00:02.075618
# 		dx = 2.20328e-06, res_now = 4.71804e-07, res_old = 6.62093e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 53760)....
# 		Finished with flag 1 after 24 iterations with relres 2.0189e-07 (from 0.418622)
# 		Time needed  0:00:00.204495
# 		dx = 1.48657e-07, res_now = 2.0189e-07, res_old = 4.8761e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 2.01798e-07 (from 0.971425)
# 		Time needed  0:00:00.002008
# 		dx = 1.52697e-09, res_now = 2.01798e-07, res_old = 2.10129e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 4.10549e-08, res_now = 1.2948e-16, res_old = 2.12785e-07
# Solution rank is [1, 64, 105, 105, 72, 16, 1]
# Maxres  tensor(6.4595e-05, device='cuda:0')
# Time  0:01:21.815325
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.44243e-07 (from 0.0106084)
# 		Time needed  0:00:00.183869
# 		dx = 1.16897e-06, res_now = 2.44243e-07, res_old = 1.92417e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 430080)....
# 		Finished with flag 0 after 80 iterations with relres 4.84428e-06 (from 0.00521023)
# 		Time needed  0:01:22.614579
# 		dx = 2.07209e-06, res_now = 4.84428e-06, res_old = 3.91776e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 94920)....
# 		Finished with flag 0 after 80 iterations with relres 3.71181e-07 (from 0.0412475)
# 		Time needed  0:00:02.429164
# 		dx = 1.47204e-06, res_now = 3.71181e-07, res_old = 4.94877e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 57856)....
# 		Finished with flag 1 after 15 iterations with relres 2.02379e-07 (from 0.539027)
# 		Time needed  0:00:00.162362
# 		dx = 4.98469e-08, res_now = 2.02379e-07, res_old = 3.7869e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 1 iterations with relres 1.91056e-07 (from 0.961097)
# 		Time needed  0:00:00.002604
# 		dx = 3.34108e-09, res_now = 1.91056e-07, res_old = 2.12387e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 2.62409e-08, res_now = 1.64419e-16, res_old = 2.01139e-07
# Solution rank is [1, 64, 113, 113, 72, 16, 1]
# Maxres  tensor(3.9178e-05, device='cuda:0')
# Time  0:01:28.651367
#
# Starting sweep 14 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 74 iterations with relres 2.00537e-07 (from 0.0118398)
# 		Time needed  0:00:00.167856
# 		dx = 6.86784e-07, res_now = 2.00537e-07, res_old = 1.72405e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 462848)....
# 		Finished with flag 0 after 80 iterations with relres 4.40597e-06 (from 0.00658449)
# 		Time needed  0:01:28.819273
# 		dx = 9.13503e-07, res_now = 4.40597e-06, res_old = 3.10008e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 109384)....
# 		Finished with flag 0 after 80 iterations with relres 2.62733e-07 (from 0.0450772)
# 		Time needed  0:00:02.863081
# 		dx = 7.8632e-07, res_now = 2.62733e-07, res_old = 4.52832e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 61952)....
# 		Finished with flag 1 after 4 iterations with relres 2.01029e-07 (from 0.758215)
# 		Time needed  0:00:00.073921
# 		dx = 8.57715e-09, res_now = 2.01029e-07, res_old = 2.69217e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.90772e-07 (from 0.966939)
# 		Time needed  0:00:00.002033
# 		dx = 2.29078e-09, res_now = 1.90772e-07, res_old = 2.11103e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 2.62239e-08, res_now = 1.81678e-16, res_old = 2.00871e-07
# Solution rank is [1, 64, 121, 121, 72, 16, 1]
# Maxres  tensor(3.1001e-05, device='cuda:0')
# Time  0:01:35.412880
#
# Starting sweep 15 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.04523e-07 (from 0.0100069)
# 		Time needed  0:00:00.185295
# 		dx = 9.12127e-07, res_now = 2.04523e-07, res_old = 2.03984e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 495616)....
# 		Finished with flag 0 after 80 iterations with relres 3.6613e-06 (from 0.00766101)
# 		Time needed  0:01:35.103037
# 		dx = 2.91963e-07, res_now = 3.6613e-06, res_old = 2.66446e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 124872)....
# 		Finished with flag 0 after 80 iterations with relres 2.53218e-07 (from 0.0545652)
# 		Time needed  0:00:03.311884
# 		dx = 6.50759e-07, res_now = 2.53218e-07, res_old = 3.74092e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 66048)....
# 		Finished with flag 1 after 3 iterations with relres 1.96679e-07 (from 0.788933)
# 		Time needed  0:00:00.069798
# 		dx = 5.21538e-09, res_now = 1.96679e-07, res_old = 2.58734e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.81088e-07 (from 0.98941)
# 		Time needed  0:00:00.002391
# 		dx = 3.36207e-09, res_now = 1.81088e-07, res_old = 2.06309e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 3.27906e-08, res_now = 4.30718e-16, res_old = 1.92283e-07
# Solution rank is [1, 64, 129, 129, 72, 16, 1]
# Maxres  tensor(2.6645e-05, device='cuda:0')
# Time  0:01:42.412382
#
# Starting sweep 16 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 69 iterations with relres 2.03305e-07 (from 0.0125565)
# 		Time needed  0:00:00.156017
# 		dx = 3.70642e-07, res_now = 2.03305e-07, res_old = 1.62564e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 528384)....
# 		Finished with flag 0 after 80 iterations with relres 2.53305e-06 (from 0.00799568)
# 		Time needed  0:01:43.444102
# 		dx = 8.70731e-07, res_now = 2.53305e-06, res_old = 2.55293e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 141384)....
# 		Finished with flag 0 after 80 iterations with relres 2.2154e-07 (from 0.0790474)
# 		Time needed  0:00:03.968987
# 		dx = 6.27802e-07, res_now = 2.2154e-07, res_old = 2.5823e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 70144)....
# 		Finished with flag 1 after 2 iterations with relres 1.90874e-07 (from 0.899309)
# 		Time needed  0:00:00.067331
# 		dx = 2.59919e-09, res_now = 1.90874e-07, res_old = 2.26979e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.7274e-07 (from 1.01883)
# 		Time needed  0:00:00.002122
# 		dx = 3.14213e-09, res_now = 1.7274e-07, res_old = 2.00351e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.8028e-08, res_now = 3.06273e-16, res_old = 1.82147e-07
# Solution rank is [1, 64, 137, 137, 72, 16, 1]
# Maxres  tensor(2.5529e-05, device='cuda:0')
# Time  0:01:51.656774
#
# Starting sweep 17 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 50 iterations with relres 2.02589e-07 (from 0.0196145)
# 		Time needed  0:00:00.123796
# 		dx = 4.39713e-07, res_now = 2.02589e-07, res_old = 1.04068e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 561152)....
# 		Finished with flag 0 after 80 iterations with relres 2.2796e-06 (from 0.0117483)
# 		Time needed  0:01:49.832147
# 		dx = 3.29228e-07, res_now = 2.2796e-06, res_old = 1.73748e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 158920)....
# 		Finished with flag 1 after 77 iterations with relres 2.03879e-07 (from 0.0878585)
# 		Time needed  0:00:04.343969
# 		dx = 4.20168e-07, res_now = 2.03879e-07, res_old = 2.32333e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 74240)....
# 		Finished with flag 1 after 0 iterations with relres 2.00061e-07 (from 0.97725)
# 		Time needed  0:00:00.051730
# 		dx = 3.59856e-10, res_now = 2.00061e-07, res_old = 2.08876e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.78174e-07 (from 0.969262)
# 		Time needed  0:00:00.002370
# 		dx = 3.19815e-09, res_now = 1.78174e-07, res_old = 2.10598e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.27353e-08, res_now = 3.37203e-16, res_old = 1.88061e-07
# Solution rank is [1, 64, 145, 145, 72, 16, 1]
# Maxres  tensor(1.7375e-05, device='cuda:0')
# Time  0:01:58.614265
#
# Starting sweep 18 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 40 iterations with relres 2.03623e-07 (from 0.0244115)
# 		Time needed  0:00:00.115247
# 		dx = 2.99558e-07, res_now = 2.03623e-07, res_old = 8.3618e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 593920)....
# 		Finished with flag 0 after 80 iterations with relres 2.12729e-06 (from 0.0133775)
# 		Time needed  0:01:56.203401
# 		dx = 2.31695e-07, res_now = 2.12729e-06, res_old = 1.52587e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 177480)....
# 		Finished with flag 1 after 70 iterations with relres 2.01892e-07 (from 0.0944964)
# 		Time needed  0:00:04.456701
# 		dx = 2.8085e-07, res_now = 2.01892e-07, res_old = 2.16013e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 78336)....
# 		Finished with flag 1 after 0 iterations with relres 1.99354e-07 (from 0.986797)
# 		Time needed  0:00:00.053093
# 		dx = 2.94433e-10, res_now = 1.99354e-07, res_old = 2.06855e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.81804e-07 (from 0.969566)
# 		Time needed  0:00:00.002368
# 		dx = 2.36792e-09, res_now = 1.81804e-07, res_old = 2.10531e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.00679e-08, res_now = 7.57476e-16, res_old = 1.91633e-07
# Solution rank is [1, 64, 153, 153, 72, 16, 1]
# Maxres  tensor(1.5259e-05, device='cuda:0')
# Time  0:02:05.333645
#
# Starting sweep 19 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 36 iterations with relres 2.03121e-07 (from 0.0284218)
# 		Time needed  0:00:00.102611
# 		dx = 2.41004e-07, res_now = 2.03121e-07, res_old = 7.18197e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 626688)....
# 		Finished with flag 0 after 80 iterations with relres 1.92581e-06 (from 0.0142173)
# 		Time needed  0:02:02.640282
# 		dx = 2.83236e-07, res_now = 1.92581e-06, res_old = 1.43575e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 197064)....
# 		Finished with flag 1 after 73 iterations with relres 2.03751e-07 (from 0.103765)
# 		Time needed  0:00:05.179370
# 		dx = 3.03712e-07, res_now = 2.03751e-07, res_old = 1.96717e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 82432)....
# 		Finished with flag 1 after 0 iterations with relres 2.01669e-07 (from 0.979279)
# 		Time needed  0:00:00.059556
# 		dx = 3.46039e-10, res_now = 2.01669e-07, res_old = 2.08443e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.80924e-07 (from 0.957702)
# 		Time needed  0:00:00.002075
# 		dx = 3.7745e-09, res_now = 1.80924e-07, res_old = 2.1314e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.37846e-08, res_now = 6.64152e-16, res_old = 1.90075e-07
# Solution rank is [1, 64, 161, 161, 72, 16, 1]
# Maxres  tensor(1.4357e-05, device='cuda:0')
# Time  0:02:12.730314
#
# Starting sweep 20 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 36 iterations with relres 2.0058e-07 (from 0.0222537)
# 		Time needed  0:00:00.103740
# 		dx = 2.07894e-07, res_now = 2.0058e-07, res_old = 9.17258e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 659456)....
# 		Finished with flag 0 after 80 iterations with relres 1.589e-06 (from 0.013402)
# 		Time needed  0:02:08.984546
# 		dx = 5.11896e-07, res_now = 1.589e-06, res_old = 1.52308e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 217672)....
# 		Finished with flag 1 after 70 iterations with relres 2.02557e-07 (from 0.126458)
# 		Time needed  0:00:05.511645
# 		dx = 3.08192e-07, res_now = 2.02557e-07, res_old = 1.61417e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 86528)....
# 		Finished with flag 1 after 0 iterations with relres 2.02109e-07 (from 0.98424)
# 		Time needed  0:00:00.063416
# 		dx = 3.13517e-10, res_now = 2.02109e-07, res_old = 2.07393e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.90772e-07 (from 0.953385)
# 		Time needed  0:00:00.002026
# 		dx = 2.58629e-09, res_now = 1.90772e-07, res_old = 2.14105e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.73543e-08, res_now = 3.66814e-16, res_old = 2.01195e-07
# Solution rank is [1, 64, 169, 169, 72, 16, 1]
# Maxres  tensor(1.5231e-05, device='cuda:0')
# Time  0:02:19.660078
#
# Starting sweep 21 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 30 iterations with relres 1.94133e-07 (from 0.0381293)
# 		Time needed  0:00:00.087821
# 		dx = 1.59288e-07, res_now = 1.94133e-07, res_old = 5.35347e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 692224)....
# 		Finished with flag 0 after 80 iterations with relres 1.31653e-06 (from 0.0174023)
# 		Time needed  0:02:15.348799
# 		dx = 4.72531e-07, res_now = 1.31653e-06, res_old = 1.17297e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 239304)....
# 		Finished with flag 1 after 65 iterations with relres 2.0289e-07 (from 0.152947)
# 		Time needed  0:00:05.738477
# 		dx = 2.56776e-07, res_now = 2.0289e-07, res_old = 1.33461e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 90624)....
# 		Finished with flag 1 after 0 iterations with relres 1.99047e-07 (from 0.982858)
# 		Time needed  0:00:00.068404
# 		dx = 4.66362e-10, res_now = 1.99047e-07, res_old = 2.07684e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4608)....
# 		Finished with flag 1 after 0 iterations with relres 1.67249e-07 (from 0.967692)
# 		Time needed  0:00:00.002177
# 		dx = 3.08344e-09, res_now = 1.67249e-07, res_old = 2.10939e-07
# 	Core 5
# 		Choosing direct solver (local size 128)....
# 		dx = 1.43172e-08, res_now = 4.45918e-16, res_old = 1.77214e-07
# Solution rank is [1, 64, 177, 177, 72, 16, 1]
# Maxres  tensor(1.1730e-05, device='cuda:0')
# Time  0:02:26.571522
#
# Starting sweep 22 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 23 iterations with relres 1.98129e-07 (from 0.048332)
# 		Time needed  0:00:00.073182
# 		dx = 1.41944e-07, res_now = 1.98129e-07, res_old = 4.22337e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 724992)....

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt

plt.figure()
y1, y2 = basis_solution[0].collocation_points(3)[0], basis_solution[1].collocation_points(3)[0]
w1, w2 = basis_solution[0].collocation_points(3)[1], basis_solution[1].collocation_points(3)[1]
ws = np.einsum('i,j->ij',w1,w2)
X1,X2 = geom([y1,y2]+[tn.tensor([0.0])]*4)
u = fspace([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
plt.contourf(X1.numpy().squeeze(), X2.numpy().squeeze(),u.numpy().squeeze(),levels=32)
plt.colorbar()

import pickle
dct = {'x1' : X1.numpy().squeeze(), 'x2' : X2.numpy().squeeze(), 'u' : u.numpy().squeeze(), 'ws' : ws}

    
u = fspace([tn.tensor([0.05]),tn.tensor([0.0]), tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10), tn.linspace(-0.001,0.001,10)])

def get_in_reference(x, param1):
    return 0.4*x/(3.27640e-2+param1)
    # return 0.1*x/(geom([tn.tensor([0.1]),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([param1]), tn.tensor([0.0])])[0].numpy().squeeze())

# %%
y1, y2 = np.linspace(0,1,32), np.linspace(0.,1,32)

grad1, grad2 = geom.gradient_physical(basis_solution, fspace)

g2 = -grad1([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
g1 = grad2([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
x1,x2 = geom([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)

plt.figure()
plt.quiver(x1.numpy().flatten(),x2.numpy().flatten(),g1.numpy().flatten(),g2.numpy().flatten(),np.sqrt(g1.numpy().flatten()**2+g2.numpy().flatten()**2))
plt.colorbar()

x1B, x2B = geom([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0])])

dct['x1B'] = x1B.numpy().squeeze()
dct['x2B'] = x2B.numpy().squeeze()

g2 = -grad1([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
g1 = grad2([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()

dct['B1'] = g1
dct['B2'] = g2

with open('quad_nominal.pkl','wb') as f:
    pickle.dump(dct, f)

# %%
with open(r"measurements.pkl", "rb") as input_file:
    data = pickle.load(input_file)
x_positions  =tn.tensor(data['x_positions'])

print(data['B'])
B_noise = data['B'] + np.random.normal(0,0.0001,size = data['B'].shape)
print(B_noise)

print(grad2(tn.outer(get_in_reference(x_positions,0), tn.tensor([1.0,0,0,0,0,0]))))
print(-grad1(tn.outer(get_in_reference(x_positions,0), tn.tensor([1.0,0,0,0,0,0]))))

# %%
sigma_noise = 0.0001  

grad1.dofs = grad1.dofs.round(1e-8)
grad2.dofs = grad2.dofs.round(1e-8)

grad1_proj = tt_iga.Function(grad1.basis[:1]+grad1.basis[2:])
grad2_proj = tt_iga.Function(grad1.basis[:1]+grad1.basis[2:])

grad1_proj.dofs = grad1.dofs.mprod(tn.tensor(grad1.basis[1](np.array([0.0]))).T,1)[:,0,...].round(1e-9)
grad2_proj.dofs = grad2.dofs.mprod(tn.tensor(grad2.basis[1](np.array([0.0]))).T,1)[:,0,...].round(1e-9)

def likelihood(params):
    g2 = -grad1([get_in_reference(x_positions,params[1]), tn.tensor([0]), tn.tensor([params[0]]), tn.tensor([params[1]]),tn.tensor([params[2]]), tn.tensor([params[3]])]).numpy().flatten()
    g1 =  grad2([get_in_reference(x_positions,params[1]), tn.tensor([0]), tn.tensor([params[0]]), tn.tensor([params[1]]),tn.tensor([params[2]]), tn.tensor([params[3]])]).numpy().flatten()

    s = np.sum((B_noise[:,0] - g1)**2) + np.sum((B_noise[:,1] - g2)**2) 
    
    return np.exp(-0.5/sigma_noise**2 *s)

def prior(params):
    return 1.0

def post(p):
    return likelihood(p)*prior(p)

def likelihood_handle(params):

    s = tn.zeros((params.shape[0],))

    for k in range(len(x_positions)):
        argz = tn.hstack((tn.reshape(get_in_reference(x_positions[k],params[:,1]),[-1,1]) ,tn.zeros((params.shape[0],1)), params))
        g2 = -grad1_proj(argz)
        # g1 = grad2_proj(argz)
        # s = s + (g1 - B_noise[k,0])**2 
        s = s + (g2 - B_noise[k,1])**2
    return tn.exp(-0.5/sigma_noise**2 * s)
        




def prior_handle(params):
    # return tn.ones((params.shape[0],))
    alpha = 5
    beta = 4
    scale = lambda p,v: (p+v)/2/v
    p1 = scale(params[:,0], var1)**(alpha-1)*(1-scale(params[:,0], var1))**(beta-1)
    p2 = scale(params[:,1], var2)**(alpha-1)*(1-scale(params[:,1], var2))**(beta-1)
    p3 = scale(params[:,2], var3)**(alpha-1)*(1-scale(params[:,2], var3))**(beta-1)
    p4 = scale(params[:,3], var4)**(alpha-1)*(1-scale(params[:,3], var4))**(beta-1)
    return p1*p2*p3*p4
    #return tn.exp(-1/(2*var*var)*(params[:,0]**2+params[:,1]**2+params[:,2]**2+params[:,3]**2))

def posterior_handle(params):
    print(params.shape)
    return prior_handle(params)* likelihood_handle(params)
    # return tn.tensor(list(map((post), list(params))))

# %%
import TTCME

basis = [TTCME.basis.BSplineBasis(34,[-var1,var1],2), TTCME.basis.BSplineBasis(32,[-var2,var2],2), TTCME.basis.BSplineBasis(32,[-var3,var3],2), TTCME.basis.BSplineBasis(32,[-var4,var4],2)]


posterior_pdf = TTCME.pdfTT.interpoalte(posterior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
print(posterior_pdf)

prior_pdf = TTCME.pdfTT.interpoalte(prior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])

# %%
posterior_pdf.normalize()

E = posterior_pdf.expected_value()
C = posterior_pdf.covariance_matrix()
V = np.diag(C)

print()
print('Exact parameters:                 ',[0,0,0,0])
print('')
print('Expected value computed posterior ' ,E)
print('Variance computed posterior       ' ,V)

# %%
plt.figure(figsize = [6,6])
true_parameters = [0.0]*4
k = 0
for i in range(4):
    for j in range(4):
        k += 1
        if i==j:
            plt.subplot(4, 4, k)
            
            theta = np.linspace(basis[i].domain[0], basis[i].domain[1],1000)
            pr = prior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
            po = posterior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
           
            plt.plot(1e3*theta,1e3*(po/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)))
            plt.axvline(true_parameters[i],c='r',linestyle=':')
            plt.plot(1e3*theta,1e3*(pr/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)),'g:')
            
        else:
            plt.subplot(4, 4, k)
             
            if j<i: 
                theta1 = np.linspace(basis[j].domain[0], basis[j].domain[1], 127)
                theta2 = np.linspace(basis[i].domain[0], basis[i].domain[1], 128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T1, 1e3*T2, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
            else: 
                theta1 = np.linspace(basis[i].domain[0],basis[i].domain[1],127)
                theta2 = np.linspace(basis[j].domain[0],basis[j].domain[1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T2, 1e3*T1, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
        
        if i==3: plt.xlabel(r'$\theta_'+str(j+1)+'$ [mm]')
        if j==0: plt.ylabel(r'$\theta_'+str(i+1)+'$ [mm]')
        
        if j>0: plt.yticks([])
        if i<3: plt.xticks([])

plt.savefig('quad_posterior1.eps')
tikzplotlib.save('quad_posterior1.tex')

# %%
dofs_tt.round(1e-6)
