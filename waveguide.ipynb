# %% [markdown]
# # Helmholz equation on a parameter dependent domain
#
# Solve the scalar Helmholz on a domain (depending on 3 parameters) resembeling a rectangular waveguide.
#
# Imports

# %%
import torch as tn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
import datetime
try:
    import torchtt as tntt
except:
    print('Installing torchTT...')
    # %pip install git+https://github.com/ion-g-ion/torchtt
    import torchtt as tntt
try:
    import tt_iga
except:
    print('Installing TT-IGA...')
    # %pip install git+https://github.com/ion-g-ion/code-paper-tt-iga
    import tt_iga

tn.set_default_dtype(tn.float64)

# %% [markdown]
# Curves and surfaces parametrizations for the shape

# %%
xc = lambda u,v: u*tn.sqrt(1-v**2/2)
yc = lambda u,v: v*tn.sqrt(1-u**2/2)

line = lambda t,a,b: t*(b-a)+a

def plane_spanner(P1,P2,P3,t1,t2):
    x = (P1[:,0]-P2[:,0])*t1+(P3[:,0]-P2[:,0])*t2+P2[:,0]
    y = (P1[:,1]-P2[:,1])*t1+(P3[:,1]-P2[:,1])*t2+P2[:,1]
    z = (P1[:,2]-P2[:,2])*t1+(P3[:,2]-P2[:,2])*t2+P2[:,2]
    return x,y,z

def curve2(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = -1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,-1,-w2)+tn.logical_and(t>=0.5,t<=1)*(-w2)
    y = 0*(t<=0.75) + (t>0.75) * ( -ry*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( rz*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))

def curve1(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = 1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,1,w2)+tn.logical_and(t>=0.5,t<=1)*(w2)
    y = 0*(t<=0.75) + (t>0.75) * ( -ry*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( rz*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))
 
def curve3(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = -1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,-1,-w2)+tn.logical_and(t>=0.5,t<=1)*(-w2)
    y = h*(t<=0.75) + (t>0.75) * ( -(ry-h)*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( (rz-h)*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))

# %% [markdown]
# Define the B-spline bases and the parameter space bases.
# For the parameter space, Gauss-Legendre nodes are used.

# %%
deg = 2
Ns = np.array([60,60,120])-deg+1
# Ns = np.array([40,40,140])-deg+1
baza1 = tt_iga.bspline.BSplineBasis(np.linspace(0,1,Ns[0]),deg)
baza2 = tt_iga.bspline.BSplineBasis(np.linspace(0,1,Ns[1]),deg)
baza3 = tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.25,Ns[2]//4),np.linspace(0.25,0.5,Ns[2]//4),np.linspace(0.5,0.75,Ns[2]//4),np.linspace(0.75,1,Ns[2]//4-1))),deg)

Basis = [baza1,baza2,baza3]
N = [baza1.N,baza2.N,baza3.N]

# %% [markdown]
# Define the parametrization and create the geometry object.

# %%
scale_mult = 1
xparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[0]
yparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[1]
zparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[2]

# interpolate the geometry parametrization
geom = tt_iga.PatchBSpline.interpolate_geometry([xparam, yparam, zparam], Basis, [])

# %% [markdown]
# Firstly, plot the  geometry for the parameter $\theta_1 = \theta_2 = \theta_3 = 0$.
#
# Secondly, plot the geometries corrrecponding to the edges of the parameter space $[-0.2,0.2] \times [-0.2,0.2] \times [-0.3,0.3]$, i.e. $(\theta_1,\theta_2,\theta_3) \in \{-0.2,0.2\} \times \{-0.2,0.2\} \times \{-0.3,0.3\}$.

# %%
fig = geom.plot_domain([],[(0,1),(0,1),(0.0,1)],surface_color='blue', wireframe = False,alpha=0.1,n=64)
fig.gca().set_xlabel(r'$x_1$', fontsize=14)
fig.gca().set_ylabel(r'$x_2$', fontsize=14)
fig.gca().set_zlabel(r'$x_3$', fontsize=14)
fig.gca().view_init(15, -60)
fig.gca().zaxis.set_rotate_label(False)
fig.gca().set_xticks([-1.5, 0, 1.5])
fig.gca().set_yticks([0,1])
fig.gca().set_zticks([-3,-1.5,0,1.5])
fig.gca().tick_params(axis='both', labelsize=14)
fig.gca().set_box_aspect(aspect = (3,1.5,4.5))

# %% [markdown]
# Construct the stiffness and mass matrix for the entire parameter grid in the TT format.

# %%
tme = datetime.datetime.now() 
Mass_tt = geom.mass_interp(Basis, eps=1e-11)
tme = datetime.datetime.now() -tme
print('Time mass matrix ',tme.total_seconds())

kinv = lambda y: 1/(49 + y[...,6]*((y[...,2]<0.5)*(y[...,2]>0.25)))
kinv = lambda y: 1/(49 - 0.5*((y[...,2]<0.5)*(y[...,2]>0.25)))

tme = datetime.datetime.now() 
Stt = geom.stiffness_interp(Basis, func=None, qtt = False, func_reference = kinv, verb=False)
tme = datetime.datetime.now() -tme
print('Time stiffness matrix ',tme.total_seconds())
# Out:
# Time mass matrix  0.152883
# Time stiffness matrix  14.782704

# %% [markdown]
# Get the boundary/interior projection operators.

# %%
Pin_tt,Pbd_tt = tt_iga.projectors.get_projectors(N,[[0,0],[0,0],[0,0]])
Pbd_tt =  Pbd_tt

Pin_tt = Pin_tt 
Pbd_tt = Pbd_tt

# %% [markdown]
# Compute the excitation on the bottom port in TT format.
# The tensor is extended using Kronecker product since the excitation does not change with the parameters.
# The boundary projectpor is applied to let only the desired dofs nonzero.

# %%
f_tt = tntt.zeros(Stt.N)

excitation_dofs = tt_iga.Function(Basis).interpolate(lambda t: tn.sin(t[:,0]*np.pi)*tn.sin(t[:,1]*np.pi))
tmp = tn.zeros(N)
tmp[:,:,0] = excitation_dofs[:,:,0].full()
g_tt = Pbd_tt@ tntt.TT(tmp)

# %% [markdown]
# Compute the system matrix and include the boundary adaptation.

# %%
knumber = 49

eps_solver = 1e-8
M_tt = (Pin_tt@(Stt-knumber*Mass_tt)+Pbd_tt).round(1e-12)
M_tt = (Pin_tt@(Stt-Mass_tt)+Pbd_tt).round(1e-12)
rhs_tt = (Pbd_tt @ g_tt).round(1e-12)

M_tt = M_tt.round(1e-12)

# %% [markdown]
# Solve the problem (can solve on GPU if one is available) and report ranks, times, memory consumption, etc.

# %%
cuda = False
tme_amen = datetime.datetime.now() 
if cuda and tn.cuda.is_available():
    print('Solving in TT (GPU)...')
    dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp=40, kickrank=2, verbose=True, preconditioner = 'c', local_iterations=24, resets=10).cpu()
else:
    print('Solving in TT (CPU)...')
    dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = eps_solver, nswp=40, kickrank=4, verbose=True, preconditioner = 'c', local_iterations=24, resets=10)
tme_amen = (datetime.datetime.now() -tme_amen).total_seconds() 

print('',flush=True)
print('Time system solve in TT :',tme_amen)
print('Relative residual       :', (M_tt@dofs_tt-rhs_tt).norm()/rhs_tt.norm())
print('N                       :',N)
print('Rank Mtt                :',M_tt.R)
print('Rank rhstt              :',rhs_tt.R)
print('Rank solution           :',dofs_tt.R)
print('size stiff              :',tntt.numel(Stt)*8/1e6,' MB')
print('size mass               :',tntt.numel(Mass_tt)*8/1e6,' MB')
print('size system mat         :',tntt.numel(M_tt)*8/1e6,' MB')
print('size rhstt              :',tntt.numel(rhs_tt)*8/1e6,' MB')
print('size solution           :',tntt.numel(dofs_tt)*8/1e6,' MB, one full solution: ',np.prod(N)*8/1e6,' MB')
# Out:
# Solving in TT (CPU)...
#
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 60)....
# 		dx = 12.6639, res_now = 1.38762e-16, res_old = 50.9947
# 	Core 1
# 		Choosing direct solver (local size 300)....
# 		dx = 0.743388, res_now = 2.47057e-16, res_old = 3.31757
# 	Core 2
# 		Choosing iterative solver GMRES (local size 580)....
# 		Finished with flag 1 after 156 iterations with relres 2.79405e-09 (from 4.08248e-09)
# 		Time needed  0:00:01.758096
# 		dx = 1.25774, res_now = 2.79405e-09, res_old = 0.707107
# Solution rank is [1, 5, 5, 1]
# Maxres  tensor(50.9947)
# Time  0:00:01.829247
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing direct solver (local size 300)....
# 		dx = 0.00865576, res_now = 2.89817e-16, res_old = 7.1027e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 2400)....
# 		Finished with flag 0 after 240 iterations with relres 5.57582e-07 (from 3.1058e-05)
# 		Time needed  0:00:01.508743
# 		dx = 0.0083559, res_now = 5.57582e-07, res_old = 9.2947e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1044)....
# 		Finished with flag 1 after 8 iterations with relres 1.61367e-09 (from 0.00129564)
# 		Time needed  0:00:00.064523
# 		dx = 0.0262264, res_now = 1.61367e-09, res_old = 2.22806e-06
# Solution rank is [1, 8, 9, 1]
# Maxres  tensor(9.2947e-05)
# Time  0:00:01.685334
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing direct solver (local size 480)....
# 		dx = 0.00224711, res_now = 4.11075e-16, res_old = 2.3879e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 6480)....
# 		Finished with flag 0 after 240 iterations with relres 2.86174e-08 (from 0.000425059)
# 		Time needed  0:00:04.123353
# 		dx = 0.000767011, res_now = 2.86174e-08, res_old = 6.79141e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1508)....
# 		Finished with flag 1 after 12 iterations with relres 2.15885e-09 (from 0.00848858)
# 		Time needed  0:00:00.079113
# 		dx = 0.00263634, res_now = 2.15885e-09, res_old = 3.40075e-07
# Solution rank is [1, 12, 13, 1]
# Maxres  tensor(6.7914e-06)
# Time  0:00:04.315194
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 720)....
# 		Finished with flag 0 after 240 iterations with relres 5.25152e-09 (from 0.00930179)
# 		Time needed  0:00:01.113607
# 		dx = 0.000161467, res_now = 5.25152e-09, res_old = 3.10344e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 12480)....
# 		Finished with flag 0 after 240 iterations with relres 3.40282e-09 (from 0.00465712)
# 		Time needed  0:00:06.502086
# 		dx = 2.53758e-05, res_now = 3.40282e-09, res_old = 6.19858e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1972)....
# 		Finished with flag 1 after 6 iterations with relres 2.18602e-09 (from 0.106755)
# 		Time needed  0:00:00.049415
# 		dx = 6.8687e-05, res_now = 2.18602e-09, res_old = 2.70408e-08
# Solution rank is [1, 16, 17, 1]
# Maxres  tensor(6.1986e-07)
# Time  0:00:07.776303
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 960)....
# 		Finished with flag 1 after 24 iterations with relres 2.74622e-09 (from 0.0851876)
# 		Time needed  0:00:00.126203
# 		dx = 1.26096e-05, res_now = 2.74622e-09, res_old = 3.3887e-08
# 	Core 1
# 		Choosing iterative solver GMRES (local size 20400)....
# 		Finished with flag 1 after 17 iterations with relres 2.85808e-09 (from 0.0485048)
# 		Time needed  0:00:00.424344
# 		dx = 2.82055e-06, res_now = 2.85808e-09, res_old = 5.95147e-08
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2436)....
# 		Finished with flag 1 after 0 iterations with relres 2.10355e-09 (from 0.906615)
# 		Time needed  0:00:00.028465
# 		dx = 2.00112e-06, res_now = 2.10355e-09, res_old = 3.1841e-09
# Solution rank is [1, 20, 21, 1]
# Maxres  tensor(5.9515e-08)
# Time  0:00:00.689804
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1200)....
# 		Finished with flag 1 after 5 iterations with relres 2.67542e-09 (from 0.0605429)
# 		Time needed  0:00:00.035012
# 		dx = 9.86202e-07, res_now = 2.67542e-09, res_old = 4.76811e-08
# 	Core 1
# 		Choosing iterative solver GMRES (local size 30240)....
# 		Finished with flag 1 after 8 iterations with relres 2.67699e-09 (from 0.301031)
# 		Time needed  0:00:00.688734
# 		dx = 1.30992e-06, res_now = 2.67699e-09, res_old = 9.58955e-09
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2900)....
# 		Finished with flag 1 after 0 iterations with relres 1.33023e-09 (from 1.56313)
# 		Time needed  0:00:00.045865
# 		dx = 5.83746e-07, res_now = 1.33023e-09, res_old = 1.84678e-09
# Solution rank is [1, 24, 25, 1]
# Maxres  tensor(4.7681e-08)
# Time  0:00:00.932657
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1440)....
# 		Finished with flag 1 after 1 iterations with relres 2.11798e-09 (from 0.964072)
# 		Time needed  0:00:00.015271
# 		dx = 1.08597e-07, res_now = 2.11798e-09, res_old = 2.99433e-09
# 	Core 1
# 		Choosing iterative solver GMRES (local size 42000)....
# 		Finished with flag 1 after 2 iterations with relres 2.60292e-09 (from 0.509147)
# 		Time needed  0:00:00.204988
# 		dx = 3.60138e-07, res_now = 2.60292e-09, res_old = 5.66978e-09
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3364)....
# 		Finished with flag 1 after 0 iterations with relres 1.04259e-09 (from 1.94799)
# 		Time needed  0:00:00.036733
# 		dx = 5.33927e-07, res_now = 1.04259e-09, res_old = 1.48191e-09
# Solution rank is [1, 28, 29, 1]
# Maxres  tensor(5.6698e-09)
# Time  0:00:00.385645
#
# Starting sweep 7 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1680)....
# 		Finished with flag 1 after 0 iterations with relres 2.81714e-09 (from 1.00811)
# 		Time needed  0:00:00.015523
# 		dx = 3.43963e-09, res_now = 2.81714e-09, res_old = 2.86353e-09
# 	Core 1
# 		Choosing iterative solver GMRES (local size 48720)....
# 		Finished with flag 1 after 0 iterations with relres 1.36216e-09 (from 2.07083)
# 		Time needed  0:00:00.183726
# 		dx = 1.3232e-09, res_now = 1.36216e-09, res_old = 1.394e-09
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3364)....
# 		Finished with flag 1 after 0 iterations with relres 8.61597e-10 (from 2.57405)
# 		Time needed  0:00:00.034258
# 		dx = 2.15309e-07, res_now = 8.61597e-10, res_old = 1.12148e-09
# Solution rank is [1, 28, 29, 1]
# Maxres  tensor(2.8635e-09)
# Time  0:00:00.314607
#
# Finished after 7  sweeps and  0:00:17.932637
#
#
# Time system solve in TT : 17.935895
# Relative residual       : tensor(9.9789e-10)
# N                       : [60, 60, 116]
# Rank Mtt                : [1, 6, 10, 1]
# Rank rhstt              : [1, 1, 1, 1]
# Rank solution           : [1, 28, 29, 1]
# size stiff              : 2.66048  MB
# size mass               : 0.301696  MB
# size system mat         : 2.97728  MB
# size rhstt              : 0.001888  MB
# size solution           : 0.430112  MB, one full solution:  3.3408  MB

# %% [markdown]
# Plot the solution in the reference domain for $(y_1,y_2,y_3)\in[0,1]\times\{0.5\}\times[0,1]$ and $\theta_1=\theta_2=\theta_3=0$.

# %%
fspace = tt_iga.Function(Basis)
fspace.dofs = dofs_tt

fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])
y1, y3 = tn.meshgrid(tn.linspace(0,1,128),tn.linspace(0,1,128))

plt.figure()
plt.contourf(y1, y3, fval.numpy().squeeze(), levels = 128)
plt.colorbar()
plt.xlabel(r'$y_1$')
plt.ylabel(r'$y_3$')

fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])

plt.figure()
plt.contourf(y1, y3, fval.numpy().squeeze(), levels = 128, cmap = 'GnBu')
plt.colorbar()
plt.xlabel(r'$y_1$')
plt.ylabel(r'$y_3$')
# Out:
# /home/yonnss/anaconda3/envs/pytorch_cpu/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484746322/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Text(0, 0.5, '$y_3$')

# %% [markdown]
# Plot the domain and the solution in the physical domain for $(y_1,y_2,y_3)\in[0,1]\times\{0.5\}\times[0,1]$ and $\theta_1=\theta_2=\theta_3=0$.

# %%
fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])
x,y,z =  geom([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])

fig = geom.plot_domain([],[(0,1),(0,1),(0.0,1)],surface_color=None, wireframe = False,frame_color='k',n = 64)
geom.plot_domain([],[(0,1),(0,1),(0.25,0.5)],fig=fig,surface_color=None, wireframe = False,frame_color='k',n = 64)
geom.plot_domain([],[(0,1),(0,1),(0.75,1)],fig=fig,surface_color=None, wireframe = False,frame_color='k',n = 64)

ax = fig.gca()
C = fval.numpy().squeeze()
norm = matplotlib.colors.Normalize(vmin=C.min(),vmax=C.max())
C = plt.cm.jet(norm(C))
C[:,:,-1] = 1
ax.plot_surface(x.numpy().squeeze(), y.numpy().squeeze(), z.numpy().squeeze(), edgecolors=None, linewidth=0, facecolors = C, antialiased=True, rcount=256, ccount=256, alpha=0.5)
fig.gca().set_xlabel(r'$x_1$', fontsize=14)
fig.gca().set_ylabel(r'$x_2$', fontsize=14)
fig.gca().set_zlabel(r'$x_3$', fontsize=14)
fig.gca().view_init(15, -60)
fig.gca().zaxis.set_rotate_label(False)
fig.gca().set_xticks([-1.5, 0, 1.5])
fig.gca().set_yticks([0,1])
fig.gca().set_zticks([-3,-1.5,0,1.5])
fig.gca().tick_params(axis='both', labelsize=14)
fig.gca().set_box_aspect(aspect = (3,1.5,4.5))

# %% [markdown]
# Generate some measurements for the inverse problem.

# %%
x1 ,x2 , x3 = geom([tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.75])])
print(x1.numpy().squeeze())
print(x2.numpy().squeeze())
print(x3.numpy().squeeze())
fval = fspace([tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.75])]).numpy().squeeze()
print('field ',fval)
import pickle
with open('wg_measurement.pkl', 'wb') as f:
    pickle.dump({'meas' : fval}, f)
# Out:
# [[-7.50000000e-01 -7.50000000e-01 -7.50000000e-01]
#  [-4.20614623e-17 -4.20614623e-17 -4.20614623e-17]
#  [ 7.50000000e-01  7.50000000e-01  7.50000000e-01]]
# [[0.125 0.25  0.375]
#  [0.125 0.25  0.375]
#  [0.125 0.25  0.375]]
# [[3.36999755e-15 2.92476007e-15 2.47952259e-15]
#  [3.36999755e-15 2.92476007e-15 2.47952259e-15]
#  [3.36999755e-15 2.92476007e-15 2.47952259e-15]]
# field  [[-0.17404061 -0.25863862 -0.19307818]
#  [-0.32112803 -0.47393378 -0.35125058]
#  [-0.17404061 -0.25863862 -0.19307818]]
