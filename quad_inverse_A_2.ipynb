# %%
from webbrowser import get
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
        
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    # Dc = 32e-3
    # hc = 7e-3
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.sin((np.pi-np.abs(alpha2(params)+np.pi*3/4))/2)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc-blc)*(hi+params[...,3])+0.5*(bli+params[...,2])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()
print(surface(np.array([0.0,0.0,0.0,0.0])))

var1 = 0.00075
var2 = 0.00075
var3 = 0.00075
var4 = 0.00075
pts = control_points([0,0,0,0])
plt.figure()
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)
pts = control_points([0,-0.003,0,0])
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)


basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 10
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param, eps = 1e-13)

# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[0].numpy().squeeze())
# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[1].numpy().squeeze())
# 
# print(weights(np.zeros((4))))
# print(control_points(np.zeros((4)))[1,:,:])
# Out:
# 0.0002177263404511999

# %%
plt.figure()

for i in range(20):
    paramz = [tn.tensor([np.random.uniform()*2*var1-var1]),tn.tensor([np.random.uniform()*2*var2-var2]),tn.tensor([np.random.uniform()*2*var3-var3]),tn.tensor([np.random.uniform()*2*var4-var4])]
    line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

    # line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_params.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r')

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
plt.text(0.03*1e3,0.035*1e3,r'$\Gamma_D$')
plt.text(0.014*1e3,0.0008*1e3,r'$\Gamma_N$')
plt.text(0.045*1e3,0.025*1e3,r'iron')
plt.text(0.041*1e3,0.005*1e3,r'Cu')
plt.text(0.015*1e3,0.005*1e3,r'air')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_section.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

pts = control_points([0,0,0,0])

plt.scatter(pts[0,...]*1e3, pts[1,...]*1e3)

plt.plot(pts[0,:,1]*1e3, pts[1,:,1]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,2]*1e3, pts[1,:,2]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,3]*1e3, pts[1,:,3]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,1,:]*1e3, pts[1,1,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,2,:]*1e3, pts[1,2,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,3,:]*1e3, pts[1,3,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,4,:]*1e3, pts[1,4,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,5,:]*1e3, pts[1,5,:]*1e3,'gray',linewidth=0.5)

for i in range(5): 
    for j in range(7): 
        plt.text(pts[0,j,i]*1e3+1,pts[1,j,i]*1e3,'(%d,%d)'%(j+1,i+1), fontsize = 10)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
tikzplotlib.save('quad_points.tex')

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))

tme = datetime.datetime.now()
Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
tme = datetime.datetime.now() - tme
print('Time mass ', tme)
tme = datetime.datetime.now()
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-10, func_reference=mu_ref, qtt = True, verb = True, device = 'cuda:1')
tme = datetime.datetime.now() - tme
print('Time stiffness ', tme)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[1])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4) / Mass_tt.N[0]

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-10)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-10)

print('System matrix... ',flush=True)

print('Rank Stiff', Stiff_tt.R, ' storage [MB] ',tntt.numel(Stiff_tt)*8/1e6)
print('Rank Mass', Mass_tt.R, ' storage [MB] ',tntt.numel(Mass_tt)*8/1e6)
print('Rank Mtt ',M_tt.R, ' storage [MB] ',tntt.numel(M_tt)*8/1e6)
print('Rank rhstt ',rhs_tt.R, ' storage [MB] ',tntt.numel(rhs_tt)*8/1e6)
# Out:
# Time mass  0:00:01.890339
# time omega 0:00:01.754894
# rank omega, [1, 18, 22, 11, 4, 2, 1]
# QTT enabled:
# [240, 236, 10, 10, 10, 10]
#   ||
#   \/
# [2, 2, 2, 2, 3, 5, 2, 2, 59, 2, 5, 2, 5, 2, 5, 2, 5]
# Sweep 1:
# 	LR supercore 1,2
# 		number evaluations 113280
# 		rank updated 2 -> 6, local error 1.000000e+00
# 	LR supercore 2,3
# 		number evaluations 28320
# 		rank updated 2 -> 4, local error 9.697169e-01
# 	LR supercore 3,4
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 1.012501e+00
# 	LR supercore 4,5
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 9.630102e-01
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 2 -> 4, local error 1.134514e+00
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 3.643330e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 1.278699e-15
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 1.048271e-15
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 9.188886e-16
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 3.726654e-15
# Max error 1.13451
# Sweep 2:
# 	LR supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 6.068796e-15
# 	LR supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 6.853035e-15
# 	LR supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 3.958593e-15
# 	LR supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 1.195870e-15
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 1.822073e-15
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 3.258849e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 1.570169e-15
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 3.582623e-15
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 3.569272e-15
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 2.787752e-15
# Max error 6.853035e-15 < 1.000000e-10  ---->  DONE
# number of function calls  1004000
#
# rank of Ftt is  [1, 3, 1, 1, 1, 1, 1]
# alpha, beta =  0 0
# 	time 1  0:00:00.567819
# 	time 2  0:00:05.253764  rank  [1, 4, 16, 48, 112, 336, 276, 436, 678, 99, 218, 87, 178, 77, 100, 10, 10, 1]
# 		time  0:00:00.128024
# 	time 4  0:00:00.128787
# alpha, beta =  0 1
# 	time 1  0:00:00.649381
# 	time 2  0:00:03.970571  rank  [1, 4, 16, 48, 112, 336, 300, 468, 756, 110, 236, 96, 196, 85, 100, 10, 10, 1]
# 		time  0:00:00.130774
# 	time 4  0:00:00.142190
# 	time ROUND  0:00:00.455739
# alpha, beta =  1 0
# 	time 1  0:00:00.558789
# 	time 2  0:00:03.974678  rank  [1, 4, 16, 48, 112, 336, 300, 468, 756, 110, 236, 96, 196, 85, 100, 10, 10, 1]
# 		time  0:00:00.137302
# 	time 4  0:00:00.158607
# alpha, beta =  1 1
# 	time 1  0:00:00.563420
# 	time 2  0:00:03.340084  rank  [1, 4, 16, 48, 112, 336, 264, 412, 696, 99, 212, 86, 176, 77, 100, 10, 10, 1]
# 		time  0:00:00.117259
# 	time 4  0:00:00.128689
# 	time ROUND  0:00:00.610047
# Time stiffness  0:00:26.633642
# System matrix...
# Rank Stiff [1, 92, 86, 61, 26, 7, 1]  storage [MB]  267.891872
# Rank Mass [1, 18, 22, 11, 4, 2, 1]  storage [MB]  13.802752
# Rank Mtt  [1, 90, 83, 59, 26, 7, 1]  storage [MB]  253.02208
# Rank rhstt  [1, 3, 6, 6, 10, 4, 1]  storage [MB]  0.021952

# %%
tme = datetime.datetime.now() 
dev_name = 'cuda:1'
# dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp = 50, kickrank = 4, preconditioner = 'c', verbose = False).cpu()
# dofs_tt = tntt.reshape(tntt.solvers.amen_solve(tntt.reshape(M_tt,[(2,2)]*21).round(1e-12).cuda(), tntt.reshape(rhs_tt,[2]*21).round(1e-12).cuda(), x0 = tntt.reshape(tntt.ones(rhs_tt.N),[2]*21).cuda(), eps = 1e-6, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True),rhs_tt.N).round(1e-12)
# dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = 1e-7, rmax = 400, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True).cpu()
dofs_tt = tntt.solvers.amen_solve(M_tt.to(dev_name), rhs_tt.to(dev_name), x0 = tntt.ones(rhs_tt.N).to(dev_name), rmax = 300, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.solvers.amen_solve(tntt.reshape(M_tt,[(8,8)]*8).round(1e-10).cuda(), tntt.reshape(rhs_tt,[8]*8).round(1e-10).cuda(), x0 = tntt.reshape(dofs_tt,[8]*8).round(1e-8).cuda(), rmax = 600, eps = 1e-7, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.reshape(dofs_tt,M_tt.N)
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 64)....
# 		dx = 399.438, res_now = 1.55734e-13, res_old = 0.999715
# 	Core 1
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.0316407 (from 1.66404e-08)
# 		Time needed  0:00:00.259909
# 		dx = 0.351993, res_now = 0.0316407, res_old = 12.2668
# 	Core 2
# 		Choosing direct solver (local size 90)....
# 		dx = 0.0319305, res_now = 2.14707e-16, res_old = 0.587675
# 	Core 3
# 		Choosing direct solver (local size 90)....
# 		dx = 0.0203651, res_now = 5.33224e-16, res_old = 1.5458
# 	Core 4
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00241328, res_now = 1.82786e-16, res_old = 0.262024
# 	Core 5
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00271188, res_now = 2.69116e-16, res_old = 0.572859
# Solution rank is [1, 9, 9, 9, 9, 9, 1]
# Maxres  tensor(12.2668, device='cuda:1')
# Time  0:00:00.324846
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00128858 (from 2.9425e-08)
# 		Time needed  0:00:00.228993
# 		dx = 0.0680548, res_now = 0.00128858, res_old = 6.93709
# 	Core 1
# 		Choosing iterative solver GMRES (local size 9792)....
# 		Finished with flag 0 after 80 iterations with relres 0.00469172 (from 9.27827e-08)
# 		Time needed  0:00:00.421675
# 		dx = 0.0252798, res_now = 0.00469172, res_old = 2.20002
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 33 iterations with relres 1.66481e-07 (from 4.2353e-06)
# 		Time needed  0:00:00.087176
# 		dx = 0.000513245, res_now = 1.66481e-07, res_old = 0.0481959
# 	Core 3
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 38 iterations with relres 1.52023e-07 (from 1.07462e-05)
# 		Time needed  0:00:00.102256
# 		dx = 0.000336509, res_now = 1.52023e-07, res_old = 0.018995
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 28 iterations with relres 1.2358e-07 (from 4.98642e-05)
# 		Time needed  0:00:00.062674
# 		dx = 5.55284e-05, res_now = 1.2358e-07, res_old = 0.00409361
# 	Core 5
# 		Choosing direct solver (local size 170)....
# 		dx = 1.03874e-09, res_now = 1.58748e-16, res_old = 1.28008e-07
# Solution rank is [1, 17, 17, 17, 17, 17, 1]
# Maxres  tensor(6.9371, device='cuda:1')
# Time  0:00:00.993391
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 0 after 80 iterations with relres 0.000496076 (from 2.05034e-06)
# 		Time needed  0:00:00.231734
# 		dx = 0.00732466, res_now = 0.000496076, res_old = 0.0995563
# 	Core 1
# 		Choosing iterative solver GMRES (local size 27200)....
# 		Finished with flag 0 after 80 iterations with relres 0.0012597 (from 1.76668e-06)
# 		Time needed  0:00:00.764182
# 		dx = 0.00407857, res_now = 0.0012597, res_old = 0.115541
# 	Core 2
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 0 after 80 iterations with relres 3.78931e-07 (from 0.000117702)
# 		Time needed  0:00:00.225326
# 		dx = 0.000337082, res_now = 3.78931e-07, res_old = 0.00173425
# 	Core 3
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 1 after 71 iterations with relres 1.88901e-07 (from 0.000832782)
# 		Time needed  0:00:00.185850
# 		dx = 6.2248e-06, res_now = 1.88901e-07, res_old = 0.000245111
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2500)....
# 		Finished with flag 1 after 3 iterations with relres 2.01473e-07 (from 0.21247)
# 		Time needed  0:00:00.006884
# 		dx = 2.29906e-08, res_now = 2.01473e-07, res_old = 9.60722e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.92213e-08, res_now = 1.55211e-16, res_old = 2.08918e-07
# Solution rank is [1, 25, 25, 25, 25, 18, 1]
# Maxres  tensor(0.1155, device='cuda:1')
# Time  0:00:01.532357
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 0 after 80 iterations with relres 8.77568e-05 (from 3.66914e-05)
# 		Time needed  0:00:00.226084
# 		dx = 0.00109596, res_now = 8.77568e-05, res_old = 0.00556327
# 	Core 1
# 		Choosing iterative solver GMRES (local size 52800)....
# 		Finished with flag 0 after 80 iterations with relres 0.000443637 (from 8.29217e-06)
# 		Time needed  0:00:01.278120
# 		dx = 0.00115188, res_now = 0.000443637, res_old = 0.0246165
# 	Core 2
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 0 after 80 iterations with relres 1.01478e-06 (from 0.000405976)
# 		Time needed  0:00:00.228942
# 		dx = 0.000244594, res_now = 1.01478e-06, res_old = 0.000502799
# 	Core 3
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 1 after 53 iterations with relres 1.99591e-07 (from 0.00801516)
# 		Time needed  0:00:00.134572
# 		dx = 2.68574e-06, res_now = 1.99591e-07, res_old = 2.54673e-05
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3300)....
# 		Finished with flag 1 after 11 iterations with relres 1.96714e-07 (from 0.624703)
# 		Time needed  0:00:00.019063
# 		dx = 3.50605e-07, res_now = 1.96714e-07, res_old = 3.26754e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.05582e-07, res_now = 1.81437e-16, res_old = 2.02897e-07
# Solution rank is [1, 33, 33, 33, 33, 18, 1]
# Maxres  tensor(0.0246, device='cuda:1')
# Time  0:00:02.021577
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 0 after 80 iterations with relres 6.10154e-05 (from 9.96674e-05)
# 		Time needed  0:00:00.228631
# 		dx = 0.000252842, res_now = 6.10154e-05, res_old = 0.00204805
# 	Core 1
# 		Choosing iterative solver GMRES (local size 86592)....
# 		Finished with flag 0 after 80 iterations with relres 0.00016623 (from 3.07278e-05)
# 		Time needed  0:00:01.996249
# 		dx = 0.000371932, res_now = 0.00016623, res_old = 0.00664298
# 	Core 2
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 0 after 80 iterations with relres 1.77771e-06 (from 0.00110242)
# 		Time needed  0:00:00.234423
# 		dx = 0.000124844, res_now = 1.77771e-06, res_old = 0.00018516
# 	Core 3
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 1 after 80 iterations with relres 2.01626e-07 (from 0.0570488)
# 		Time needed  0:00:00.222362
# 		dx = 7.9588e-06, res_now = 2.01626e-07, res_old = 3.57807e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4100)....
# 		Finished with flag 1 after 2 iterations with relres 2.01519e-07 (from 0.847296)
# 		Time needed  0:00:00.006016
# 		dx = 1.41892e-08, res_now = 2.01519e-07, res_old = 2.40912e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.62606e-08, res_now = 1.91923e-16, res_old = 2.1031e-07
# Solution rank is [1, 41, 41, 41, 41, 18, 1]
# Maxres  tensor(0.0066, device='cuda:1')
# Time  0:00:02.853192
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 0 after 80 iterations with relres 1.71028e-05 (from 0.000368148)
# 		Time needed  0:00:00.228694
# 		dx = 0.000118437, res_now = 1.71028e-05, res_old = 0.000554463
# 	Core 1
# 		Choosing iterative solver GMRES (local size 128576)....
# 		Finished with flag 0 after 80 iterations with relres 6.70184e-05 (from 0.000126534)
# 		Time needed  0:00:02.792312
# 		dx = 0.000116852, res_now = 6.70184e-05, res_old = 0.00161319
# 	Core 2
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 0 after 80 iterations with relres 1.20075e-06 (from 0.00287607)
# 		Time needed  0:00:00.237270
# 		dx = 6.02202e-05, res_now = 1.20075e-06, res_old = 7.09734e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 1 after 36 iterations with relres 1.9934e-07 (from 0.137696)
# 		Time needed  0:00:00.098428
# 		dx = 9.69321e-07, res_now = 1.9934e-07, res_old = 1.48242e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4900)....
# 		Finished with flag 1 after 1 iterations with relres 1.98728e-07 (from 0.979879)
# 		Time needed  0:00:00.004882
# 		dx = 4.51826e-09, res_now = 1.98728e-07, res_old = 2.08316e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.85241e-08, res_now = 1.27499e-16, res_old = 2.09138e-07
# Solution rank is [1, 49, 49, 49, 49, 18, 1]
# Maxres  tensor(0.0016, device='cuda:1')
# Time  0:00:03.559627
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 0 after 80 iterations with relres 6.41682e-06 (from 0.000816995)
# 		Time needed  0:00:00.228063
# 		dx = 3.81224e-05, res_now = 6.41682e-06, res_old = 0.000249847
# 	Core 1
# 		Choosing iterative solver GMRES (local size 178752)....
# 		Finished with flag 0 after 80 iterations with relres 3.29265e-05 (from 0.000269824)
# 		Time needed  0:00:03.884990
# 		dx = 4.42333e-05, res_now = 3.29265e-05, res_old = 0.000756508
# 	Core 2
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 0 after 80 iterations with relres 6.4603e-07 (from 0.00595454)
# 		Time needed  0:00:00.244100
# 		dx = 1.2357e-05, res_now = 6.4603e-07, res_old = 3.42804e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 1 after 58 iterations with relres 1.97248e-07 (from 0.277652)
# 		Time needed  0:00:00.149048
# 		dx = 2.37388e-06, res_now = 1.97248e-07, res_old = 7.35179e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 5700)....
# 		Finished with flag 1 after 0 iterations with relres 2.01657e-07 (from 0.996443)
# 		Time needed  0:00:00.004093
# 		dx = 2.01685e-09, res_now = 2.01657e-07, res_old = 2.04853e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.49624e-08, res_now = 1.52122e-16, res_old = 2.11717e-07
# Solution rank is [1, 57, 57, 57, 57, 18, 1]
# Maxres  tensor(0.0008, device='cuda:1')
# Time  0:00:04.745761
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 0 after 80 iterations with relres 2.41507e-06 (from 0.00217659)
# 		Time needed  0:00:00.232941
# 		dx = 1.26773e-05, res_now = 2.41507e-06, res_old = 9.37815e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 233472)....
# 		Finished with flag 0 after 80 iterations with relres 1.89346e-05 (from 0.000722611)
# 		Time needed  0:00:04.937315
# 		dx = 1.83713e-05, res_now = 1.89346e-05, res_old = 0.000282481
# 	Core 2
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 0 after 80 iterations with relres 3.75941e-07 (from 0.010426)
# 		Time needed  0:00:00.265979
# 		dx = 6.00418e-06, res_now = 3.75941e-07, res_old = 1.95784e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 1 after 29 iterations with relres 2.02417e-07 (from 0.512298)
# 		Time needed  0:00:00.073095
# 		dx = 5.74628e-07, res_now = 2.02417e-07, res_old = 3.98448e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 6500)....
# 		Finished with flag 1 after 1 iterations with relres 2.01414e-07 (from 0.971477)
# 		Time needed  0:00:00.005095
# 		dx = 8.16042e-09, res_now = 2.01414e-07, res_old = 2.10117e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.43732e-08, res_now = 1.75902e-16, res_old = 2.12696e-07
# Solution rank is [1, 64, 65, 65, 65, 18, 1]
# Maxres  tensor(0.0003, device='cuda:1')
# Time  0:00:05.793539
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 1.35646e-06 (from 0.00314884)
# 		Time needed  0:00:00.226279
# 		dx = 6.35272e-06, res_now = 1.35646e-06, res_old = 6.48252e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 266240)....
# 		Finished with flag 0 after 80 iterations with relres 1.13753e-05 (from 0.00123843)
# 		Time needed  0:00:05.639770
# 		dx = 1.0164e-05, res_now = 1.13753e-05, res_old = 0.000164825
# 	Core 2
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 0 after 80 iterations with relres 3.66234e-07 (from 0.017423)
# 		Time needed  0:00:00.282191
# 		dx = 3.22134e-06, res_now = 3.66234e-07, res_old = 1.17158e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 1 after 23 iterations with relres 1.97345e-07 (from 0.454681)
# 		Time needed  0:00:00.056733
# 		dx = 2.08531e-07, res_now = 1.97345e-07, res_old = 4.48939e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 7300)....
# 		Finished with flag 1 after 0 iterations with relres 1.9729e-07 (from 0.999981)
# 		Time needed  0:00:00.003922
# 		dx = 2.31898e-09, res_now = 1.9729e-07, res_old = 2.04128e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.01741e-07, res_now = 1.95979e-16, res_old = 2.08638e-07
# Solution rank is [1, 64, 73, 73, 73, 18, 1]
# Maxres  tensor(0.0002, device='cuda:1')
# Time  0:00:06.523478
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 8.16279e-07 (from 0.00484049)
# 		Time needed  0:00:00.226253
# 		dx = 3.25913e-06, res_now = 8.16279e-07, res_old = 4.21701e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 299008)....
# 		Finished with flag 0 after 80 iterations with relres 7.00646e-06 (from 0.00212993)
# 		Time needed  0:00:06.319646
# 		dx = 5.7215e-06, res_now = 7.00646e-06, res_old = 9.58363e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 0 after 80 iterations with relres 3.29279e-07 (from 0.0283412)
# 		Time needed  0:00:00.319335
# 		dx = 2.04617e-06, res_now = 3.29279e-07, res_old = 7.20239e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 1 after 21 iterations with relres 2.00051e-07 (from 0.395574)
# 		Time needed  0:00:00.055070
# 		dx = 8.58629e-08, res_now = 2.00051e-07, res_old = 5.1602e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8100)....
# 		Finished with flag 1 after 0 iterations with relres 2.01398e-07 (from 0.987187)
# 		Time needed  0:00:00.003903
# 		dx = 1.31008e-09, res_now = 2.01398e-07, res_old = 2.06774e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.83191e-08, res_now = 1.47314e-16, res_old = 2.14509e-07
# Solution rank is [1, 64, 81, 81, 81, 18, 1]
# Maxres  tensor(9.5836e-05, device='cuda:1')
# Time  0:00:07.264093
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 3.67771e-07 (from 0.00737626)
# 		Time needed  0:00:00.226058
# 		dx = 2.07784e-06, res_now = 3.67771e-07, res_old = 2.76731e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 331776)....
# 		Finished with flag 0 after 80 iterations with relres 4.57319e-06 (from 0.00382754)
# 		Time needed  0:00:06.974925
# 		dx = 3.21716e-06, res_now = 4.57319e-06, res_old = 5.33304e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 0 after 80 iterations with relres 2.24683e-07 (from 0.0433142)
# 		Time needed  0:00:00.372935
# 		dx = 1.21864e-06, res_now = 2.24683e-07, res_old = 4.71264e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 1 after 4 iterations with relres 1.94692e-07 (from 0.608674)
# 		Time needed  0:00:00.020724
# 		dx = 3.69503e-09, res_now = 1.94692e-07, res_old = 3.35359e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8900)....
# 		Finished with flag 1 after 0 iterations with relres 1.8952e-07 (from 1.01844)
# 		Time needed  0:00:00.004074
# 		dx = 1.19946e-09, res_now = 1.8952e-07, res_old = 2.00428e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.86946e-08, res_now = 1.37631e-16, res_old = 2.00462e-07
# Solution rank is [1, 64, 89, 89, 89, 18, 1]
# Maxres  tensor(5.3330e-05, device='cuda:1')
# Time  0:00:07.965893
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.28934e-07 (from 0.0119273)
# 		Time needed  0:00:00.227141
# 		dx = 1.04585e-06, res_now = 2.28934e-07, res_old = 1.7114e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 364544)....
# 		Finished with flag 0 after 80 iterations with relres 3.1992e-06 (from 0.00613121)
# 		Time needed  0:00:07.659529
# 		dx = 2.04445e-06, res_now = 3.1992e-06, res_old = 3.32926e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 1 after 80 iterations with relres 1.96828e-07 (from 0.0622463)
# 		Time needed  0:00:00.434277
# 		dx = 9.03464e-07, res_now = 1.96828e-07, res_old = 3.2793e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 1 after 0 iterations with relres 1.9628e-07 (from 0.878175)
# 		Time needed  0:00:00.014829
# 		dx = 1.65085e-10, res_now = 1.9628e-07, res_old = 2.32441e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 9700)....
# 		Finished with flag 1 after 0 iterations with relres 1.85406e-07 (from 1.00637)
# 		Time needed  0:00:00.004391
# 		dx = 1.32829e-09, res_now = 1.85406e-07, res_old = 2.02833e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.04639e-08, res_now = 1.83219e-16, res_old = 1.97142e-07
# Solution rank is [1, 64, 97, 97, 97, 18, 1]
# Maxres  tensor(3.3293e-05, device='cuda:1')
# Time  0:00:08.731046
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 63 iterations with relres 2.02535e-07 (from 0.0179177)
# 		Time needed  0:00:00.165485
# 		dx = 7.93438e-07, res_now = 2.02535e-07, res_old = 1.13923e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 397312)....
# 		Finished with flag 0 after 80 iterations with relres 2.39194e-06 (from 0.0099341)
# 		Time needed  0:00:08.304001
# 		dx = 9.74927e-07, res_now = 2.39194e-06, res_old = 2.05478e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 1 after 77 iterations with relres 2.01356e-07 (from 0.0831706)
# 		Time needed  0:00:00.485556
# 		dx = 6.21214e-07, res_now = 2.01356e-07, res_old = 2.45428e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 1 after 0 iterations with relres 1.97552e-07 (from 0.964742)
# 		Time needed  0:00:00.017455
# 		dx = 1.59667e-10, res_now = 1.97552e-07, res_old = 2.11584e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10500)....
# 		Finished with flag 1 after 0 iterations with relres 1.85526e-07 (from 0.997645)
# 		Time needed  0:00:00.004523
# 		dx = 1.24815e-09, res_now = 1.85526e-07, res_old = 2.04606e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.32415e-08, res_now = 1.60805e-16, res_old = 1.98181e-07
# Solution rank is [1, 64, 105, 105, 105, 18, 1]
# Maxres  tensor(2.0548e-05, device='cuda:1')
# Time  0:00:09.396774
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 47 iterations with relres 2.02751e-07 (from 0.0235405)
# 		Time needed  0:00:00.127762
# 		dx = 5.15689e-07, res_now = 2.02751e-07, res_old = 8.67119e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 430080)....
# 		Finished with flag 0 after 80 iterations with relres 2.12632e-06 (from 0.0136265)
# 		Time needed  0:00:08.982505
# 		dx = 2.96168e-07, res_now = 2.12632e-06, res_old = 1.498e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 118650)....
# 		Finished with flag 1 after 76 iterations with relres 2.01346e-07 (from 0.0930556)
# 		Time needed  0:00:00.546583
# 		dx = 4.10269e-07, res_now = 2.01346e-07, res_old = 2.19357e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 113000)....
# 		Finished with flag 1 after 0 iterations with relres 2.00042e-07 (from 0.943165)
# 		Time needed  0:00:00.018958
# 		dx = 1.17403e-10, res_now = 2.00042e-07, res_old = 2.16425e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.91838e-07 (from 0.986253)
# 		Time needed  0:00:00.004194
# 		dx = 1.1128e-09, res_now = 1.91838e-07, res_old = 2.06969e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.7333e-08, res_now = 1.79719e-16, res_old = 2.04731e-07
# Solution rank is [1, 64, 113, 113, 108, 18, 1]
# Maxres  tensor(1.4980e-05, device='cuda:1')
# Time  0:00:10.124168
#
# Starting sweep 14 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 36 iterations with relres 2.01187e-07 (from 0.028362)
# 		Time needed  0:00:00.098737
# 		dx = 3.1815e-07, res_now = 2.01187e-07, res_old = 7.1971e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 462848)....
# 		Finished with flag 0 after 80 iterations with relres 1.70148e-06 (from 0.0161751)
# 		Time needed  0:00:09.640786
# 		dx = 7.09118e-07, res_now = 1.70148e-06, res_old = 1.26196e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 136730)....
# 		Finished with flag 1 after 78 iterations with relres 2.01499e-07 (from 0.116548)
# 		Time needed  0:00:00.626155
# 		dx = 3.67606e-07, res_now = 2.01499e-07, res_old = 1.75141e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 121000)....
# 		Finished with flag 1 after 0 iterations with relres 2.01297e-07 (from 0.943217)
# 		Time needed  0:00:00.020280
# 		dx = 1.12636e-10, res_now = 2.01297e-07, res_old = 2.16413e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.95552e-07 (from 0.974179)
# 		Time needed  0:00:00.004155
# 		dx = 1.54373e-09, res_now = 1.95552e-07, res_old = 2.09535e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.63511e-08, res_now = 1.41981e-16, res_old = 2.08633e-07
# Solution rank is [1, 64, 121, 121, 108, 18, 1]
# Maxres  tensor(1.2620e-05, device='cuda:1')
# Time  0:00:10.862380
#
# Starting sweep 15 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 40 iterations with relres 1.97769e-07 (from 0.0274092)
# 		Time needed  0:00:00.115374
# 		dx = 3.46236e-07, res_now = 1.97769e-07, res_old = 7.4473e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 495616)....
# 		Finished with flag 0 after 80 iterations with relres 1.1703e-06 (from 0.0176239)
# 		Time needed  0:00:10.309029
# 		dx = 7.23997e-07, res_now = 1.1703e-06, res_old = 1.15822e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 156090)....
# 		Finished with flag 1 after 49 iterations with relres 2.03972e-07 (from 0.170538)
# 		Time needed  0:00:00.464610
# 		dx = 1.43754e-07, res_now = 2.03972e-07, res_old = 1.19694e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 129000)....
# 		Finished with flag 1 after 0 iterations with relres 2.03154e-07 (from 0.959953)
# 		Time needed  0:00:00.021625
# 		dx = 1.25922e-10, res_now = 2.03154e-07, res_old = 2.1264e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 2.00215e-07 (from 0.966619)
# 		Time needed  0:00:00.004420
# 		dx = 8.37261e-10, res_now = 2.00215e-07, res_old = 2.11173e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.65586e-08, res_now = 1.58561e-16, res_old = 2.13607e-07
# Solution rank is [1, 64, 129, 129, 108, 18, 1]
# Maxres  tensor(1.1582e-05, device='cuda:1')
# Time  0:00:11.416836
#
# Starting sweep 16 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 21 iterations with relres 1.98767e-07 (from 0.0492197)
# 		Time needed  0:00:00.049511
# 		dx = 1.657e-07, res_now = 1.98767e-07, res_old = 4.14721e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 528384)....
# 		Finished with flag 0 after 80 iterations with relres 2.07857e-06 (from 0.0299534)
# 		Time needed  0:00:11.092412
# 		dx = 5.38022e-08, res_now = 2.07857e-06, res_old = 6.81473e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 176730)....
# 		Finished with flag 1 after 65 iterations with relres 2.02471e-07 (from 0.100632)
# 		Time needed  0:00:00.691583
# 		dx = 1.78347e-07, res_now = 2.02471e-07, res_old = 2.02842e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 137000)....
# 		Finished with flag 1 after 0 iterations with relres 2.00743e-07 (from 0.970336)
# 		Time needed  0:00:00.023105
# 		dx = 9.93835e-11, res_now = 2.00743e-07, res_old = 2.10364e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.91597e-07 (from 0.97865)
# 		Time needed  0:00:00.004087
# 		dx = 1.022e-09, res_now = 1.91597e-07, res_old = 2.08577e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.41258e-08, res_now = 1.84261e-16, res_old = 2.04019e-07
# Solution rank is [1, 64, 137, 137, 108, 18, 1]
# Maxres  tensor(6.8147e-06, device='cuda:1')
# Time  0:00:12.393251
#
# Starting sweep 17 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 30 iterations with relres 1.94297e-07 (from 0.0424539)
# 		Time needed  0:00:00.077795
# 		dx = 1.86182e-07, res_now = 1.94297e-07, res_old = 4.80813e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 561152)....
# 		Finished with flag 0 after 80 iterations with relres 6.99923e-07 (from 0.0192275)
# 		Time needed  0:00:11.764179
# 		dx = 5.0049e-07, res_now = 6.99923e-07, res_old = 1.06162e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 198650)....
# 		Finished with flag 1 after 61 iterations with relres 2.0306e-07 (from 0.281302)
# 		Time needed  0:00:00.726476
# 		dx = 1.71123e-07, res_now = 2.0306e-07, res_old = 7.2564e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 145000)....
# 		Finished with flag 1 after 0 iterations with relres 2.02767e-07 (from 0.966297)
# 		Time needed  0:00:00.024413
# 		dx = 8.88786e-11, res_now = 2.02767e-07, res_old = 2.11244e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.88002e-07 (from 0.965369)
# 		Time needed  0:00:00.004182
# 		dx = 1.71503e-09, res_now = 1.88002e-07, res_old = 2.11447e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.64497e-08, res_now = 1.62928e-16, res_old = 2.00539e-07
# Solution rank is [1, 64, 145, 145, 108, 18, 1]
# Maxres  tensor(1.0616e-05, device='cuda:1')
# Time  0:00:13.157528
#
# Starting sweep 18 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 14 iterations with relres 1.92076e-07 (from 0.0838266)
# 		Time needed  0:00:00.030634
# 		dx = 7.90376e-08, res_now = 1.92076e-07, res_old = 2.43508e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 593920)....
# 		Finished with flag 0 after 80 iterations with relres 4.50124e-07 (from 0.048369)
# 		Time needed  0:00:12.442728
# 		dx = 3.53374e-07, res_now = 4.50124e-07, res_old = 4.22014e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 221850)....
# 		Finished with flag 1 after 18 iterations with relres 2.01973e-07 (from 0.428728)
# 		Time needed  0:00:00.269100
# 		dx = 2.54911e-08, res_now = 2.01973e-07, res_old = 4.76116e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 153000)....
# 		Finished with flag 1 after 0 iterations with relres 2.01233e-07 (from 0.983107)
# 		Time needed  0:00:00.025838
# 		dx = 9.25846e-11, res_now = 2.01233e-07, res_old = 2.07632e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.90357e-07 (from 0.971488)
# 		Time needed  0:00:00.004727
# 		dx = 9.71587e-10, res_now = 1.90357e-07, res_old = 2.10115e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 2.27758e-08, res_now = 2.2631e-16, res_old = 2.03909e-07
# Solution rank is [1, 64, 153, 153, 108, 18, 1]
# Maxres  tensor(4.2201e-06, device='cuda:1')
# Time  0:00:13.362863
#
# Starting sweep 19 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 7 iterations with relres 1.73287e-07 (from 0.186276)
# 		Time needed  0:00:00.018105
# 		dx = 4.88038e-08, res_now = 1.73287e-07, res_old = 1.09582e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 626688)....
# 		Finished with flag 0 after 80 iterations with relres 3.20524e-07 (from 0.101467)
# 		Time needed  0:00:13.117796
# 		dx = 3.28446e-07, res_now = 3.20524e-07, res_old = 2.01172e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 246330)....
# 		Finished with flag 1 after 4 iterations with relres 1.92444e-07 (from 0.588808)
# 		Time needed  0:00:00.120844
# 		dx = 2.02827e-09, res_now = 1.92444e-07, res_old = 3.46674e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 161000)....
# 		Finished with flag 1 after 0 iterations with relres 1.84405e-07 (from 1.04544)
# 		Time needed  0:00:00.026678
# 		dx = 1.1267e-10, res_now = 1.84405e-07, res_old = 1.95252e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.74066e-07 (from 1.0618)
# 		Time needed  0:00:00.004192
# 		dx = 6.66024e-10, res_now = 1.74066e-07, res_old = 1.92243e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 2.1268e-08, res_now = 1.6845e-16, res_old = 1.86496e-07
# Solution rank is [1, 64, 161, 161, 108, 18, 1]
# Maxres  tensor(2.0117e-06, device='cuda:1')
# Time  0:00:13.904944
#
# Starting sweep 20 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 2 iterations with relres 2.01391e-07 (from 0.472398)
# 		Time needed  0:00:00.011169
# 		dx = 3.73978e-08, res_now = 2.01391e-07, res_old = 4.32102e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 659456)....
# 		Finished with flag 0 after 80 iterations with relres 2.30368e-07 (from 0.173329)
# 		Time needed  0:00:13.792081
# 		dx = 2.45483e-07, res_now = 2.30368e-07, res_old = 1.17767e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 272090)....
# 		Finished with flag 1 after 2 iterations with relres 1.90197e-07 (from 0.843296)
# 		Time needed  0:00:00.108415
# 		dx = 7.26799e-10, res_now = 1.90197e-07, res_old = 2.42055e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 169000)....
# 		Finished with flag 1 after 0 iterations with relres 1.80974e-07 (from 1.06692)
# 		Time needed  0:00:00.029146
# 		dx = 9.03456e-11, res_now = 1.80974e-07, res_old = 1.91321e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.73795e-07 (from 1.07913)
# 		Time needed  0:00:00.004637
# 		dx = 3.70776e-10, res_now = 1.73795e-07, res_old = 1.89156e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.78702e-08, res_now = 2.09789e-16, res_old = 1.86073e-07
# Solution rank is [1, 64, 169, 169, 108, 18, 1]
# Maxres  tensor(1.1777e-06, device='cuda:1')
# Time  0:00:14.593100
#
# Starting sweep 21 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.85913e-07 (from 0.777465)
# 		Time needed  0:00:00.009281
# 		dx = 4.37505e-09, res_now = 1.85913e-07, res_old = 2.62551e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 692224)....
# 		Finished with flag 1 after 24 iterations with relres 2.041e-07 (from 0.279881)
# 		Time needed  0:00:04.797124
# 		dx = 1.94823e-08, res_now = 2.041e-07, res_old = 7.29324e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 299130)....
# 		Finished with flag 1 after 0 iterations with relres 2.00946e-07 (from 0.969749)
# 		Time needed  0:00:00.088926
# 		dx = 1.38833e-10, res_now = 2.00946e-07, res_old = 2.10492e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 177000)....
# 		Finished with flag 1 after 0 iterations with relres 1.89049e-07 (from 1.00177)
# 		Time needed  0:00:00.030181
# 		dx = 1.40329e-10, res_now = 1.89049e-07, res_old = 2.03764e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.63106e-07 (from 1.03803)
# 		Time needed  0:00:00.004545
# 		dx = 7.93016e-10, res_now = 1.63106e-07, res_old = 1.96646e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 9.07689e-09, res_now = 1.26988e-16, res_old = 1.7501e-07
# Solution rank is [1, 64, 177, 177, 108, 18, 1]
# Maxres  tensor(7.2932e-07, device='cuda:1')
# Time  0:00:05.605468
#
# Starting sweep 22 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.60129e-07 (from 0.983943)
# 		Time needed  0:00:00.005097
# 		dx = 3.70879e-09, res_now = 1.60129e-07, res_old = 2.07455e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 724992)....
# 		Finished with flag 1 after 4 iterations with relres 2.04112e-07 (from 0.219819)
# 		Time needed  0:00:01.573033
# 		dx = 6.85651e-09, res_now = 2.04112e-07, res_old = 9.28599e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 313290)....
# 		Finished with flag 1 after 0 iterations with relres 1.46741e-07 (from 1.33186)
# 		Time needed  0:00:00.087337
# 		dx = 8.75123e-11, res_now = 1.46741e-07, res_old = 1.53262e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 177000)....
# 		Finished with flag 1 after 0 iterations with relres 1.11844e-07 (from 1.75573)
# 		Time needed  0:00:00.029805
# 		dx = 6.71564e-11, res_now = 1.11844e-07, res_old = 1.16262e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10000)....
# 		Finished with flag 1 after 0 iterations with relres 5.32077e-08 (from 3.8006)
# 		Time needed  0:00:00.004222
# 		dx = 6.81015e-11, res_now = 5.32077e-08, res_old = 5.37083e-08
# 	Core 5
# 		Choosing direct solver (local size 100)....
# 		dx = 5.95327e-09, res_now = 1.33127e-16, res_old = 7.45195e-09
# Solution rank is [1, 64, 177, 177, 100, 10, 1]
# Maxres  tensor(9.2860e-07, device='cuda:1')
# Time  0:00:02.320214
#
# Finished after 22  sweeps and  0:02:49.455942
#
# Time system solve  0:02:49.575620

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt.round(1e-10)

plt.figure()
y1, y2 = basis_solution[0].collocation_points(3)[0], basis_solution[1].collocation_points(3)[0]
w1, w2 = basis_solution[0].collocation_points(3)[1], basis_solution[1].collocation_points(3)[1]
ws = np.einsum('i,j->ij',w1,w2)
X1,X2 = geom([y1,y2]+[tn.tensor([0.0])]*4)
u = fspace([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
plt.contourf(X1.numpy().squeeze(), X2.numpy().squeeze(),u.numpy().squeeze(),levels=32)
plt.colorbar()

import pickle
dct = {'x1' : X1.numpy().squeeze(), 'x2' : X2.numpy().squeeze(), 'u' : u.numpy().squeeze(), 'ws' : ws}

    
u = fspace([tn.tensor([0.05]),tn.tensor([0.0]), tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10), tn.linspace(-0.001,0.001,10)])

def get_in_reference(x, param1):
    return 0.4*x/(3.27640e-2+param1)
    # return 0.1*x/(geom([tn.tensor([0.1]),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([param1]), tn.tensor([0.0])])[0].numpy().squeeze())

# %%
# y1, y2 = np.linspace(0,1,32), np.linspace(0.,1,32)
# 
# grad1, grad2 = geom.gradient_physical(basis_solution, fspace)
# 
# g2 = -grad1([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# g1 = grad2([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# x1,x2 = geom([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
# 
# plt.figure()
# plt.quiver(x1.numpy().flatten(),x2.numpy().flatten(),g1.numpy().flatten(),g2.numpy().flatten(),np.sqrt(g1.numpy().flatten()**2+g2.numpy().flatten()**2))
# plt.colorbar()
# 
# x1B, x2B = geom([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0])])
# 
# dct['x1B'] = x1B.numpy().squeeze()
# dct['x2B'] = x2B.numpy().squeeze()
# 
# g2 = -grad1([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# g1 = grad2([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# 
# dct['B1'] = g1
# dct['B2'] = g2
# 
# with open('quad_nominal.pkl','wb') as f:
#     pickle.dump(dct, f)

# %%
import pickle
with open(r"measurements2.pkl", "rb") as input_file:
    data = pickle.load(input_file)
x_positions = tn.tensor(data['x_positions'])

np.random.seed(1234)

print(x_positions)
print(data['A'])
A_noise = data['A'] + np.random.normal(0,1e-6*5,size = data['A'].shape)
print(A_noise)

print(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten())
print('err',np.abs(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten() - data['A'])/np.max(np.abs(data['A'])) )
# Out:
# tensor([0.0000, 0.0020, 0.0040, 0.0060, 0.0080, 0.0100, 0.0120, 0.0140, 0.0160])
# [-8.86502117e-15  1.35307862e-05  5.41231869e-05  1.21777168e-04
#   2.16492447e-04  3.38266789e-04  4.87088973e-04  6.62917265e-04
#   8.65626845e-04]
# [2.35717581e-06 7.57590773e-06 6.12867217e-05 1.20213909e-04
#  2.12889503e-04 3.42702604e-04 4.91386915e-04 6.59734647e-04
#  8.65705326e-04]
# [1.95588844e-12 1.35307095e-05 5.41231224e-05 1.21777077e-04
#  2.16492319e-04 3.38266696e-04 4.87088826e-04 6.62916281e-04
#  8.65624074e-04]
# err [2.26974645e-09 8.85681357e-08 7.44780626e-08 1.05951341e-07
#  1.48097648e-07 1.08011440e-07 1.70166108e-07 1.13603859e-06
#  3.20053194e-06]

# %%
sigma_noise = 1e-6*5

fspace_mod = fspace[:,0,:,:,:,:]
fspace_mod.dofs = fspace_mod.dofs.round(1e-11)

def likelihood_handle(params):

    s = tn.zeros((params.shape[0],))

    for k in range(len(x_positions)):
        argz = tn.hstack((tn.reshape(get_in_reference(x_positions[k],params[:,1]),[-1,1]), params))
        A = fspace_mod(argz)

        s = s + (A - A_noise[k])**2
    return tn.exp(-0.5/sigma_noise**2 * s)/(2*np.pi*sigma_noise)**2
        




def prior_handle(params):
    # return tn.ones((params.shape[0],))
    alpha = 5
    beta = 5
    scale = lambda p,v: (p+v)/2/v
    p1 = scale(params[:,0], var1)**(alpha-1)*(1-scale(params[:,0], var1))**(beta-1)
    p2 = scale(params[:,1], var2)**(alpha-1)*(1-scale(params[:,1], var2))**(beta-1)
    p3 = scale(params[:,2], var3)**(alpha-1)*(1-scale(params[:,2], var3))**(beta-1)
    p4 = scale(params[:,3], var4)**(alpha-1)*(1-scale(params[:,3], var4))**(beta-1)
    return p1*p2*p3*p4
    #return tn.exp(-1/(2*var*var)*(params[:,0]**2+params[:,1]**2+params[:,2]**2+params[:,3]**2))

def posterior_handle(params):
    print(params.shape)
    return prior_handle(params)* likelihood_handle(params)#+1e-101*(params[...,0]+params[...,1]+params[...,2]+params[...,3])
    # return tn.tensor(list(map((post), list(params))))

# %%
import TTCME

basis = [TTCME.basis.BSplineBasis(50,[-var1,var1],2), TTCME.basis.BSplineBasis(25,[-var2,var2],2), TTCME.basis.BSplineBasis(25,[-var3,var3],2), TTCME.basis.BSplineBasis(25,[-var4,var4],2)]
xs = tntt.meshgrid([tn.tensor(b.interpolation_pts[0]) for b in basis])
Ms = tntt.rank1TT([tn.linalg.inv(tn.tensor(b.interpolation_pts[1]).t()) for b in basis])

#paramz = tn.hstack(( tn.reshape(xs[0].full(),[-1,1]) , tn.reshape(xs[1].full(),[-1,1]) , tn.reshape(xs[2].full(),[-1,1]) , tn.reshape(xs[3].full(),[-1,1]) ))

vals = tn.reshape(posterior_handle(paramz), [b.dim for b in basis])

posterior_pdf = TTCME.pdfTT(basis, variable_names= ['theta1', 'theta2', 'theta3', 'theta4'], dofs = Ms @ tntt.TT(vals,eps = 1e-12))
#posterior_pdf = TTCME.pdfTT.interpoalte(posterior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
print(posterior_pdf)
# 
prior_pdf = TTCME.pdfTT.interpoalte(prior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
# Out:
# torch.Size([781250, 4])
# Probability density function:
# p(theta1,theta2,theta3,theta4)
#
# Basis:
# B-spline basis defined on [-0.00075, 0.00075] and dimension 50
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
#
# DoF:
# TT with sizes and ranks:
# N = [50, 25, 25, 25]
# R = [1, 10, 28, 9, 1]
#
# Device: cpu, dtype: torch.float64
# #entries 14025 compression 0.017952

# %%
posterior_pdf.normalize()

E = posterior_pdf.expected_value()
C = posterior_pdf.covariance_matrix()
V = np.diag(C)

print()
print('Exact parameters:                 ',[0,0,0,0])
print('')
print('Expected value computed posterior ' ,E)
print('Coariance computed posterior      ' ,C)

E = prior_pdf.expected_value()
C = prior_pdf.covariance_matrix()
V = np.diag(C)

print('')
print('Expected value prior              ' ,E)
print('Variance prior                    ' ,V)
# Out:
# Exact parameters:                  [0, 0, 0, 0]
#
# Expected value computed posterior  [tensor(-5.2097e-06), tensor(-1.1710e-06), tensor(-5.2263e-09), tensor(7.3029e-09)]
# Coariance computed posterior       tensor([[ 1.6124e-09,  5.7096e-10, -8.6326e-11, -1.1170e-10],
#         [ 5.7096e-10,  5.1132e-08,  6.8686e-13,  6.8265e-13],
#         [-8.6326e-11,  6.8686e-13,  5.1140e-08, -1.2719e-13],
#         [-1.1170e-10,  6.8265e-13, -1.2719e-13,  5.1140e-08]])
#
# Expected value prior               [tensor(-3.8956e-22), tensor(6.0472e-21), tensor(3.3451e-20), tensor(3.6846e-20)]
# Variance prior                     [5.11364180e-08 5.11384162e-08 5.11384162e-08 5.11384162e-08]

# %%
plt.figure(figsize = [6,6])
true_parameters = [0.0]*4
k = 0
for i in range(4):
    for j in range(4):
        k += 1
        if i==j:
            plt.subplot(4, 4, k)
            
            theta = np.linspace(basis[i].domain[0], basis[i].domain[1],1000)
            pr = prior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
            po = posterior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
           
            plt.plot(1e3*theta,1e3*(po/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)))
            plt.axvline(true_parameters[i],c='r',linestyle=':')
            plt.plot(1e3*theta,1e3*(pr/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)),'g:')
            
        else:
            plt.subplot(4, 4, k)
             
            if j<i: 
                theta1 = np.linspace(basis[j].domain[0], basis[j].domain[1], 127)
                theta2 = np.linspace(basis[i].domain[0], basis[i].domain[1], 128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T1, 1e3*T2, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
            else: 
                theta1 = np.linspace(basis[i].domain[0],basis[i].domain[1],127)
                theta2 = np.linspace(basis[j].domain[0],basis[j].domain[1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T2, 1e3*T1, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
        
        if i==3: plt.xlabel(r'$\theta_'+str(j+1)+'$ [mm]')
        if j==0: plt.ylabel(r'$\theta_'+str(i+1)+'$ [mm]')
        
        if j>0: plt.yticks([])
        if i<3: plt.xticks([])

plt.savefig('quad_posterior1.pdf')
tikzplotlib.save('quad_posterior1.tex')

# %%
print('Rank solution ', dofs_tt.round(1e-10).R)
print('Storage solution ', tntt.numel(dofs_tt.round(1e-10))*8/1e6)
# Out:
# Rank solution  [1, 62, 144, 119, 53, 8, 1]
# Storage solution  6.51288

# %%
post = fspace_mod([tn.tensor([0.3]),tn.tensor([0]), tn.tensor([0]) , tn.linspace(-var1,var1,100),tn.linspace(-var2,var2,100)])
plt.imshow(post.numpy().squeeze())
plt.colorbar()

# %%
Dc = 3.27640e-2                                                           
# Dc = 32e-3
# hc = 7e-3
hc = 7.55176e-3                                                           
ri = 20e-3                                                           
                                                         
rm = ((Dc+var2)**2+hc*hc-(ri+var1)**2)/((Dc+var2)*np.sqrt(2)+hc*np.sqrt(2)-2*(ri+var1))                 


O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])

xc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[0].numpy().squeeze()
yc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[1].numpy().squeeze()
print(np.std(np.sqrt((xc-O[0])**2+(yc-O[1])**2)))
# Out:
# 9.152914622947604e-17
