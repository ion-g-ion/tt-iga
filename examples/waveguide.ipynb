# %% [markdown]
# # Helmholz equation on a parameter dependent domain
#
# Solve the scalar Helmholz on a domain (depending on 3 parameters) resembeling a rectangular waveguide.
#
# Imports

# %%
import torch as tn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
import datetime
try:
    import torchtt as tntt
except:
    print('Installing torchTT...')
    # %pip install git+https://github.com/ion-g-ion/torchtt
    import torchtt as tntt
try:
    import tt_iga
except:
    print('Installing TT-IGA...')
    # %pip install git+https://github.com/ion-g-ion/code-paper-tt-iga
    import tt_iga

tn.set_default_dtype(tn.float64)

# %% [markdown]
# Curves and surfaces parametrizations for the shape

# %%
xc = lambda u,v: u*tn.sqrt(1-v**2/2)
yc = lambda u,v: v*tn.sqrt(1-u**2/2)

line = lambda t,a,b: t*(b-a)+a

def plane_spanner(P1,P2,P3,t1,t2):
    x = (P1[:,0]-P2[:,0])*t1+(P3[:,0]-P2[:,0])*t2+P2[:,0]
    y = (P1[:,1]-P2[:,1])*t1+(P3[:,1]-P2[:,1])*t2+P2[:,1]
    z = (P1[:,2]-P2[:,2])*t1+(P3[:,2]-P2[:,2])*t2+P2[:,2]
    return x,y,z

def curve2(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = -1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,-1,-w2)+tn.logical_and(t>=0.5,t<=1)*(-w2)
    y = 0*(t<=0.75) + (t>0.75) * ( -ry*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( rz*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))

def curve1(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = 1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,1,w2)+tn.logical_and(t>=0.5,t<=1)*(w2)
    y = 0*(t<=0.75) + (t>0.75) * ( -ry*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( rz*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))
  
def curve3(t,a,b,c,d):
    w2 = 1.5
    ry = 1.5
    h = 0.5
    rz = 1.5+c
    x = -1*(t<0.25)+tn.logical_and(t>=0.25,t<0.5)*line((t-0.25)/0.25,-1,-w2)+tn.logical_and(t>=0.5,t<=1)*(-w2)
    y = h*(t<=0.75) + (t>0.75) * ( -(ry-h)*tn.cos((t-0.75)/0.25*np.pi/2) + ry )
    z = line(t/0.25,-3,-2+a)*(t<=0.25) + tn.logical_and(t>0.25,t<=0.5)*line((t-0.25)/0.25,-2+a,-1+b) + tn.logical_and(t>0.5,t<=0.75)*line((t-0.5)/0.25,-1+b,-0) + (t>0.75) * ( (rz-h)*tn.sin((t-0.75)/0.25*np.pi/2) )
    return tn.hstack((tn.reshape(x,[-1,1]),tn.reshape(y,[-1,1]),tn.reshape(z,[-1,1])))

# %% [markdown]
# Define the B-spline bases and the parameter space bases.
# For the parameter space, Gauss-Legendre nodes are used.

# %%
deg = 2
Ns = np.array([60,60,120])-deg+1
# Ns = np.array([40,40,140])-deg+1
baza1 = tt_iga.bspline.BSplineBasis(np.linspace(0,1,Ns[0]),deg)
baza2 = tt_iga.bspline.BSplineBasis(np.linspace(0,1,Ns[1]),deg)
baza3 = tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.25,Ns[2]//4),np.linspace(0.25,0.5,Ns[2]//4),np.linspace(0.5,0.75,Ns[2]//4),np.linspace(0.75,1,Ns[2]//4-1))),deg)

Basis = [baza1,baza2,baza3]
N = [baza1.N,baza2.N,baza3.N]

# %% [markdown]
# Define the parametrization and create the geometry object.

# %%
scale_mult = 1
xparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[0]
yparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[1]
zparam = lambda t : plane_spanner(curve1(t[:,2],0,0,0,0),curve2(t[:,2],0,0,0,0),curve3(t[:,2],0,0,0,0),t[:,0],t[:,1])[2]

# interpolate the geometry parametrization
geom = tt_iga.PatchBSpline.interpolate_geometry([xparam, yparam, zparam], Basis, [])

# %% [markdown]
# Firstly, plot the  geometry for the parameter $\theta_1 = \theta_2 = \theta_3 = 0$.
#
# Secondly, plot the geometries corrrecponding to the edges of the parameter space $[-0.2,0.2] \times [-0.2,0.2] \times [-0.3,0.3]$, i.e. $(\theta_1,\theta_2,\theta_3) \in \{-0.2,0.2\} \times \{-0.2,0.2\} \times \{-0.3,0.3\}$.

# %%
fig = geom.plot_domain([],[(0,1),(0,1),(0.0,1)],surface_color='blue', wireframe = False,alpha=0.1,n=64)
fig.gca().set_xlabel(r'$x_1$', fontsize=14)
fig.gca().set_ylabel(r'$x_2$', fontsize=14)
fig.gca().set_zlabel(r'$x_3$', fontsize=14)
fig.gca().view_init(15, -60)
fig.gca().zaxis.set_rotate_label(False)
fig.gca().set_xticks([-1.5, 0, 1.5])
fig.gca().set_yticks([0,1])
fig.gca().set_zticks([-3,-1.5,0,1.5])
fig.gca().tick_params(axis='both', labelsize=14)
fig.gca().set_box_aspect(aspect = (3,1.5,4.5))

# %% [markdown]
# Construct the stiffness and mass matrix for the entire parameter grid in the TT format.

# %%
tme = datetime.datetime.now() 
Mass_tt = geom.mass_interp(Basis, eps=1e-11)
tme = datetime.datetime.now() -tme
print('Time mass matrix ',tme.total_seconds())

tme = datetime.datetime.now() 
Stt = geom.stiffness_interp(Basis, func=None, func_reference = None, qtt = False, verb=False)
tme = datetime.datetime.now() -tme
print('Time stiffness matrix ',tme.total_seconds())
# Out:
# Time mass matrix  0.063798
# Time stiffness matrix  0.554995

# %% [markdown]
# Get the boundary/interior projection operators.

# %%
Pin_tt,Pbd_tt = tt_iga.projectors.get_projectors(N,[[0,0],[0,0],[0,0]])
Pbd_tt =  Pbd_tt

Pin_tt = Pin_tt 
Pbd_tt = Pbd_tt

# %% [markdown]
# Compute the excitation on the bottom port in TT format.
# The tensor is extended using Kronecker product since the excitation does not change with the parameters.
# The boundary projectpor is applied to let only the desired dofs nonzero.

# %%
f_tt = tntt.zeros(Stt.N)

excitation_dofs = tt_iga.Function(Basis).interpolate(lambda t: tn.sin(t[:,0]*np.pi)*tn.sin(t[:,1]*np.pi))
tmp = tn.zeros(N)
tmp[:,:,0] = excitation_dofs[:,:,0].full()
g_tt = Pbd_tt@ tntt.TT(tmp)

# %% [markdown]
# Compute the system matrix and include the boundary adaptation.

# %%
knumber = 49

eps_solver = 1e-8
M_tt = (Pin_tt@(Stt-knumber*Mass_tt)+Pbd_tt).round(1e-12)
rhs_tt = (Pbd_tt @ g_tt).round(1e-12)

M_tt = M_tt.round(1e-12)

# %% [markdown]
# Solve the problem (can solve on GPU if one is available) and report ranks, times, memory consumption, etc.

# %%
cuda = True
tme_amen = datetime.datetime.now() 
if cuda and tn.cuda.is_available():
    print('Solving in TT (GPU)...')
    dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp=40, kickrank=2, verbose=True, preconditioner = 'c', local_iterations=24, resets=10).cpu()
else:
    print('Solving in TT (CPU)...')
    dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = eps_solver, nswp=40, kickrank=2, verbose=False, preconditioner = 'c', local_iterations=24, resets=10)
tme_amen = (datetime.datetime.now() -tme_amen).total_seconds() 

print('',flush=True)
print('Time system solve in TT :',tme_amen)
print('Relative residual       :', (M_tt@dofs_tt-rhs_tt).norm()/rhs_tt.norm())
print('N                       :',N)
print('Rank Mtt                :',M_tt.R)
print('Rank rhstt              :',rhs_tt.R)
print('Rank solution           :',dofs_tt.R)
print('size stiff              :',tntt.numel(Stt)*8/1e6,' MB')
print('size mass               :',tntt.numel(Mass_tt)*8/1e6,' MB')
print('size system mat         :',tntt.numel(M_tt)*8/1e6,' MB')
print('size rhstt              :',tntt.numel(rhs_tt)*8/1e6,' MB')
print('size solution           :',tntt.numel(dofs_tt)*8/1e6,' MB, one full solution: ',np.prod(N)*8/1e6,' MB')
# Out:
# Solving in TT (GPU)...
#
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 60)....
# 		dx = 12.4587, res_now = 1.36465e-16, res_old = 50.945
# 	Core 1
# 		Choosing direct solver (local size 180)....
# 		dx = 0.74161, res_now = 1.64739e-15, res_old = 3.36782
# 	Core 2
# 		Choosing direct solver (local size 348)....
# 		dx = 1.25415, res_now = 7.25801e-18, res_old = 0.707131
# Solution rank is [1, 3, 3, 1]
# Maxres  tensor(50.9450, device='cuda:0')
# Time  0:00:00.035371
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing direct solver (local size 180)....
# 		dx = 0.00289309, res_now = 1.97525e-16, res_old = 0.00102214
# 	Core 1
# 		Choosing iterative solver GMRES (local size 900)....
# 		Finished with flag 1 after 27 iterations with relres 2.06314e-09 (from 8.92498e-07)
# 		Time needed  0:00:00.067562
# 		dx = 0.0110495, res_now = 2.06314e-09, res_old = 0.00323446
# 	Core 2
# 		Choosing iterative solver GMRES (local size 580)....
# 		Finished with flag 1 after 27 iterations with relres 2.33112e-09 (from 1.72693e-05)
# 		Time needed  0:00:00.058665
# 		dx = 0.0357037, res_now = 2.33112e-09, res_old = 0.000167161
# Solution rank is [1, 5, 5, 1]
# Maxres  tensor(0.0032, device='cuda:0')
# Time  0:00:00.163820
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing direct solver (local size 300)....
# 		dx = 0.029592, res_now = 2.7622e-16, res_old = 0.000901362
# 	Core 1
# 		Choosing iterative solver GMRES (local size 2100)....
# 		Finished with flag 1 after 34 iterations with relres 2.42612e-09 (from 1.02086e-05)
# 		Time needed  0:00:00.074488
# 		dx = 0.000392539, res_now = 2.42612e-09, res_old = 0.000282776
# 	Core 2
# 		Choosing iterative solver GMRES (local size 812)....
# 		Finished with flag 1 after 14 iterations with relres 1.11618e-09 (from 2.40035e-05)
# 		Time needed  0:00:00.029575
# 		dx = 0.0629158, res_now = 1.11618e-09, res_old = 0.000120264
# Solution rank is [1, 7, 7, 1]
# Maxres  tensor(0.0009, device='cuda:0')
# Time  0:00:00.143871
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing direct solver (local size 420)....
# 		dx = 0.012726, res_now = 2.91107e-16, res_old = 0.00025774
# 	Core 1
# 		Choosing iterative solver GMRES (local size 3780)....
# 		Finished with flag 1 after 237 iterations with relres 2.82738e-09 (from 3.39191e-05)
# 		Time needed  0:00:00.542702
# 		dx = 0.000637062, res_now = 2.82738e-09, res_old = 8.5107e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1044)....
# 		Finished with flag 1 after 13 iterations with relres 1.49974e-09 (from 5.81376e-05)
# 		Time needed  0:00:00.028438
# 		dx = 0.0158046, res_now = 1.49974e-09, res_old = 4.96538e-05
# Solution rank is [1, 9, 9, 1]
# Maxres  tensor(0.0003, device='cuda:0')
# Time  0:00:00.611501
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 540)....
# 		Finished with flag 0 after 240 iterations with relres 8.16331e-09 (from 7.38299e-05)
# 		Time needed  0:00:00.549209
# 		dx = 0.000777077, res_now = 8.16331e-09, res_old = 3.91e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 5940)....
# 		Finished with flag 0 after 240 iterations with relres 1.44046e-08 (from 1.13359e-05)
# 		Time needed  0:00:00.581630
# 		dx = 0.00101579, res_now = 1.44046e-08, res_old = 0.000254655
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1276)....
# 		Finished with flag 1 after 16 iterations with relres 2.57962e-09 (from 0.000382327)
# 		Time needed  0:00:00.028608
# 		dx = 0.00121532, res_now = 2.57962e-09, res_old = 7.55048e-06
# Solution rank is [1, 11, 11, 1]
# Maxres  tensor(0.0003, device='cuda:0')
# Time  0:00:01.194733
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 660)....
# 		Finished with flag 1 after 75 iterations with relres 2.86624e-09 (from 0.000477713)
# 		Time needed  0:00:00.171502
# 		dx = 6.16287e-05, res_now = 2.86624e-09, res_old = 6.04285e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 8580)....
# 		Finished with flag 1 after 21 iterations with relres 2.82123e-09 (from 0.000186477)
# 		Time needed  0:00:00.048161
# 		dx = 1.25217e-05, res_now = 2.82123e-09, res_old = 1.54805e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1508)....
# 		Finished with flag 1 after 9 iterations with relres 1.66946e-09 (from 0.0012906)
# 		Time needed  0:00:00.016408
# 		dx = 4.77629e-05, res_now = 1.66946e-09, res_old = 2.23675e-06
# Solution rank is [1, 13, 13, 1]
# Maxres  tensor(1.5480e-05, device='cuda:0')
# Time  0:00:00.267340
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 780)....
# 		Finished with flag 1 after 38 iterations with relres 2.56863e-09 (from 0.00142137)
# 		Time needed  0:00:00.076401
# 		dx = 1.592e-05, res_now = 2.56863e-09, res_old = 2.03097e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 11700)....
# 		Finished with flag 1 after 15 iterations with relres 2.03714e-09 (from 0.000433668)
# 		Time needed  0:00:00.029520
# 		dx = 4.81861e-06, res_now = 2.03714e-09, res_old = 6.6566e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1740)....
# 		Finished with flag 1 after 11 iterations with relres 2.082e-09 (from 0.00346587)
# 		Time needed  0:00:00.019552
# 		dx = 1.10996e-05, res_now = 2.082e-09, res_old = 8.32908e-07
# Solution rank is [1, 15, 15, 1]
# Maxres  tensor(6.6566e-06, device='cuda:0')
# Time  0:00:00.156481
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 900)....
# 		Finished with flag 1 after 21 iterations with relres 2.57375e-09 (from 0.00515395)
# 		Time needed  0:00:00.044057
# 		dx = 2.79427e-06, res_now = 2.57375e-09, res_old = 5.60104e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 15300)....
# 		Finished with flag 1 after 12 iterations with relres 2.28079e-09 (from 0.00132344)
# 		Time needed  0:00:00.023138
# 		dx = 1.58365e-06, res_now = 2.28079e-09, res_old = 2.18125e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1972)....
# 		Finished with flag 1 after 12 iterations with relres 2.59423e-09 (from 0.01065)
# 		Time needed  0:00:00.025878
# 		dx = 3.85299e-06, res_now = 2.59423e-09, res_old = 2.71056e-07
# Solution rank is [1, 17, 17, 1]
# Maxres  tensor(2.1812e-06, device='cuda:0')
# Time  0:00:00.127925
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1020)....
# 		Finished with flag 1 after 14 iterations with relres 2.84684e-09 (from 0.0210858)
# 		Time needed  0:00:00.026823
# 		dx = 1.00832e-06, res_now = 2.84684e-09, res_old = 1.36905e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 19380)....
# 		Finished with flag 1 after 12 iterations with relres 2.33833e-09 (from 0.00330862)
# 		Time needed  0:00:00.023677
# 		dx = 7.25371e-07, res_now = 2.33833e-09, res_old = 8.72494e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2204)....
# 		Finished with flag 1 after 6 iterations with relres 2.30092e-09 (from 0.0349223)
# 		Time needed  0:00:00.016001
# 		dx = 5.39866e-07, res_now = 2.30092e-09, res_old = 8.26622e-08
# Solution rank is [1, 19, 19, 1]
# Maxres  tensor(8.7249e-07, device='cuda:0')
# Time  0:00:00.104993
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1140)....
# 		Finished with flag 1 after 14 iterations with relres 2.52843e-09 (from 0.0173137)
# 		Time needed  0:00:00.030707
# 		dx = 9.92531e-07, res_now = 2.52843e-09, res_old = 1.66732e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 23940)....
# 		Finished with flag 1 after 10 iterations with relres 2.37314e-09 (from 0.00828358)
# 		Time needed  0:00:00.025687
# 		dx = 2.55825e-07, res_now = 2.37314e-09, res_old = 3.48491e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2436)....
# 		Finished with flag 1 after 7 iterations with relres 2.3709e-09 (from 0.0591215)
# 		Time needed  0:00:00.016788
# 		dx = 4.61129e-07, res_now = 2.3709e-09, res_old = 4.88274e-08
# Solution rank is [1, 21, 21, 1]
# Maxres  tensor(3.4849e-07, device='cuda:0')
# Time  0:00:00.110905
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1260)....
# 		Finished with flag 1 after 7 iterations with relres 2.75615e-09 (from 0.0770533)
# 		Time needed  0:00:00.014404
# 		dx = 4.35632e-07, res_now = 2.75615e-09, res_old = 3.74643e-08
# 	Core 1
# 		Choosing iterative solver GMRES (local size 28980)....
# 		Finished with flag 1 after 10 iterations with relres 2.26456e-09 (from 0.0161725)
# 		Time needed  0:00:00.031742
# 		dx = 1.81883e-07, res_now = 2.26456e-09, res_old = 1.78497e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2668)....
# 		Finished with flag 1 after 4 iterations with relres 2.48659e-09 (from 0.144671)
# 		Time needed  0:00:00.011528
# 		dx = 1.48971e-07, res_now = 2.48659e-09, res_old = 1.99539e-08
# Solution rank is [1, 23, 23, 1]
# Maxres  tensor(1.7850e-07, device='cuda:0')
# Time  0:00:00.101332
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1380)....
# 		Finished with flag 1 after 9 iterations with relres 2.13778e-09 (from 0.177897)
# 		Time needed  0:00:00.021181
# 		dx = 4.49391e-07, res_now = 2.13778e-09, res_old = 1.62271e-08
# 	Core 1
# 		Choosing iterative solver GMRES (local size 34500)....
# 		Finished with flag 1 after 6 iterations with relres 2.83144e-09 (from 0.0399293)
# 		Time needed  0:00:00.020446
# 		dx = 8.39481e-08, res_now = 2.83144e-09, res_old = 7.22966e-08
# 	Core 2
# 		Choosing iterative solver GMRES (local size 2900)....
# 		Finished with flag 1 after 3 iterations with relres 2.47234e-09 (from 0.432344)
# 		Time needed  0:00:00.010372
# 		dx = 7.16334e-08, res_now = 2.47234e-09, res_old = 6.67697e-09
# Solution rank is [1, 25, 25, 1]
# Maxres  tensor(7.2297e-08, device='cuda:0')
# Time  0:00:00.095338
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1500)....
# 		Finished with flag 1 after 3 iterations with relres 2.71403e-09 (from 0.28415)
# 		Time needed  0:00:00.008244
# 		dx = 1.63902e-07, res_now = 2.71403e-09, res_old = 1.01593e-08
# 	Core 1
# 		Choosing iterative solver GMRES (local size 40500)....
# 		Finished with flag 1 after 4 iterations with relres 2.74288e-09 (from 0.14626)
# 		Time needed  0:00:00.020270
# 		dx = 2.96709e-07, res_now = 2.74288e-09, res_old = 1.97371e-08
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3132)....
# 		Finished with flag 1 after 0 iterations with relres 2.31739e-09 (from 0.790962)
# 		Time needed  0:00:00.006186
# 		dx = 1.86722e-07, res_now = 2.31739e-09, res_old = 3.64967e-09
# Solution rank is [1, 27, 27, 1]
# Maxres  tensor(1.9737e-08, device='cuda:0')
# Time  0:00:00.076005
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1620)....
# 		Finished with flag 1 after 3 iterations with relres 2.66394e-09 (from 0.846309)
# 		Time needed  0:00:00.007115
# 		dx = 1.62225e-07, res_now = 2.66394e-09, res_old = 3.41099e-09
# 	Core 1
# 		Choosing iterative solver GMRES (local size 46980)....
# 		Finished with flag 1 after 1 iterations with relres 2.76735e-09 (from 0.352846)
# 		Time needed  0:00:00.014612
# 		dx = 5.97212e-08, res_now = 2.76735e-09, res_old = 8.18133e-09
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3364)....
# 		Finished with flag 1 after 0 iterations with relres 1.46671e-09 (from 1.50326)
# 		Time needed  0:00:00.006814
# 		dx = 2.35381e-08, res_now = 1.46671e-09, res_old = 1.92032e-09
# Solution rank is [1, 29, 29, 1]
# Maxres  tensor(8.1813e-09, device='cuda:0')
# Time  0:00:00.067603
#
# Starting sweep 14 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1740)....
# 		Finished with flag 1 after 0 iterations with relres 1.88749e-09 (from 1.4772)
# 		Time needed  0:00:00.004071
# 		dx = 6.72431e-09, res_now = 1.88749e-09, res_old = 1.9542e-09
# 	Core 1
# 		Choosing iterative solver GMRES (local size 50460)....
# 		Finished with flag 1 after 1 iterations with relres 2.77448e-09 (from 0.783077)
# 		Time needed  0:00:00.014788
# 		dx = 3.02531e-07, res_now = 2.77448e-09, res_old = 3.68642e-09
# 	Core 2
# 		Choosing iterative solver GMRES (local size 3364)....
# 		Finished with flag 1 after 0 iterations with relres 1.14153e-09 (from 1.49618)
# 		Time needed  0:00:00.006145
# 		dx = 2.77275e-07, res_now = 1.14153e-09, res_old = 1.92941e-09
# Solution rank is [1, 29, 29, 1]
# Maxres  tensor(3.6864e-09, device='cuda:0')
# Time  0:00:00.049587
#
# Finished after 14  sweeps and  0:00:03.315818
#
#
# Time system solve in TT : 6.142235
# Relative residual       : tensor(1.2871e-09)
# N                       : [60, 60, 116]
# Rank Mtt                : [1, 6, 11, 1]
# Rank rhstt              : [1, 1, 1, 1]
# Rank solution           : [1, 29, 29, 1]
# size stiff              : 2.66048  MB
# size mass               : 0.301696  MB
# size system mat         : 3.257728  MB
# size rhstt              : 0.001888  MB
# size solution           : 0.444512  MB, one full solution:  3.3408  MB

# %% [markdown]
# Plot the solution in the reference domain for $(y_1,y_2,y_3)\in[0,1]\times\{0.5\}\times[0,1]$ and $\theta_1=\theta_2=\theta_3=0$.

# %%
fspace = tt_iga.Function(Basis)
fspace.dofs = dofs_tt

fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])
y1, y3 = tn.meshgrid(tn.linspace(0,1,128),tn.linspace(0,1,128))

plt.figure()
plt.contourf(y1, y3, fval.numpy().squeeze(), levels = 128)
plt.colorbar()
plt.xlabel(r'$y_1$')
plt.ylabel(r'$y_3$')

fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])

plt.figure()
plt.contourf(y1, y3, fval.numpy().squeeze(), levels = 128, cmap = 'GnBu')
plt.colorbar()
plt.xlabel(r'$y_1$')
plt.ylabel(r'$y_3$')
# Out:
# /home/yonnss/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Text(0, 0.5, '$y_3$')

# %% [markdown]
# Plot the domain and the solution in the physical domain for $(y_1,y_2,y_3)\in[0,1]\times\{0.5\}\times[0,1]$ and $\theta_1=\theta_2=\theta_3=0$.

# %%
fval = fspace([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])
x,y,z =  geom([tn.linspace(0,1,128),tn.tensor([0.5]),tn.linspace(0,1,128)])

fig = geom.plot_domain([],[(0,1),(0,1),(0.0,1)],surface_color=None, wireframe = False,frame_color='k',n = 64)
geom.plot_domain([],[(0,1),(0,1),(0.25,0.5)],fig=fig,surface_color=None, wireframe = False,frame_color='k',n = 64)
geom.plot_domain([],[(0,1),(0,1),(0.75,1)],fig=fig,surface_color=None, wireframe = False,frame_color='k',n = 64)

ax = fig.gca()
C = fval.numpy().squeeze()
norm = matplotlib.colors.Normalize(vmin=C.min(),vmax=C.max())
C = plt.cm.jet(norm(C))
C[:,:,-1] = 1
ax.plot_surface(x.numpy().squeeze(), y.numpy().squeeze(), z.numpy().squeeze(), edgecolors=None, linewidth=0, facecolors = C, antialiased=True, rcount=256, ccount=256, alpha=0.5)
fig.gca().set_xlabel(r'$x_1$', fontsize=14)
fig.gca().set_ylabel(r'$x_2$', fontsize=14)
fig.gca().set_zlabel(r'$x_3$', fontsize=14)
fig.gca().view_init(15, -60)
fig.gca().zaxis.set_rotate_label(False)
fig.gca().set_xticks([-1.5, 0, 1.5])
fig.gca().set_yticks([0,1])
fig.gca().set_zticks([-3,-1.5,0,1.5])
fig.gca().tick_params(axis='both', labelsize=14)
fig.gca().set_box_aspect(aspect = (3,1.5,4.5))

# %% [markdown]
# Generate some measurements for the inverse problem.

# %%
x1 ,x2 , x3 = geom([tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.75])])
print(x1.numpy().squeeze())
print(x2.numpy().squeeze())
print(x3.numpy().squeeze())
fval = fspace([tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.25, 0.5, 0.75]), tn.tensor([0.75])]).numpy().squeeze()
print('field ',fval)
import pickle
with open('wg_measurement.pkl', 'wb') as f:
    pickle.dump({'meas' : fval}, f)
# Out:
# [[-7.50000000e-01 -7.50000000e-01 -7.50000000e-01]
#  [-4.95724377e-17 -4.95724377e-17 -4.95724377e-17]
#  [ 7.50000000e-01  7.50000000e-01  7.50000000e-01]]
# [[0.125 0.25  0.375]
#  [0.125 0.25  0.375]
#  [0.125 0.25  0.375]]
# [[-1.26339734e-15 -1.11845851e-15 -9.73519675e-16]
#  [-1.26339734e-15 -1.11845851e-15 -9.73519675e-16]
#  [-1.26339734e-15 -1.11845851e-15 -9.73519675e-16]]
# field  [[-0.17160485 -0.25513911 -0.19055893]
#  [-0.32557508 -0.48036638 -0.35591617]
#  [-0.1716053  -0.25513976 -0.1905594 ]]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
