# %%
import torch as tn
import torch.nn as nn
import torch.nn.functional as F
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime
import torch.utils.data 

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
        
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    # Dc = 32e-3
    # hc = 7e-3
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.sin((np.pi-np.abs(alpha2(params)+np.pi*3/4))/2)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc-blc)*(hi+params[...,3])+0.5*(bli+params[...,2])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()

var1, var2, var3, var4 = (0.00075, 0.00075, 0.00075, 0.00075)

basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 10
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param, eps = 1e-13)

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))

tme = datetime.datetime.now()
Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
tme = datetime.datetime.now() - tme
print('Time mass ', tme)
tme = datetime.datetime.now()
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-10, func_reference=mu_ref, qtt = True, verb = False, device = 'cuda:1')
tme = datetime.datetime.now() - tme
print('Time stiffness ', tme)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[1])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4) / Mass_tt.N[0]

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-10)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-10)

print('System matrix... ',flush=True)

print('Rank Stiff', Stiff_tt.R, ' storage [MB] ',tntt.numel(Stiff_tt)*8/1e6)
print('Rank Mass', Mass_tt.R, ' storage [MB] ',tntt.numel(Mass_tt)*8/1e6)
print('Rank Mtt ',M_tt.R, ' storage [MB] ',tntt.numel(M_tt)*8/1e6)
print('Rank rhstt ',rhs_tt.R, ' storage [MB] ',tntt.numel(rhs_tt)*8/1e6)
# Out:
# Time mass  0:00:01.833745
# Sweep 1:
# 	LR supercore 1,2
# 		number evaluations 113280
# 		rank updated 2 -> 6, local error 1.000000e+00
# 	LR supercore 2,3
# 		number evaluations 28320
# 		rank updated 2 -> 4, local error 1.156948e+00
# 	LR supercore 3,4
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 1.168934e+00
# 	LR supercore 4,5
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 1.430973e+00
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 2 -> 4, local error 1.208699e+00
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 2.275523e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 3.926802e-16
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 5.632826e-16
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 1.208686e-15
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 3.058591e-14
# Max error 1.43097
# Sweep 2:
# 	LR supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 4.736372e-15
# 	LR supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 8.222091e-15
# 	LR supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 4.577308e-15
# 	LR supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 4.713453e-16
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 1.182786e-15
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 7.801113e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 4.402349e-16
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 9.645141e-15
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 1.912568e-15
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 5.897037e-15
# Max error 9.645141e-15 < 1.000000e-10  ---->  DONE
# number of function calls  1004000
#
# Time stiffness  0:00:25.991976
# System matrix...
# Rank Stiff [1, 92, 86, 61, 26, 7, 1]  storage [MB]  267.891872
# Rank Mass [1, 18, 22, 11, 4, 2, 1]  storage [MB]  13.802752
# Rank Mtt  [1, 90, 83, 59, 26, 7, 1]  storage [MB]  253.02208
# Rank rhstt  [1, 3, 6, 6, 10, 4, 1]  storage [MB]  0.021952

# %%
tme = datetime.datetime.now() 
dev_name = 'cuda:1'
dofs_tt = tntt.solvers.amen_solve(M_tt.to(dev_name), rhs_tt.to(dev_name), x0 = tntt.ones(rhs_tt.N).to(dev_name), rmax = 300, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = False).cpu()
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# Time system solve  0:02:57.073024

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt.round(1e-10)

# %%
def generate_batch(n):
   # tn.manual_seed(123)
    inputs = tn.rand((n,4))*2-1
    outputs = []
    varz = [var1,var2,var3,var4]
    for p in inputs:
        out = dofs_tt.mprod([tn.tensor(basis_param[i]([p[i]*varz[i]])).T for i in range(4)],[2,3,4,5])[:,:,0,0,0,0]
        outputs.append(tn.squeeze(out.full())[None,:,:]/0.005)

    return inputs, tn.concat(outputs,0)

n_train = 10000
train_ins, train_outs = generate_batch(n_train)
train_data = torch.utils.data.TensorDataset(train_ins, train_outs)

n_test = 1000
test_ins, test_outs = generate_batch(n_test)
test_data = torch.utils.data.TensorDataset(test_ins, test_outs)

dataloader_train = tn.utils.data.DataLoader(train_data, batch_size=100, shuffle=True, num_workers=10, pin_memory = False)
dataloader_test = tn.utils.data.DataLoader(test_data, batch_size=100, shuffle=True, num_workers=10, pin_memory = False)

# %%
class CPINN(nn.Module):
   def __init__(self):
      super(CPINN, self).__init__()
      self.fc1 = nn.Linear(4, 50)
      self.fc2 = nn.Linear(50, 169)
      self.c1 = nn.ConvTranspose2d(1, 1, (6,6), stride=2)
      self.c2 = nn.ConvTranspose2d(1, 1, (6,6), stride=2)
   def forward(self, x):
      x = tn.tanh(self.fc1(x))
      x = tn.tanh(self.fc2(x))
      x = x.view([-1,1,13,13])
      x = tn.relu(self.c1(x))
      x = self.c2(x)
      return x.view([-1,64,64])

class ANN(nn.Module):
   def __init__(self):
      super(ANN, self).__init__()
      self.fc1 = nn.Linear(4, 25)
      self.fc2 = nn.Linear(25, 25)
      self.fc3 = nn.Linear(25, 64*64)
   def forward(self, x):
      x = tn.tanh(self.fc1(x))
      x = tn.tanh(self.fc2(x))
      x = (self.fc3(x))
      return x.view([-1,64,64])

class TTN(nn.Module):
    def __init__(self):
        super().__init__()
        p = 0.25
        self.fc1 = nn.Linear(4, 16)
        self.fc2 = nn.Linear(16, 16)
        self.ttl1 = tntt.nn.LinearLayerTT([2,2,2,2], [4,4,4,4], [1,4,4,4,1], initializer = 'He', dtype = tn.float64)
        self.dropout1 = nn.Dropout(p)
        self.ttl2 = tntt.nn.LinearLayerTT([4,4,4,4], [6,6,6,6], [1,4,4,4,1], initializer = 'He', dtype = tn.float64)
        self.dropout2 = nn.Dropout(p)
        self.ttl3 = tntt.nn.LinearLayerTT([6,6,6,6], [8,8,8,8], [1,4,4,4,1], initializer = 'He', dtype = tn.float64)
        self.dropout3 = nn.Dropout(p)
        self.ttl4 = tntt.nn.LinearLayerTT([8,8,8,8], [8,8,8,8], [1,2,2,2,1], initializer = 'He', dtype = tn.float64)

    def forward(self, x):
        x = tn.tanh(self.fc1(x))
        x = tn.tanh(self.fc2(x))
        x = x.view([-1,2,2,2,2])
        
        x = self.ttl1(x)
        #x = self.dropout1(x)
        x = tn.relu(x)

        x = self.ttl2(x)
        #x = self.dropout2(x)
        x = tn.relu(x)

        x = self.ttl3(x)
        #x = self.dropout3(x)
        x = tn.relu(x)

        x = self.ttl4(x)
        
        return x.view([-1,64,64])

# %%
tn.cuda.empty_cache() 
device_name = 'cuda:1'
model = TTN()
print(model)
model.to(device_name) #.to(tn.float32)



loss_function = nn.MSELoss()
# Out:
# TTN(
#   (fc1): Linear(in_features=4, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=16, bias=True)
#   (ttl1): LinearLayerTT(
#     (cores): ParameterList(
#         (0): Parameter containing: [torch.DoubleTensor of size 1x4x2x4]
#         (1): Parameter containing: [torch.DoubleTensor of size 4x4x2x4]
#         (2): Parameter containing: [torch.DoubleTensor of size 4x4x2x4]
#         (3): Parameter containing: [torch.DoubleTensor of size 4x4x2x1]
#     )
#   )
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (ttl2): LinearLayerTT(
#     (cores): ParameterList(
#         (0): Parameter containing: [torch.DoubleTensor of size 1x6x4x4]
#         (1): Parameter containing: [torch.DoubleTensor of size 4x6x4x4]
#         (2): Parameter containing: [torch.DoubleTensor of size 4x6x4x4]
#         (3): Parameter containing: [torch.DoubleTensor of size 4x6x4x1]
#     )
#   )
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (ttl3): LinearLayerTT(
#     (cores): ParameterList(
#         (0): Parameter containing: [torch.DoubleTensor of size 1x8x6x4]
#         (1): Parameter containing: [torch.DoubleTensor of size 4x8x6x4]
#         (2): Parameter containing: [torch.DoubleTensor of size 4x8x6x4]
#         (3): Parameter containing: [torch.DoubleTensor of size 4x8x6x1]
#     )
#   )
#   (dropout3): Dropout(p=0.25, inplace=False)
#   (ttl4): LinearLayerTT(
#     (cores): ParameterList(
#         (0): Parameter containing: [torch.DoubleTensor of size 1x8x8x3]
#         (1): Parameter containing: [torch.DoubleTensor of size 3x8x8x3]
#         (2): Parameter containing: [torch.DoubleTensor of size 3x8x8x3]
#         (3): Parameter containing: [torch.DoubleTensor of size 3x8x8x1]
#     )
#   )
# )

# %%
# optimizer = tn.optim.SGD(model.parameters(), lr=0.005, momentum=0.9)
optimizer = tn.optim.Adam(model.parameters(), lr=0.005)
scheduler = tn.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
device_name = 'cuda:0'
model.to(device_name).to(tn.float32)

tn.cuda.empty_cache() 

n_epochs = 400


history_test_loss = []
history_train_loss = []



for epoch in range(n_epochs):
    
    loss_train = 0

    model.train(True)
    for i,(param,sol) in enumerate(dataloader_train):
        
        param = param.to(device_name).to(tn.float32)
        sol = sol.to(device_name).to(tn.float32)
        
        optimizer.zero_grad()
        # Make predictions for this batch
        out = model(param)
        # Compute the loss and its gradients
        loss = (loss_function(out, sol))
        # regularization
        l2_lambda = 0.000005
        l2_norm = sum(p.pow(2.0).sum() for p in model.parameters())
        loss = loss+l2_lambda*l2_norm
        loss.backward()
        loss_train += loss

    loss_train /= len(dataloader_train)
    model.train(False)
    optimizer.step()

    loss_test = 0
    # for i,(param,sol) in enumerate(dataloader_train):
    #     
    #     param = param.to(device_name).to(tn.float32)
    #     sol = sol.to(device_name).to(tn.float32)
    #     
    #     
    #     # Make predictions for this batch
    #     out = model(param)
    #     # Compute the loss and its gradients
    #     loss = tn.sqrt(loss_function(out, sol))
    #     # regularization
    #     l2_lambda = 0.00005
    #     l2_norm = sum(p.pow(2.0).sum() for p in model.parameters())
    #     loss = loss+0#l2_lambda*l2_norm
    #     loss_test += loss

    loss_test /= len(dataloader_test)

    print('Epoch %d/%d: iterations %d, loss train %e, loss test %e'%(epoch+1, n_epochs, len(dataloader_train), loss_train, loss_test))
    history_train_loss.append(loss_train)
    history_test_loss.append(loss_test)

    tn.cuda.empty_cache()
# Out:
# Epoch 1/400: iterations 100, loss train 7.464343e-03, loss test 0.000000e+00
# Epoch 2/400: iterations 100, loss train 4.654248e-03, loss test 0.000000e+00
# Epoch 3/400: iterations 100, loss train 4.904766e-03, loss test 0.000000e+00
# Epoch 4/400: iterations 100, loss train 3.735249e-03, loss test 0.000000e+00
# Epoch 5/400: iterations 100, loss train 3.828443e-03, loss test 0.000000e+00
# Epoch 6/400: iterations 100, loss train 3.133404e-03, loss test 0.000000e+00
# Epoch 7/400: iterations 100, loss train 2.638344e-03, loss test 0.000000e+00
# Epoch 8/400: iterations 100, loss train 2.657653e-03, loss test 0.000000e+00
# Epoch 9/400: iterations 100, loss train 2.265426e-03, loss test 0.000000e+00
# Epoch 10/400: iterations 100, loss train 2.144572e-03, loss test 0.000000e+00
# Epoch 11/400: iterations 100, loss train 2.249639e-03, loss test 0.000000e+00
# Epoch 12/400: iterations 100, loss train 2.071410e-03, loss test 0.000000e+00
# Epoch 13/400: iterations 100, loss train 2.020359e-03, loss test 0.000000e+00
# Epoch 14/400: iterations 100, loss train 2.097845e-03, loss test 0.000000e+00
# Epoch 15/400: iterations 100, loss train 1.965008e-03, loss test 0.000000e+00
# Epoch 16/400: iterations 100, loss train 1.900534e-03, loss test 0.000000e+00
# Epoch 17/400: iterations 100, loss train 1.927797e-03, loss test 0.000000e+00
# Epoch 18/400: iterations 100, loss train 1.841088e-03, loss test 0.000000e+00
# Epoch 19/400: iterations 100, loss train 1.801231e-03, loss test 0.000000e+00
# Epoch 20/400: iterations 100, loss train 1.846784e-03, loss test 0.000000e+00
# Epoch 21/400: iterations 100, loss train 1.804108e-03, loss test 0.000000e+00
# Epoch 22/400: iterations 100, loss train 1.768980e-03, loss test 0.000000e+00
# Epoch 23/400: iterations 100, loss train 1.778862e-03, loss test 0.000000e+00
# Epoch 24/400: iterations 100, loss train 1.726069e-03, loss test 0.000000e+00
# Epoch 25/400: iterations 100, loss train 1.683667e-03, loss test 0.000000e+00
# Epoch 26/400: iterations 100, loss train 1.697948e-03, loss test 0.000000e+00
# Epoch 27/400: iterations 100, loss train 1.669064e-03, loss test 0.000000e+00
# Epoch 28/400: iterations 100, loss train 1.643868e-03, loss test 0.000000e+00
# Epoch 29/400: iterations 100, loss train 1.655622e-03, loss test 0.000000e+00
# Epoch 30/400: iterations 100, loss train 1.625509e-03, loss test 0.000000e+00
# Epoch 31/400: iterations 100, loss train 1.601878e-03, loss test 0.000000e+00
# Epoch 32/400: iterations 100, loss train 1.611762e-03, loss test 0.000000e+00
# Epoch 33/400: iterations 100, loss train 1.585687e-03, loss test 0.000000e+00
# Epoch 34/400: iterations 100, loss train 1.573128e-03, loss test 0.000000e+00
# Epoch 35/400: iterations 100, loss train 1.574906e-03, loss test 0.000000e+00
# Epoch 36/400: iterations 100, loss train 1.550995e-03, loss test 0.000000e+00
# Epoch 37/400: iterations 100, loss train 1.542823e-03, loss test 0.000000e+00
# Epoch 38/400: iterations 100, loss train 1.538808e-03, loss test 0.000000e+00
# Epoch 39/400: iterations 100, loss train 1.521634e-03, loss test 0.000000e+00
# Epoch 40/400: iterations 100, loss train 1.519407e-03, loss test 0.000000e+00
# Epoch 41/400: iterations 100, loss train 1.512858e-03, loss test 0.000000e+00
# Epoch 42/400: iterations 100, loss train 1.497901e-03, loss test 0.000000e+00
# Epoch 43/400: iterations 100, loss train 1.495674e-03, loss test 0.000000e+00
# Epoch 44/400: iterations 100, loss train 1.485795e-03, loss test 0.000000e+00
# Epoch 45/400: iterations 100, loss train 1.476193e-03, loss test 0.000000e+00
# Epoch 46/400: iterations 100, loss train 1.475171e-03, loss test 0.000000e+00
# Epoch 47/400: iterations 100, loss train 1.464278e-03, loss test 0.000000e+00
# Epoch 48/400: iterations 100, loss train 1.458052e-03, loss test 0.000000e+00
# Epoch 49/400: iterations 100, loss train 1.453780e-03, loss test 0.000000e+00
# Epoch 50/400: iterations 100, loss train 1.443295e-03, loss test 0.000000e+00
# Epoch 51/400: iterations 100, loss train 1.439925e-03, loss test 0.000000e+00
# Epoch 52/400: iterations 100, loss train 1.431741e-03, loss test 0.000000e+00
# Epoch 53/400: iterations 100, loss train 1.426587e-03, loss test 0.000000e+00
# Epoch 54/400: iterations 100, loss train 1.422460e-03, loss test 0.000000e+00
# Epoch 55/400: iterations 100, loss train 1.413208e-03, loss test 0.000000e+00
# Epoch 56/400: iterations 100, loss train 1.410250e-03, loss test 0.000000e+00
# Epoch 57/400: iterations 100, loss train 1.400999e-03, loss test 0.000000e+00
# Epoch 58/400: iterations 100, loss train 1.397584e-03, loss test 0.000000e+00
# Epoch 59/400: iterations 100, loss train 1.390595e-03, loss test 0.000000e+00
# Epoch 60/400: iterations 100, loss train 1.384611e-03, loss test 0.000000e+00
# Epoch 61/400: iterations 100, loss train 1.379093e-03, loss test 0.000000e+00
# Epoch 62/400: iterations 100, loss train 1.372947e-03, loss test 0.000000e+00
# Epoch 63/400: iterations 100, loss train 1.367610e-03, loss test 0.000000e+00
# Epoch 64/400: iterations 100, loss train 1.361819e-03, loss test 0.000000e+00
# Epoch 65/400: iterations 100, loss train 1.357208e-03, loss test 0.000000e+00
# Epoch 66/400: iterations 100, loss train 1.351404e-03, loss test 0.000000e+00
# Epoch 67/400: iterations 100, loss train 1.347140e-03, loss test 0.000000e+00
# Epoch 68/400: iterations 100, loss train 1.340951e-03, loss test 0.000000e+00
# Epoch 69/400: iterations 100, loss train 1.336611e-03, loss test 0.000000e+00
# Epoch 70/400: iterations 100, loss train 1.330974e-03, loss test 0.000000e+00
# Epoch 71/400: iterations 100, loss train 1.325924e-03, loss test 0.000000e+00
# Epoch 72/400: iterations 100, loss train 1.321606e-03, loss test 0.000000e+00
# Epoch 73/400: iterations 100, loss train 1.315499e-03, loss test 0.000000e+00
# Epoch 74/400: iterations 100, loss train 1.310367e-03, loss test 0.000000e+00
# Epoch 75/400: iterations 100, loss train 1.304561e-03, loss test 0.000000e+00
# Epoch 76/400: iterations 100, loss train 1.300484e-03, loss test 0.000000e+00
# Epoch 77/400: iterations 100, loss train 1.294233e-03, loss test 0.000000e+00
# Epoch 78/400: iterations 100, loss train 1.290335e-03, loss test 0.000000e+00
# Epoch 79/400: iterations 100, loss train 1.284837e-03, loss test 0.000000e+00
# Epoch 80/400: iterations 100, loss train 1.279684e-03, loss test 0.000000e+00
# Epoch 81/400: iterations 100, loss train 1.274825e-03, loss test 0.000000e+00
# Epoch 82/400: iterations 100, loss train 1.269938e-03, loss test 0.000000e+00
# Epoch 83/400: iterations 100, loss train 1.266088e-03, loss test 0.000000e+00
# Epoch 84/400: iterations 100, loss train 1.260726e-03, loss test 0.000000e+00
# Epoch 85/400: iterations 100, loss train 1.255989e-03, loss test 0.000000e+00
# Epoch 86/400: iterations 100, loss train 1.250533e-03, loss test 0.000000e+00
# Epoch 87/400: iterations 100, loss train 1.247782e-03, loss test 0.000000e+00
# Epoch 88/400: iterations 100, loss train 1.241077e-03, loss test 0.000000e+00
# Epoch 89/400: iterations 100, loss train 1.237661e-03, loss test 0.000000e+00
# Epoch 90/400: iterations 100, loss train 1.232089e-03, loss test 0.000000e+00
# Epoch 91/400: iterations 100, loss train 1.229829e-03, loss test 0.000000e+00
# Epoch 92/400: iterations 100, loss train 1.222561e-03, loss test 0.000000e+00
# Epoch 93/400: iterations 100, loss train 1.221202e-03, loss test 0.000000e+00
# Epoch 94/400: iterations 100, loss train 1.213251e-03, loss test 0.000000e+00
# Epoch 95/400: iterations 100, loss train 1.212110e-03, loss test 0.000000e+00
# Epoch 96/400: iterations 100, loss train 1.204952e-03, loss test 0.000000e+00
# Epoch 97/400: iterations 100, loss train 1.200965e-03, loss test 0.000000e+00
# Epoch 98/400: iterations 100, loss train 1.196585e-03, loss test 0.000000e+00
# Epoch 99/400: iterations 100, loss train 1.191680e-03, loss test 0.000000e+00
# Epoch 100/400: iterations 100, loss train 1.189727e-03, loss test 0.000000e+00
# Epoch 101/400: iterations 100, loss train 1.182733e-03, loss test 0.000000e+00
# Epoch 102/400: iterations 100, loss train 1.180424e-03, loss test 0.000000e+00
# Epoch 103/400: iterations 100, loss train 1.174272e-03, loss test 0.000000e+00
# Epoch 104/400: iterations 100, loss train 1.170749e-03, loss test 0.000000e+00
# Epoch 105/400: iterations 100, loss train 1.166785e-03, loss test 0.000000e+00
# Epoch 106/400: iterations 100, loss train 1.162233e-03, loss test 0.000000e+00
# Epoch 107/400: iterations 100, loss train 1.158849e-03, loss test 0.000000e+00
# Epoch 108/400: iterations 100, loss train 1.152822e-03, loss test 0.000000e+00
# Epoch 109/400: iterations 100, loss train 1.151826e-03, loss test 0.000000e+00
# Epoch 110/400: iterations 100, loss train 1.145102e-03, loss test 0.000000e+00
# Epoch 111/400: iterations 100, loss train 1.142695e-03, loss test 0.000000e+00
# Epoch 112/400: iterations 100, loss train 1.137015e-03, loss test 0.000000e+00
# Epoch 113/400: iterations 100, loss train 1.132518e-03, loss test 0.000000e+00
# Epoch 114/400: iterations 100, loss train 1.129988e-03, loss test 0.000000e+00
# Epoch 115/400: iterations 100, loss train 1.123926e-03, loss test 0.000000e+00
# Epoch 116/400: iterations 100, loss train 1.120697e-03, loss test 0.000000e+00
# Epoch 117/400: iterations 100, loss train 1.116788e-03, loss test 0.000000e+00
# Epoch 118/400: iterations 100, loss train 1.112120e-03, loss test 0.000000e+00
# Epoch 119/400: iterations 100, loss train 1.107925e-03, loss test 0.000000e+00
# Epoch 120/400: iterations 100, loss train 1.105260e-03, loss test 0.000000e+00
# Epoch 121/400: iterations 100, loss train 1.100537e-03, loss test 0.000000e+00
# Epoch 122/400: iterations 100, loss train 1.097951e-03, loss test 0.000000e+00
# Epoch 123/400: iterations 100, loss train 1.094011e-03, loss test 0.000000e+00
# Epoch 124/400: iterations 100, loss train 1.088986e-03, loss test 0.000000e+00
# Epoch 125/400: iterations 100, loss train 1.086249e-03, loss test 0.000000e+00
# Epoch 126/400: iterations 100, loss train 1.081366e-03, loss test 0.000000e+00
# Epoch 127/400: iterations 100, loss train 1.078455e-03, loss test 0.000000e+00
# Epoch 128/400: iterations 100, loss train 1.076368e-03, loss test 0.000000e+00
# Epoch 129/400: iterations 100, loss train 1.070855e-03, loss test 0.000000e+00
# Epoch 130/400: iterations 100, loss train 1.066866e-03, loss test 0.000000e+00
# Epoch 131/400: iterations 100, loss train 1.067422e-03, loss test 0.000000e+00
# Epoch 132/400: iterations 100, loss train 1.060768e-03, loss test 0.000000e+00
# Epoch 133/400: iterations 100, loss train 1.056690e-03, loss test 0.000000e+00
# Epoch 134/400: iterations 100, loss train 1.055071e-03, loss test 0.000000e+00
# Epoch 135/400: iterations 100, loss train 1.049959e-03, loss test 0.000000e+00
# Epoch 136/400: iterations 100, loss train 1.047130e-03, loss test 0.000000e+00
# Epoch 137/400: iterations 100, loss train 1.044533e-03, loss test 0.000000e+00
# Epoch 138/400: iterations 100, loss train 1.040265e-03, loss test 0.000000e+00
# Epoch 139/400: iterations 100, loss train 1.035545e-03, loss test 0.000000e+00
# Epoch 140/400: iterations 100, loss train 1.031977e-03, loss test 0.000000e+00
# Epoch 141/400: iterations 100, loss train 1.028520e-03, loss test 0.000000e+00
# Epoch 142/400: iterations 100, loss train 1.024387e-03, loss test 0.000000e+00
# Epoch 143/400: iterations 100, loss train 1.020959e-03, loss test 0.000000e+00
# Epoch 144/400: iterations 100, loss train 1.017999e-03, loss test 0.000000e+00
# Epoch 145/400: iterations 100, loss train 1.014171e-03, loss test 0.000000e+00
# Epoch 146/400: iterations 100, loss train 1.011690e-03, loss test 0.000000e+00
# Epoch 147/400: iterations 100, loss train 1.008655e-03, loss test 0.000000e+00
# Epoch 148/400: iterations 100, loss train 1.004877e-03, loss test 0.000000e+00
# Epoch 149/400: iterations 100, loss train 1.001733e-03, loss test 0.000000e+00
# Epoch 150/400: iterations 100, loss train 9.994715e-04, loss test 0.000000e+00
# Epoch 151/400: iterations 100, loss train 9.974212e-04, loss test 0.000000e+00
# Epoch 152/400: iterations 100, loss train 9.930111e-04, loss test 0.000000e+00
# Epoch 153/400: iterations 100, loss train 9.881133e-04, loss test 0.000000e+00
# Epoch 154/400: iterations 100, loss train 9.908420e-04, loss test 0.000000e+00
# Epoch 155/400: iterations 100, loss train 9.886193e-04, loss test 0.000000e+00
# Epoch 156/400: iterations 100, loss train 9.806518e-04, loss test 0.000000e+00
# Epoch 157/400: iterations 100, loss train 9.759764e-04, loss test 0.000000e+00
# Epoch 158/400: iterations 100, loss train 9.792417e-04, loss test 0.000000e+00
# Epoch 159/400: iterations 100, loss train 9.748090e-04, loss test 0.000000e+00

# %%
i, o = generate_batch(2)

n = model(i.to(device_name).to(tn.float32)).cpu()

plt.figure()
plt.imshow(o[0,...])
plt.colorbar()

plt.figure()
plt.imshow(n[0,...].detach())
plt.colorbar()

plt.figure()
plt.imshow(n[0,...].detach()-o[0,...])
plt.colorbar()

# %%
sum([ tn.numel(t) for t in list(model.parameters())])
dofs_tt
# Out:
# TT with sizes and ranks:
# N = [64, 64, 10, 10, 10, 10]
# R = [1, 64, 161, 161, 100, 10, 1]
#
# Device: cpu, dtype: torch.float64
# #entries 1093862 compression 0.026705615234375
