# %%
from webbrowser import get
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
        
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    # Dc = 32e-3
    # hc = 7e-3
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.sin((np.pi-np.abs(alpha2(params)+np.pi*3/4))/2)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc-blc)*(hi+params[...,3])+0.5*(bli+params[...,2])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()
print(surface(np.array([0.0,0.0,0.0,0.0])))

var1 = 0.00075
var2 = 0.00075
var3 = 0.00075
var4 = 0.00075
pts = control_points([0,0,0,0])
plt.figure()
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)
pts = control_points([0,-0.003,0,0])
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)


basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 10
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param, eps = 1e-13)

# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[0].numpy().squeeze())
# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[1].numpy().squeeze())
# 
# print(weights(np.zeros((4))))
# print(control_points(np.zeros((4)))[1,:,:])
# Out:
# 0.0002177263404511999

# %%
plt.figure()

for i in range(20):
    paramz = [tn.tensor([np.random.uniform()*2*var1-var1]),tn.tensor([np.random.uniform()*2*var2-var2]),tn.tensor([np.random.uniform()*2*var3-var3]),tn.tensor([np.random.uniform()*2*var4-var4])]
    line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

    # line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_params.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r')

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
plt.text(0.03*1e3,0.035*1e3,r'$\Gamma_D$')
plt.text(0.014*1e3,0.0008*1e3,r'$\Gamma_N$')
plt.text(0.045*1e3,0.025*1e3,r'iron')
plt.text(0.041*1e3,0.005*1e3,r'Cu')
plt.text(0.015*1e3,0.005*1e3,r'air')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_section.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

pts = control_points([0,0,0,0])

plt.scatter(pts[0,...]*1e3, pts[1,...]*1e3)

plt.plot(pts[0,:,1]*1e3, pts[1,:,1]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,2]*1e3, pts[1,:,2]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,3]*1e3, pts[1,:,3]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,1,:]*1e3, pts[1,1,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,2,:]*1e3, pts[1,2,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,3,:]*1e3, pts[1,3,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,4,:]*1e3, pts[1,4,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,5,:]*1e3, pts[1,5,:]*1e3,'gray',linewidth=0.5)

for i in range(5): 
    for j in range(7): 
        plt.text(pts[0,j,i]*1e3+1,pts[1,j,i]*1e3,'(%d,%d)'%(j+1,i+1), fontsize = 10)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
tikzplotlib.save('quad_points.tex')

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))

tme = datetime.datetime.now()
Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
tme = datetime.datetime.now() - tme
print('Time mass ', tme)
tme = datetime.datetime.now()
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-10, func_reference=mu_ref, qtt = True, verb = True)
tme = datetime.datetime.now() - tme
print('Time stiffness ', tme)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[1])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4) / Mass_tt.N[0]

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-10)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-10)

print('System matrix... ',flush=True)

print('Rank Stiff', Stiff_tt.R, ' storage [MB] ',tntt.numel(Stiff_tt)*8/1e6)
print('Rank Mass', Mass_tt.R, ' storage [MB] ',tntt.numel(Mass_tt)*8/1e6)
print('Rank Mtt ',M_tt.R, ' storage [MB] ',tntt.numel(M_tt)*8/1e6)
print('Rank rhstt ',rhs_tt.R, ' storage [MB] ',tntt.numel(rhs_tt)*8/1e6)
# Out:
# Time mass  0:00:01.797690
# time omega 0:00:01.666152
# rank omega, [1, 18, 22, 11, 4, 2, 1]
# QTT enabled:
# [240, 236, 10, 10, 10, 10]
#   ||
#   \/
# [2, 2, 2, 2, 3, 5, 2, 2, 59, 2, 5, 2, 5, 2, 5, 2, 5]
# rank of Ftt is  [1, 3, 1, 1, 1, 1, 1]
# alpha, beta =  0 0
# 	time 1  0:00:00.598594
# 	time 2  0:00:09.860209  rank  [1, 4, 16, 56, 144, 336, 276, 436, 678, 99, 218, 87, 178, 77, 100, 10, 10, 1]
# 		time  0:00:00.106969
# 	time 4  0:00:00.111380
# alpha, beta =  0 1
# 	time 1  0:00:00.570258
# 	time 2  0:00:12.025580  rank  [1, 4, 16, 56, 144, 336, 300, 468, 756, 110, 236, 96, 196, 85, 100, 10, 10, 1]
# 		time  0:00:00.127881
# 	time 4  0:00:00.219996
# 	time ROUND  0:00:00.723921
# alpha, beta =  1 0
# 	time 1  0:00:00.564790
# 	time 2  0:00:12.391857  rank  [1, 4, 16, 56, 144, 336, 300, 468, 756, 110, 236, 96, 196, 85, 100, 10, 10, 1]
# 		time  0:00:00.128130
# 	time 4  0:00:00.193140
# alpha, beta =  1 1
# 	time 1  0:00:00.553789
# 	time 2  0:00:09.099557  rank  [1, 4, 16, 56, 144, 336, 264, 412, 696, 99, 212, 86, 176, 77, 100, 10, 10, 1]
# 		time  0:00:00.117858
# 	time 4  0:00:00.265535
# 	time ROUND  0:00:01.070771
# Time stiffness  0:00:54.042995
# System matrix...
# Rank Stiff [1, 92, 86, 61, 26, 7, 1]  storage [MB]  267.891872
# Rank Mass [1, 18, 22, 11, 4, 2, 1]  storage [MB]  13.802752
# Rank Mtt  [1, 90, 83, 59, 26, 7, 1]  storage [MB]  253.02208
# Rank rhstt  [1, 3, 6, 6, 10, 4, 1]  storage [MB]  0.021952

# %%
tme = datetime.datetime.now() 
# dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp = 50, kickrank = 4, preconditioner = 'c', verbose = False).cpu()
# dofs_tt = tntt.reshape(tntt.solvers.amen_solve(tntt.reshape(M_tt,[(2,2)]*21).round(1e-12).cuda(), tntt.reshape(rhs_tt,[2]*21).round(1e-12).cuda(), x0 = tntt.reshape(tntt.ones(rhs_tt.N),[2]*21).cuda(), eps = 1e-6, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True),rhs_tt.N).round(1e-12)
# dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = 1e-7, rmax = 400, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True).cpu()
dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), rmax = 300, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.solvers.amen_solve(tntt.reshape(M_tt,[(8,8)]*8).round(1e-10).cuda(), tntt.reshape(rhs_tt,[8]*8).round(1e-10).cuda(), x0 = tntt.reshape(dofs_tt,[8]*8).round(1e-8).cuda(), rmax = 600, eps = 1e-7, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.reshape(dofs_tt,M_tt.N)
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 64)....
# 		dx = 399.438, res_now = 7.9592e-14, res_old = 0.999715
# 	Core 1
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.0050889 (from 1.70676e-08)
# 		Time needed  0:00:00.343741
# 		dx = 0.349938, res_now = 0.0050889, res_old = 11.9597
# 	Core 2
# 		Choosing direct solver (local size 90)....
# 		dx = 0.0316694, res_now = 2.12649e-16, res_old = 0.588893
# 	Core 3
# 		Choosing direct solver (local size 90)....
# 		dx = 0.0188641, res_now = 4.80936e-16, res_old = 1.56131
# 	Core 4
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00252054, res_now = 1.39199e-16, res_old = 0.279057
# 	Core 5
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00261048, res_now = 2.48875e-16, res_old = 0.652769
# Solution rank is [1, 9, 9, 9, 9, 9, 1]
# Maxres  tensor(11.9597, device='cuda:0')
# Time  0:00:00.437445
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.0014371 (from 3.37958e-08)
# 		Time needed  0:00:00.225045
# 		dx = 0.0539264, res_now = 0.0014371, res_old = 6.03992
# 	Core 1
# 		Choosing iterative solver GMRES (local size 9792)....
# 		Finished with flag 0 after 80 iterations with relres 0.00279692 (from 1.21209e-07)
# 		Time needed  0:00:02.224335
# 		dx = 0.0226087, res_now = 0.00279692, res_old = 1.68407
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 31 iterations with relres 1.93935e-07 (from 5.09425e-06)
# 		Time needed  0:00:00.096490
# 		dx = 0.000829861, res_now = 1.93935e-07, res_old = 0.0400695
# 	Core 3
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 37 iterations with relres 1.9328e-07 (from 5.75954e-06)
# 		Time needed  0:00:00.096895
# 		dx = 0.000326935, res_now = 1.9328e-07, res_old = 0.0354411
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 24 iterations with relres 1.80365e-07 (from 0.000167606)
# 		Time needed  0:00:00.047528
# 		dx = 1.91215e-05, res_now = 1.80365e-07, res_old = 0.00121788
# 	Core 5
# 		Choosing direct solver (local size 170)....
# 		dx = 1.08085e-08, res_now = 1.52696e-16, res_old = 1.82642e-07
# Solution rank is [1, 17, 17, 17, 17, 17, 1]
# Maxres  tensor(6.0399, device='cuda:0')
# Time  0:00:02.896222
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 0 after 80 iterations with relres 0.000661008 (from 2.75306e-06)
# 		Time needed  0:00:00.227179
# 		dx = 0.00932808, res_now = 0.000661008, res_old = 0.0741446
# 	Core 1
# 		Choosing iterative solver GMRES (local size 27200)....
# 		Finished with flag 0 after 80 iterations with relres 0.000836251 (from 2.3896e-06)
# 		Time needed  0:00:05.179668
# 		dx = 0.00368496, res_now = 0.000836251, res_old = 0.085422
# 	Core 2
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 0 after 80 iterations with relres 3.16562e-07 (from 0.000130693)
# 		Time needed  0:00:00.284242
# 		dx = 0.000253679, res_now = 3.16562e-07, res_old = 0.00156185
# 	Core 3
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 1 after 59 iterations with relres 2.02687e-07 (from 0.000851162)
# 		Time needed  0:00:00.144985
# 		dx = 8.05457e-06, res_now = 2.02687e-07, res_old = 0.000239818
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2500)....
# 		Finished with flag 1 after 2 iterations with relres 1.36124e-07 (from 0.278311)
# 		Time needed  0:00:00.005313
# 		dx = 1.00776e-08, res_now = 1.36124e-07, res_old = 7.33438e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.3953e-08, res_now = 2.13536e-16, res_old = 1.40372e-07
# Solution rank is [1, 25, 25, 25, 25, 18, 1]
# Maxres  tensor(0.0854, device='cuda:0')
# Time  0:00:06.179329
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 0 after 80 iterations with relres 7.25824e-05 (from 3.4976e-05)
# 		Time needed  0:00:00.227381
# 		dx = 0.000545367, res_now = 7.25824e-05, res_old = 0.00583613
# 	Core 1
# 		Choosing iterative solver GMRES (local size 52800)....
# 		Finished with flag 0 after 80 iterations with relres 0.000227825 (from 1.62665e-05)
# 		Time needed  0:00:09.622374
# 		dx = 0.000643892, res_now = 0.000227825, res_old = 0.0125487
# 	Core 2
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 0 after 80 iterations with relres 7.39484e-07 (from 0.000673451)
# 		Time needed  0:00:00.336324
# 		dx = 0.000118132, res_now = 7.39484e-07, res_old = 0.000303102
# 	Core 3
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 1 after 34 iterations with relres 1.94125e-07 (from 0.0192196)
# 		Time needed  0:00:00.094528
# 		dx = 1.03885e-06, res_now = 1.94125e-07, res_old = 1.06206e-05
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3300)....
# 		Finished with flag 1 after 2 iterations with relres 1.99741e-07 (from 0.798782)
# 		Time needed  0:00:00.005292
# 		dx = 1.22073e-08, res_now = 1.99741e-07, res_old = 2.55544e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 8.92255e-08, res_now = 1.19683e-16, res_old = 2.06337e-07
# Solution rank is [1, 33, 33, 33, 33, 18, 1]
# Maxres  tensor(0.0125, device='cuda:0')
# Time  0:00:10.788096
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 0 after 80 iterations with relres 2.08573e-05 (from 0.000172366)
# 		Time needed  0:00:00.230804
# 		dx = 0.000119413, res_now = 2.08573e-05, res_old = 0.00118425
# 	Core 1
# 		Choosing iterative solver GMRES (local size 86592)....
# 		Finished with flag 0 after 80 iterations with relres 8.82475e-05 (from 8.31521e-05)
# 		Time needed  0:00:15.307339
# 		dx = 0.000126723, res_now = 8.82475e-05, res_old = 0.00245483
# 	Core 2
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 0 after 80 iterations with relres 5.02751e-07 (from 0.00189193)
# 		Time needed  0:00:00.430105
# 		dx = 4.95664e-05, res_now = 5.02751e-07, res_old = 0.000107892
# 	Core 3
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 1 after 37 iterations with relres 1.99276e-07 (from 0.0517109)
# 		Time needed  0:00:00.123957
# 		dx = 1.21492e-06, res_now = 1.99276e-07, res_old = 3.94741e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4100)....
# 		Finished with flag 1 after 0 iterations with relres 1.85155e-07 (from 0.925616)
# 		Time needed  0:00:00.003468
# 		dx = 3.17203e-09, res_now = 1.85155e-07, res_old = 2.20528e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.70873e-08, res_now = 1.48744e-16, res_old = 1.92089e-07
# Solution rank is [1, 41, 41, 41, 41, 18, 1]
# Maxres  tensor(0.0025, device='cuda:0')
# Time  0:00:16.822329
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 0 after 80 iterations with relres 8.01304e-06 (from 0.000696941)
# 		Time needed  0:00:00.231966
# 		dx = 3.873e-05, res_now = 8.01304e-06, res_old = 0.000292886
# 	Core 1
# 		Choosing iterative solver GMRES (local size 128576)....
# 		Finished with flag 0 after 80 iterations with relres 4.51855e-05 (from 0.000228439)
# 		Time needed  0:00:22.586249
# 		dx = 6.10187e-05, res_now = 4.51855e-05, res_old = 0.000893562
# 	Core 2
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 0 after 80 iterations with relres 3.6369e-07 (from 0.00425418)
# 		Time needed  0:00:00.575930
# 		dx = 2.74339e-05, res_now = 3.6369e-07, res_old = 4.7982e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 1 after 17 iterations with relres 2.0326e-07 (from 0.274773)
# 		Time needed  0:00:00.075509
# 		dx = 1.59002e-07, res_now = 2.0326e-07, res_old = 7.42882e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4900)....
# 		Finished with flag 1 after 0 iterations with relres 1.91885e-07 (from 0.987541)
# 		Time needed  0:00:00.003510
# 		dx = 3.14864e-09, res_now = 1.91885e-07, res_old = 2.06699e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.6346e-08, res_now = 1.83757e-16, res_old = 1.99792e-07
# Solution rank is [1, 49, 49, 49, 49, 18, 1]
# Maxres  tensor(0.0009, device='cuda:0')
# Time  0:00:24.470807
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 0 after 80 iterations with relres 4.74462e-06 (from 0.00194168)
# 		Time needed  0:00:00.227523
# 		dx = 1.56275e-05, res_now = 4.74462e-06, res_old = 0.000105127
# 	Core 1
# 		Choosing iterative solver GMRES (local size 178752)....
# 		Finished with flag 0 after 80 iterations with relres 2.4165e-05 (from 0.000397767)
# 		Time needed  0:00:31.547680
# 		dx = 2.98774e-05, res_now = 2.4165e-05, res_old = 0.000513175
# 	Core 2
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 0 after 80 iterations with relres 4.52189e-07 (from 0.00810693)
# 		Time needed  0:00:00.728361
# 		dx = 1.13458e-05, res_now = 4.52189e-07, res_old = 2.5179e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 1 after 32 iterations with relres 1.98921e-07 (from 0.394411)
# 		Time needed  0:00:00.156163
# 		dx = 1.0509e-06, res_now = 1.98921e-07, res_old = 5.17541e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 5700)....
# 		Finished with flag 1 after 0 iterations with relres 1.98252e-07 (from 0.99373)
# 		Time needed  0:00:00.004257
# 		dx = 3.24033e-09, res_now = 1.98252e-07, res_old = 2.05412e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.30916e-08, res_now = 2.34422e-16, res_old = 2.0517e-07
# Solution rank is [1, 57, 57, 57, 57, 18, 1]
# Maxres  tensor(0.0005, device='cuda:0')
# Time  0:00:33.990558
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 0 after 80 iterations with relres 2.14789e-06 (from 0.00321012)
# 		Time needed  0:00:00.219724
# 		dx = 1.02825e-05, res_now = 2.14789e-06, res_old = 6.35877e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 233472)....
# 		Finished with flag 0 after 80 iterations with relres 1.51163e-05 (from 0.000687014)
# 		Time needed  0:00:40.512351
# 		dx = 1.64005e-05, res_now = 1.51163e-05, res_old = 0.000297118
# 	Core 2
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 0 after 80 iterations with relres 3.45659e-07 (from 0.0131076)
# 		Time needed  0:00:00.979051
# 		dx = 5.6778e-06, res_now = 3.45659e-07, res_old = 1.55729e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 1 after 25 iterations with relres 2.00936e-07 (from 0.543073)
# 		Time needed  0:00:00.154369
# 		dx = 4.85872e-07, res_now = 2.00936e-07, res_old = 3.75869e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 6500)....
# 		Finished with flag 1 after 0 iterations with relres 2.0198e-07 (from 0.973785)
# 		Time needed  0:00:00.003485
# 		dx = 3.7896e-09, res_now = 2.0198e-07, res_old = 2.09619e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.62353e-08, res_now = 1.12153e-16, res_old = 2.10385e-07
# Solution rank is [1, 64, 65, 65, 65, 18, 1]
# Maxres  tensor(0.0003, device='cuda:0')
# Time  0:00:43.536098
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 1.529e-06 (from 0.00385926)
# 		Time needed  0:00:00.221765
# 		dx = 7.24017e-06, res_now = 1.529e-06, res_old = 5.2892e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 266240)....
# 		Finished with flag 0 after 80 iterations with relres 9.59728e-06 (from 0.00133676)
# 		Time needed  0:00:46.381393
# 		dx = 1.02137e-05, res_now = 9.59728e-06, res_old = 0.0001527
# 	Core 2
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 0 after 80 iterations with relres 3.03371e-07 (from 0.0208714)
# 		Time needed  0:00:01.336060
# 		dx = 3.32471e-06, res_now = 3.03371e-07, res_old = 9.78009e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 1 after 20 iterations with relres 2.01211e-07 (from 0.580796)
# 		Time needed  0:00:00.167415
# 		dx = 2.01042e-07, res_now = 2.01211e-07, res_old = 3.51456e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 7300)....
# 		Finished with flag 1 after 0 iterations with relres 2.01393e-07 (from 0.969436)
# 		Time needed  0:00:00.003756
# 		dx = 2.41148e-09, res_now = 2.01393e-07, res_old = 2.1056e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.62583e-08, res_now = 1.89551e-16, res_old = 2.11475e-07
# Solution rank is [1, 64, 73, 73, 73, 18, 1]
# Maxres  tensor(0.0002, device='cuda:0')
# Time  0:00:50.064123
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 8.30624e-07 (from 0.00463977)
# 		Time needed  0:00:00.220267
# 		dx = 4.28494e-06, res_now = 8.30624e-07, res_old = 4.39944e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 299008)....
# 		Finished with flag 0 after 80 iterations with relres 6.35233e-06 (from 0.00197389)
# 		Time needed  0:00:52.013358
# 		dx = 5.63303e-06, res_now = 6.35233e-06, res_old = 0.000103412
# 	Core 2
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 0 after 80 iterations with relres 2.59258e-07 (from 0.0313223)
# 		Time needed  0:00:01.539983
# 		dx = 2.19091e-06, res_now = 2.59258e-07, res_old = 6.5169e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 1 after 14 iterations with relres 2.03529e-07 (from 0.64242)
# 		Time needed  0:00:00.154815
# 		dx = 5.2209e-08, res_now = 2.03529e-07, res_old = 3.17742e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8100)....
# 		Finished with flag 1 after 1 iterations with relres 2.02665e-07 (from 0.95341)
# 		Time needed  0:00:00.004432
# 		dx = 4.27132e-09, res_now = 2.02665e-07, res_old = 2.14099e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.53479e-08, res_now = 1.37396e-16, res_old = 2.13728e-07
# Solution rank is [1, 64, 81, 81, 81, 18, 1]
# Maxres  tensor(0.0001, device='cuda:0')
# Time  0:00:56.092865
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 4.38374e-07 (from 0.00770064)
# 		Time needed  0:00:00.220975
# 		dx = 2.59971e-06, res_now = 4.38374e-07, res_old = 2.65074e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 331776)....
# 		Finished with flag 0 after 80 iterations with relres 4.34207e-06 (from 0.00338299)
# 		Time needed  0:00:58.105824
# 		dx = 3.9393e-06, res_now = 4.34207e-06, res_old = 6.03383e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 0 after 80 iterations with relres 3.18051e-07 (from 0.0457398)
# 		Time needed  0:00:01.872916
# 		dx = 1.68084e-06, res_now = 3.18051e-07, res_old = 4.46273e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 1 after 23 iterations with relres 2.04098e-07 (from 0.562203)
# 		Time needed  0:00:00.283278
# 		dx = 1.14551e-07, res_now = 2.04098e-07, res_old = 3.63079e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8900)....
# 		Finished with flag 1 after 1 iterations with relres 2.0193e-07 (from 0.964576)
# 		Time needed  0:00:00.004447
# 		dx = 2.41315e-09, res_now = 2.0193e-07, res_old = 2.11621e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.88033e-08, res_now = 1.52076e-16, res_old = 2.15862e-07
# Solution rank is [1, 64, 89, 89, 89, 18, 1]
# Maxres  tensor(6.0338e-05, device='cuda:0')
# Time  0:01:02.862372
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.63735e-07 (from 0.0101729)
# 		Time needed  0:00:00.220963
# 		dx = 1.48496e-06, res_now = 2.63735e-07, res_old = 2.00655e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 364544)....
# 		Finished with flag 0 after 80 iterations with relres 3.02528e-06 (from 0.00516766)
# 		Time needed  0:01:02.686574
# 		dx = 2.58126e-06, res_now = 3.02528e-06, res_old = 3.95003e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 1 after 80 iterations with relres 1.98001e-07 (from 0.065315)
# 		Time needed  0:00:02.280823
# 		dx = 1.07741e-06, res_now = 1.98001e-07, res_old = 3.12523e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 1 after 0 iterations with relres 2.01838e-07 (from 0.707783)
# 		Time needed  0:00:00.059612
# 		dx = 1.57989e-10, res_now = 2.01838e-07, res_old = 2.88399e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 9700)....
# 		Finished with flag 1 after 0 iterations with relres 1.9286e-07 (from 0.985406)
# 		Time needed  0:00:00.003678
# 		dx = 1.31481e-09, res_now = 1.9286e-07, res_old = 2.07147e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 8.46307e-08, res_now = 1.48212e-16, res_old = 2.05611e-07
# Solution rank is [1, 64, 97, 97, 97, 18, 1]
# Maxres  tensor(3.9500e-05, device='cuda:0')
# Time  0:01:07.823251
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 66 iterations with relres 2.04084e-07 (from 0.0183869)
# 		Time needed  0:00:00.171313
# 		dx = 7.57623e-07, res_now = 2.04084e-07, res_old = 1.11016e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 397312)....
# 		Finished with flag 0 after 80 iterations with relres 2.16622e-06 (from 0.00928266)
# 		Time needed  0:01:08.740414
# 		dx = 1.5891e-06, res_now = 2.16622e-06, res_old = 2.19898e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 1 after 76 iterations with relres 2.021e-07 (from 0.0923905)
# 		Time needed  0:00:02.646324
# 		dx = 6.20534e-07, res_now = 2.021e-07, res_old = 2.20936e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 1 after 0 iterations with relres 2.0194e-07 (from 0.967494)
# 		Time needed  0:00:00.074670
# 		dx = 1.97959e-10, res_now = 2.0194e-07, res_old = 2.10982e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10500)....
# 		Finished with flag 1 after 0 iterations with relres 1.96089e-07 (from 0.968737)
# 		Time needed  0:00:00.004290
# 		dx = 1.62636e-09, res_now = 1.96089e-07, res_old = 2.10712e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 6.86952e-08, res_now = 1.93747e-16, res_old = 2.08177e-07
# Solution rank is [1, 64, 105, 105, 105, 18, 1]
# Maxres  tensor(2.1990e-05, device='cuda:0')
# Time  0:01:14.450665
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 40 iterations with relres 1.99247e-07 (from 0.0276264)
# 		Time needed  0:00:00.120971
# 		dx = 5.46006e-07, res_now = 1.99247e-07, res_old = 7.38874e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 430080)....
# 		Finished with flag 0 after 80 iterations with relres 1.59572e-06 (from 0.0132901)
# 		Time needed  0:01:14.442477
# 		dx = 1.08676e-06, res_now = 1.59572e-06, res_old = 1.53592e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 118650)....
# 		Finished with flag 1 after 61 iterations with relres 2.01094e-07 (from 0.123802)
# 		Time needed  0:00:02.482756
# 		dx = 3.16797e-07, res_now = 2.01094e-07, res_old = 1.64879e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 113000)....
# 		Finished with flag 1 after 0 iterations with relres 2.02183e-07 (from 0.938144)
# 		Time needed  0:00:00.081368
# 		dx = 1.64302e-10, res_now = 2.02183e-07, res_old = 2.17583e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.9756e-07 (from 0.976302)
# 		Time needed  0:00:00.004362
# 		dx = 9.5356e-10, res_now = 1.9756e-07, res_old = 2.09079e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.79025e-08, res_now = 2.09957e-16, res_old = 2.11289e-07
# Solution rank is [1, 64, 113, 113, 108, 18, 1]
# Maxres  tensor(1.5359e-05, device='cuda:0')
# Time  0:01:20.159010
#
# Starting sweep 14 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 28 iterations with relres 2.01434e-07 (from 0.0445308)
# 		Time needed  0:00:00.077391
# 		dx = 3.49186e-07, res_now = 2.01434e-07, res_old = 4.58389e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 462848)....
# 		Finished with flag 0 after 80 iterations with relres 1.1332e-06 (from 0.0225742)
# 		Time needed  0:01:20.168345
# 		dx = 9.01504e-07, res_now = 1.1332e-06, res_old = 9.04237e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 136730)....
# 		Finished with flag 1 after 47 iterations with relres 2.03862e-07 (from 0.175137)
# 		Time needed  0:00:02.280837
# 		dx = 1.67884e-07, res_now = 2.03862e-07, res_old = 1.16551e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 121000)....
# 		Finished with flag 1 after 1 iterations with relres 2.02562e-07 (from 0.926845)
# 		Time needed  0:00:00.100297
# 		dx = 3.22061e-10, res_now = 2.02562e-07, res_old = 2.20235e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.88501e-07 (from 0.96711)
# 		Time needed  0:00:00.004341
# 		dx = 1.52012e-09, res_now = 1.88501e-07, res_old = 2.11066e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 2.21659e-08, res_now = 1.32959e-16, res_old = 2.01482e-07
# Solution rank is [1, 64, 121, 121, 108, 18, 1]
# Maxres  tensor(9.0424e-06, device='cuda:0')
# Time  0:01:25.874563
#
# Starting sweep 15 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 23 iterations with relres 2.00703e-07 (from 0.0422015)
# 		Time needed  0:00:00.062759
# 		dx = 2.50757e-07, res_now = 2.00703e-07, res_old = 4.83689e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 495616)....
# 		Finished with flag 0 after 80 iterations with relres 7.93156e-07 (from 0.0240427)
# 		Time needed  0:01:25.882587
# 		dx = 5.04715e-07, res_now = 7.93156e-07, res_old = 8.49008e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 156090)....
# 		Finished with flag 1 after 28 iterations with relres 2.03529e-07 (from 0.248351)
# 		Time needed  0:00:01.610451
# 		dx = 7.22311e-08, res_now = 2.03529e-07, res_old = 8.21918e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 129000)....
# 		Finished with flag 1 after 0 iterations with relres 2.03498e-07 (from 0.95238)
# 		Time needed  0:00:00.093987
# 		dx = 1.51233e-10, res_now = 2.03498e-07, res_old = 2.14331e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 2.01147e-07 (from 0.964188)
# 		Time needed  0:00:00.004570
# 		dx = 7.85902e-10, res_now = 2.01147e-07, res_old = 2.11706e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.18964e-08, res_now = 2.3001e-16, res_old = 2.15454e-07
# Solution rank is [1, 64, 129, 129, 108, 18, 1]
# Maxres  tensor(8.4901e-06, device='cuda:0')
# Time  0:01:31.143064
#
# Starting sweep 16 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 15 iterations with relres 1.91283e-07 (from 0.0799772)
# 		Time needed  0:00:00.043958
# 		dx = 1.18016e-07, res_now = 1.91283e-07, res_old = 2.55228e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 528384)....
# 		Finished with flag 0 after 80 iterations with relres 5.69136e-07 (from 0.0415221)
# 		Time needed  0:01:32.585055
# 		dx = 5.10647e-07, res_now = 5.69136e-07, res_old = 4.91604e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 176730)....
# 		Finished with flag 1 after 15 iterations with relres 2.04079e-07 (from 0.344631)
# 		Time needed  0:00:01.128187
# 		dx = 2.2886e-08, res_now = 2.04079e-07, res_old = 5.92299e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 137000)....
# 		Finished with flag 1 after 0 iterations with relres 2.00038e-07 (from 0.976737)
# 		Time needed  0:00:00.103111
# 		dx = 1.74853e-10, res_now = 2.00038e-07, res_old = 2.08986e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.80802e-07 (from 0.978458)
# 		Time needed  0:00:00.004547
# 		dx = 1.2599e-09, res_now = 1.80802e-07, res_old = 2.08618e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.21869e-08, res_now = 1.90432e-16, res_old = 1.92849e-07
# Solution rank is [1, 64, 137, 137, 108, 18, 1]
# Maxres  tensor(4.9160e-06, device='cuda:0')
# Time  0:01:37.606961
#
# Starting sweep 17 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 8 iterations with relres 1.92184e-07 (from 0.162026)
# 		Time needed  0:00:00.032018
# 		dx = 6.38365e-08, res_now = 1.92184e-07, res_old = 1.25982e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 561152)....
# 		Finished with flag 0 after 80 iterations with relres 4.01756e-07 (from 0.0710019)
# 		Time needed  0:01:38.332153
# 		dx = 4.32531e-07, res_now = 4.01756e-07, res_old = 2.87491e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 198650)....
# 		Finished with flag 1 after 6 iterations with relres 1.9829e-07 (from 0.483718)
# 		Time needed  0:00:00.709472
# 		dx = 3.59324e-09, res_now = 1.9829e-07, res_old = 4.2199e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 145000)....
# 		Finished with flag 1 after 0 iterations with relres 1.91461e-07 (from 1.00916)
# 		Time needed  0:00:00.107362
# 		dx = 1.32307e-10, res_now = 1.91461e-07, res_old = 2.02272e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.71874e-07 (from 1.02078)
# 		Time needed  0:00:00.004584
# 		dx = 1.08641e-09, res_now = 1.71874e-07, res_old = 1.99968e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.23603e-08, res_now = 1.6611e-16, res_old = 1.82444e-07
# Solution rank is [1, 64, 145, 145, 108, 18, 1]
# Maxres  tensor(2.8749e-06, device='cuda:0')
# Time  0:01:43.155418
#
# Starting sweep 18 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 3 iterations with relres 1.81323e-07 (from 0.352709)
# 		Time needed  0:00:00.025652
# 		dx = 3.66321e-08, res_now = 1.81323e-07, res_old = 5.78733e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 593920)....
# 		Finished with flag 0 after 80 iterations with relres 2.83409e-07 (from 0.140696)
# 		Time needed  0:01:44.092151
# 		dx = 3.22678e-07, res_now = 2.83409e-07, res_old = 1.45082e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 221850)....
# 		Finished with flag 1 after 2 iterations with relres 2.02698e-07 (from 0.713065)
# 		Time needed  0:00:00.516578
# 		dx = 9.9813e-10, res_now = 2.02698e-07, res_old = 2.86263e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 153000)....
# 		Finished with flag 1 after 0 iterations with relres 1.88011e-07 (from 1.0048)
# 		Time needed  0:00:00.114801
# 		dx = 1.32471e-10, res_now = 1.88011e-07, res_old = 2.03148e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.62233e-07 (from 1.041)
# 		Time needed  0:00:00.004430
# 		dx = 6.76449e-10, res_now = 1.62233e-07, res_old = 1.96084e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.08868e-08, res_now = 2.26782e-16, res_old = 1.73035e-07
# Solution rank is [1, 64, 153, 153, 108, 18, 1]
# Maxres  tensor(1.4508e-06, device='cuda:0')
# Time  0:01:48.955674
#
# Starting sweep 19 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.99216e-07 (from 0.659685)
# 		Time needed  0:00:00.023346
# 		dx = 1.6411e-08, res_now = 1.99216e-07, res_old = 3.09427e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 626688)....
# 		Finished with flag 0 after 80 iterations with relres 2.05233e-07 (from 0.207192)
# 		Time needed  0:01:49.885323
# 		dx = 2.16321e-07, res_now = 2.05233e-07, res_old = 9.85192e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 246330)....
# 		Finished with flag 1 after 0 iterations with relres 1.91673e-07 (from 0.976317)
# 		Time needed  0:00:00.420874
# 		dx = 1.1191e-10, res_now = 1.91673e-07, res_old = 2.09076e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 161000)....
# 		Finished with flag 1 after 0 iterations with relres 1.75571e-07 (from 1.05355)
# 		Time needed  0:00:00.122434
# 		dx = 1.30901e-10, res_now = 1.75571e-07, res_old = 1.93748e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.60337e-07 (from 1.11862)
# 		Time needed  0:00:00.004443
# 		dx = 4.35727e-10, res_now = 1.60337e-07, res_old = 1.82478e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 9.28126e-09, res_now = 1.69221e-16, res_old = 1.7054e-07
# Solution rank is [1, 64, 161, 161, 108, 18, 1]
# Maxres  tensor(9.8519e-07, device='cuda:0')
# Time  0:01:54.905312
#
# Starting sweep 20 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.68955e-07 (from 1.00111)
# 		Time needed  0:00:00.004724
# 		dx = 3.21257e-09, res_now = 1.68955e-07, res_old = 2.03898e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 659456)....
# 		Finished with flag 1 after 3 iterations with relres 2.03835e-07 (from 0.261365)
# 		Time needed  0:00:10.650002
# 		dx = 5.30403e-09, res_now = 2.03835e-07, res_old = 7.80994e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 259210)....
# 		Finished with flag 1 after 0 iterations with relres 1.24896e-07 (from 1.50736)
# 		Time needed  0:00:00.429838
# 		dx = 7.96736e-11, res_now = 1.24896e-07, res_old = 1.35419e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 161000)....
# 		Finished with flag 1 after 0 iterations with relres 8.71752e-08 (from 2.2194)
# 		Time needed  0:00:00.120807
# 		dx = 5.22667e-11, res_now = 8.71752e-08, res_old = 9.19728e-08
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10000)....
# 		Finished with flag 1 after 0 iterations with relres 4.81221e-08 (from 4.17965)
# 		Time needed  0:00:00.003860
# 		dx = 1.53297e-10, res_now = 4.81221e-08, res_old = 4.88376e-08
# 	Core 5
# 		Choosing direct solver (local size 100)....
# 		dx = 4.50511e-09, res_now = 1.06439e-16, res_old = 4.96353e-09
# Solution rank is [1, 64, 161, 161, 100, 10, 1]
# Maxres  tensor(7.8099e-07, device='cuda:0')
# Time  0:00:15.604816
#
# Finished after 20  sweeps and  0:19:07.830061
#
# Time system solve  0:19:10.325155

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt.round(1e-10)

plt.figure()
y1, y2 = basis_solution[0].collocation_points(3)[0], basis_solution[1].collocation_points(3)[0]
w1, w2 = basis_solution[0].collocation_points(3)[1], basis_solution[1].collocation_points(3)[1]
ws = np.einsum('i,j->ij',w1,w2)
X1,X2 = geom([y1,y2]+[tn.tensor([0.0])]*4)
u = fspace([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
plt.contourf(X1.numpy().squeeze(), X2.numpy().squeeze(),u.numpy().squeeze(),levels=32)
plt.colorbar()

import pickle
dct = {'x1' : X1.numpy().squeeze(), 'x2' : X2.numpy().squeeze(), 'u' : u.numpy().squeeze(), 'ws' : ws}

    
u = fspace([tn.tensor([0.05]),tn.tensor([0.0]), tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10), tn.linspace(-0.001,0.001,10)])

def get_in_reference(x, param1):
    return 0.4*x/(3.27640e-2+param1)
    # return 0.1*x/(geom([tn.tensor([0.1]),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([param1]), tn.tensor([0.0])])[0].numpy().squeeze())

# %%
# y1, y2 = np.linspace(0,1,32), np.linspace(0.,1,32)
# 
# grad1, grad2 = geom.gradient_physical(basis_solution, fspace)
# 
# g2 = -grad1([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# g1 = grad2([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# x1,x2 = geom([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
# 
# plt.figure()
# plt.quiver(x1.numpy().flatten(),x2.numpy().flatten(),g1.numpy().flatten(),g2.numpy().flatten(),np.sqrt(g1.numpy().flatten()**2+g2.numpy().flatten()**2))
# plt.colorbar()
# 
# x1B, x2B = geom([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0])])
# 
# dct['x1B'] = x1B.numpy().squeeze()
# dct['x2B'] = x2B.numpy().squeeze()
# 
# g2 = -grad1([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# g1 = grad2([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# 
# dct['B1'] = g1
# dct['B2'] = g2
# 
# with open('quad_nominal.pkl','wb') as f:
#     pickle.dump(dct, f)

# %%
import pickle
with open(r"measurements2.pkl", "rb") as input_file:
    data = pickle.load(input_file)
x_positions = tn.tensor(data['x_positions'])

print(x_positions)
print(data['A'])
A_noise = data['A'] + np.random.normal(0,1e-7,size = data['A'].shape)
print(A_noise)

print(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten())
print('err',np.abs(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten() - data['A'])/np.max(np.abs(data['A'])) )
# Out:
# tensor([0.0000, 0.0015, 0.0030, 0.0045, 0.0060, 0.0075, 0.0090, 0.0105, 0.0120,
#         0.0135, 0.0150])
# [-1.85871461e-14  7.61105953e-06  3.04442879e-05  6.84996613e-05
#   1.21777168e-04  1.90276690e-04  2.73997576e-04  3.72937441e-04
#   4.87088973e-04  6.16432703e-04  7.60925385e-04]
# [1.22977773e-07 7.79545811e-06 3.04069020e-05 6.85840028e-05
#  1.21804090e-04 1.90201421e-04 2.73937390e-04 3.72989944e-04
#  4.86968201e-04 6.16342645e-04 7.61011710e-04]
# [-5.78051811e-13  7.61097648e-06  3.04442164e-05  6.84995909e-05
#   1.21777074e-04  1.90276559e-04  2.73997406e-04  3.72937245e-04
#   4.87088825e-04  6.16433126e-04  7.60926017e-04]
# err [7.35242478e-10 1.09135772e-07 9.38909548e-08 9.25411437e-08
#  1.23301084e-07 1.71236662e-07 2.24353850e-07 2.57817832e-07
#  1.94336133e-07 5.56407906e-07 8.31198016e-07]

# %%
sigma_noise = 1e-7



def likelihood_handle(params):

    s = tn.zeros((params.shape[0],))

    for k in range(len(x_positions)):
        argz = tn.hstack((tn.reshape(get_in_reference(x_positions[k],params[:,1]),[-1,1]) ,tn.zeros((params.shape[0],1)), params))
        A = fspace(argz)

        s = s + (A - A_noise[k])**2
    return tn.exp(-0.5/sigma_noise**2 * s)
        




def prior_handle(params):
    # return tn.ones((params.shape[0],))
    alpha = 5
    beta = 5
    scale = lambda p,v: (p+v)/2/v
    p1 = scale(params[:,0], var1)**(alpha-1)*(1-scale(params[:,0], var1))**(beta-1)
    p2 = scale(params[:,1], var2)**(alpha-1)*(1-scale(params[:,1], var2))**(beta-1)
    p3 = scale(params[:,2], var3)**(alpha-1)*(1-scale(params[:,2], var3))**(beta-1)
    p4 = scale(params[:,3], var4)**(alpha-1)*(1-scale(params[:,3], var4))**(beta-1)
    return p1*p2*p3*p4
    #return tn.exp(-1/(2*var*var)*(params[:,0]**2+params[:,1]**2+params[:,2]**2+params[:,3]**2))

def posterior_handle(params):
    print(params.shape)
    return prior_handle(params)* likelihood_handle(params)#+1e-101*(params[...,0]+params[...,1]+params[...,2]+params[...,3])
    # return tn.tensor(list(map((post), list(params))))

# %%
import TTCME

basis = [TTCME.basis.BSplineBasis(25,[-var1,var1],2), TTCME.basis.BSplineBasis(25,[-var2,var2],2), TTCME.basis.BSplineBasis(25,[-var3,var3],2), TTCME.basis.BSplineBasis(25,[-var4,var4],2)]
xs = tntt.meshgrid([tn.tensor(b.interpolation_pts[0]) for b in basis])
Mg = tntt.rank1TT([tn.tensor(b.interpolation_pts[1]) for b in basis])

paramz = tn.hstack(( tn.reshape(xs[0].full(),[-1,1]) , tn.reshape(xs[1].full(),[-1,1]) , tn.reshape(xs[2].full(),[-1,1]) , tn.reshape(xs[3].full(),[-1,1]) ))

vals = tn.reshape(posterior_handle(paramz),[25]*4)

posterior_pdf = TTCME.pdfTT(basis, variable_names= ['theta1', 'theta2', 'theta3', 'theta4'], dofs = tntt.TT(vals,eps = 1e-12))
#posterior_pdf = TTCME.pdfTT.interpoalte(posterior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
print(posterior_pdf)
# 
prior_pdf = TTCME.pdfTT.interpoalte(prior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
# Out:
# torch.Size([390625, 4])
# Probability density function:
# p(theta1,theta2,theta3,theta4)
#
# Basis:
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
# B-spline basis defined on [-0.00075, 0.00075] and dimension 25
#
# DoF:
# TT with sizes and ranks:
# N = [25, 25, 25, 25]
# R = [1, 1, 18, 19, 1]
#
# Device: cpu, dtype: torch.float64
# #entries 9500 compression 0.02432

# %%
posterior_pdf.normalize()

E = posterior_pdf.expected_value()
C = posterior_pdf.covariance_matrix()
V = np.diag(C)

print()
print('Exact parameters:                 ',[0,0,0,0])
print('')
print('Expected value computed posterior ' ,E)
print('Coariance computed posterior      ' ,C)

E = prior_pdf.expected_value()
C = prior_pdf.covariance_matrix()
V = np.diag(C)

print('')
print('Expected value prior              ' ,E)
print('Variance prior                    ' ,V)
# Out:
# Exact parameters:                  [0, 0, 0, 0]
#
# Expected value computed posterior  [tensor(8.2665e-20), tensor(-2.0211e-05), tensor(1.1465e-05), tensor(1.3219e-05)]
# Coariance computed posterior       tensor([[ 1.0633e-09,  7.2985e-26, -4.1401e-26, -4.7736e-26],
#         [ 7.2985e-26,  9.6665e-09,  7.1819e-09,  9.2786e-09],
#         [-4.1401e-26,  7.1819e-09,  5.1460e-08, -1.2742e-09],
#         [-4.7736e-26,  9.2786e-09, -1.2742e-09,  5.1022e-08]])
#
# Expected value prior               [tensor(-1.6274e-20), tensor(3.0760e-20), tensor(2.8945e-20), tensor(1.1986e-19)]
# Variance prior                     [5.11405107e-08 5.11405107e-08 5.11405107e-08 5.11405107e-08]

# %%
plt.figure(figsize = [6,6])
true_parameters = [0.0]*4
k = 0
for i in range(4):
    for j in range(4):
        k += 1
        if i==j:
            plt.subplot(4, 4, k)
            
            theta = np.linspace(basis[i].domain[0], basis[i].domain[1],1000)
            pr = prior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
            po = posterior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
           
            plt.plot(1e3*theta,1e3*(po/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)))
            plt.axvline(true_parameters[i],c='r',linestyle=':')
            plt.plot(1e3*theta,1e3*(pr/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)),'g:')
            
        else:
            plt.subplot(4, 4, k)
             
            if j<i: 
                theta1 = np.linspace(basis[j].domain[0], basis[j].domain[1], 127)
                theta2 = np.linspace(basis[i].domain[0], basis[i].domain[1], 128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T1, 1e3*T2, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
            else: 
                theta1 = np.linspace(basis[i].domain[0],basis[i].domain[1],127)
                theta2 = np.linspace(basis[j].domain[0],basis[j].domain[1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T2, 1e3*T1, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
        
        if i==3: plt.xlabel(r'$\theta_'+str(j+1)+'$ [mm]')
        if j==0: plt.ylabel(r'$\theta_'+str(i+1)+'$ [mm]')
        
        if j>0: plt.yticks([])
        if i<3: plt.xticks([])

plt.savefig('quad_posterior1.eps')
tikzplotlib.save('quad_posterior1.tex')

# %%
print('Rank solution ', dofs_tt.round(1e-10).R)
print('Storage solution ', tntt.numel(dofs_tt.round(1e-10))*8/1e6)
# Out:
# Rank solution  [1, 63, 141, 123, 54, 8, 1]
# Storage solution  6.534352

# %%
Dc = 3.27640e-2                                                           
# Dc = 32e-3
# hc = 7e-3
hc = 7.55176e-3                                                           
ri = 20e-3                                                           
                                                         
rm = ((Dc+var2)**2+hc*hc-(ri+var1)**2)/((Dc+var2)*np.sqrt(2)+hc*np.sqrt(2)-2*(ri+var1))                 


O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])

xc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[0].numpy().squeeze()
yc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[1].numpy().squeeze()
print(np.std(np.sqrt((xc-O[0])**2+(yc-O[1])**2)))
# Out:
# 7.515514033335292e-17
