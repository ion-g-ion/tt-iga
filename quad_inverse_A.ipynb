# %%
from webbrowser import get
import torchtt as tntt
import numpy as np
import tt_iga
import matplotlib.pyplot as plt
import torch as tn
import datetime

tn.set_default_dtype(tn.float64)

# %%
def create_geometry( ):
        
    Nt = 24                                                                
    lz = 40e-3                                                             
    Do = 72e-3                                                            
    Di = 51e-3                                                            
    hi = 13e-3                                                             
    bli = 3e-3                                                             
    Dc = 3.27640e-2                                                           
    # Dc = 32e-3
    # hc = 7e-3
    hc = 7.55176e-3                                                           
    ri = 20e-3                                                           
    ra = 18e-3                                                           
    blc = hi-hc                                                           
    rm = (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)                 
    R = rm-ri

    get_rO = lambda Ax,Ay,ri: (Ax**2+Ay**2-ri**2)/(np.sqrt(2)*(Ax+Ay)-2*ri)

    O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])
    alpha1 = -np.pi*3/4       
    alpha2 = np.math.asin((hc-rm/np.sqrt(2))/R)
    alpha = np.abs(alpha2-alpha1)
    
    A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
    b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
    C = np.linalg.solve(A,b)

    def Cx(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[0]

    def Cy(ri,Dc,hc):
        O = [((Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri) )/np.sqrt(2),( (Dc*Dc+hc*hc-ri*ri)/(Dc*np.sqrt(2)+hc*np.sqrt(2)-2*ri)  )/np.sqrt(2)]
        A = np.array([[O[0] - ri/np.sqrt(2), O[1] - ri/np.sqrt(2)], [O[0] - Dc, O[1] - hc]])
        b = np.array([[A[0,0]*ri/np.sqrt(2)+A[0,1]*ri/np.sqrt(2)],[A[1,0]*Dc+A[1,1]*hc]])
        C = np.linalg.solve(A,b)
        return C[1]

    control_points = tt_iga.geometry.ParameterDependentControlPoints([7,5])

    # params ri - 0 , Dc - 1 , Di - 2 
    control_points[:,0,0] = [0,0]
    control_points[:,1,0] = [lambda params: (Dc+params[1])/2, 0]
    control_points[:,2,0] = [lambda params: (Dc+params[1]), 0]
    control_points[:,3,0] = [(Dc+Di)/2,0]
    control_points[:,4,0] = [lambda params: Di+params[2],0]
    control_points[:,5,0] = [(Do+Di)/2,0]
    control_points[:,6,0] = [Do,0]
    
    control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    control_points[:,1,1] = [lambda params: (Cx(ri,Dc,hc)+Dc/2)*0.5, lambda params: Cy(ri,Dc,hc)*0.5]
    control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    control_points[:,6,1] = [Do,(hi-bli)*0.5]

    #control_points[:,0,1] = [lambda params: (ri+params[0])/np.sqrt(2)*0.5,lambda params: (ri+params[0])/np.sqrt(2)*0.5]
    #control_points[:,1,1] = [lambda params: (Cx(ri+params[0],Dc+params[1],hc)+(Dc+params[1])/2)*0.5, lambda params: Cy(ri+params[0],Dc+params[1],hc)*0.5]
    #control_points[:,2,1] = [lambda params: (Dc+params[1]), hc*0.5]
    #control_points[:,3,1] = [(Dc+Di)/2,0.5*(hi-bli+hc)*0.5]
    #control_points[:,4,1] = [lambda params: Di+params[2],(hi-bli)*0.5]
    #control_points[:,5,1] = [(Do+Di)/2,(hi-bli)*0.5]
    #control_points[:,6,1] = [Do,(hi-bli)*0.5]
    
    control_points[:,0,2] = [lambda params: (ri+params[0])/np.sqrt(2),lambda params: (ri+params[0])/np.sqrt(2)]
    control_points[:,1,2] = [lambda params: Cx(ri+params[0],Dc+params[1],hc), lambda params: Cy(ri+params[0],Dc+params[1],hc)]
    control_points[:,2,2] = [lambda params: (Dc+params[1]), hc]
    control_points[:,3,2] = [(Dc+Di)/2,0.5*(hi-bli+hc)]
    control_points[:,4,2] = [lambda params: Di+params[2],hi-bli]
    control_points[:,5,2] = [(Do+Di)/2,hi-bli]
    control_points[:,6,2] = [Do,hi-bli]
    
    control_points[:,0,3] = [(0.75*ri+0.25*Do)/np.sqrt(2),(0.75*ri+0.25*Do)/np.sqrt(2)]
    control_points[:,1,3] = [0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+Dc+blc), 0.5*((0.75*ri+0.25*Do)/np.sqrt(2)+hi)]
    control_points[:,2,3] = [Dc+blc,lambda params:  hi+params[3]]
    control_points[:,3,3] = [ 0.5*(Dc+blc+Di-bli),lambda params:  hi+params[3]]
    control_points[:,4,3] = [ Di-bli, lambda params: hi+params[3]]
    control_points[:,5,3] = [lambda params: 0.5*(Di+Do),hi]
    control_points[:,6,3] = [Do,hi]

    control_points[:,0,4] = [Do/np.sqrt(2), Do/np.sqrt(2)]
    control_points[:,1,4] = [Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*(0.5*Dc/Do), Do/np.sqrt(2)*(1-0.5*Dc/Do)+Do*np.tan(np.pi/8)*(0.5*Dc/Do)]
    control_points[:,2,4] = [Do/np.sqrt(2)*(1-Dc/Do)+Do*(Dc/Do), Do/np.sqrt(2)*(1-Dc/Do)+Do*np.tan(np.pi/8)*(Dc/Do)]
    control_points[:,3,4] = [Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*(0.5*(Dc+Di)/Do), Do/np.sqrt(2)*(1-0.5*(Dc+Di)/Do)+Do*np.tan(np.pi/8)*(0.5*(Dc+Di)/Do)]
    control_points[:,4,4] = [Do/np.sqrt(2)*(1-Di/Do)+Do*(Di/Do), Do/np.sqrt(2)*(1-Di/Do)+Do*np.tan(np.pi/8)*(Di/Do)]
    control_points[:,5,4] = [Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*(0.5*(Di+Do)/Do), Do/np.sqrt(2)*(1-0.5*(Di+Do)/Do)+Do*np.tan(np.pi/8)*(0.5*(Di+Do)/Do)]
    control_points[:,6,4] = [Do,Do*np.tan(np.pi/8)]

    weights = tt_iga.geometry.ParameterDependentWeights([7,5])
    weights[...] = 1.0
    alpha2 = lambda params: np.math.asin((hc-get_rO(Dc+params[1],hc,ri+params[0])/np.sqrt(2))/(get_rO(Dc+params[1],hc,ri+params[0])-ri-params[0]))
    weights[1,2] = lambda params :  np.sin((np.pi-np.abs(alpha2(params)+np.pi*3/4))/2)
    # weights[1,2] = lambda params :  np.abs(alpha2+np.pi*3/4)
    
    surface_excitation = lambda params: 0.5*(blc-params[...,1])*(hi+params[...,3]+hc)+(Di-bli-Dc-blc)*(hi+params[...,3])+0.5*(bli+params[...,2])*(hi+params[...,3]+hi-bli)
    return control_points, weights, surface_excitation

# %%
control_points, weights, surface = create_geometry()
print(surface(np.array([0.0,0.0,0.0,0.0])))

var1 = 0.00075
var2 = 0.00075
var3 = 0.00075
var4 = 0.00075
pts = control_points([0,0,0,0])
plt.figure()
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)
pts = control_points([0,-0.003,0,0])
plt.scatter(pts[0,...].flatten(),pts[1,...].flatten(),s=1)


basis1 = tt_iga.bspline.BSplineBasis(np.array([0,0.4,0.4,0.6,0.6,1]),2)
basis2 = tt_iga.bspline.BSplineBasis(np.array([0,0.15,0.3,0.5,1]),1)
basis = [basis1, basis2]
basis_solution = [tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.4,21), np.linspace(0.4,0.6,21),np.linspace(0.6,1,21))),2)]
basis_solution.append(tt_iga.bspline.BSplineBasis(np.concatenate((np.linspace(0,0.15,16),np.linspace(0.15,0.3,15), np.linspace(0.3,0.5,15),np.linspace(0.5,1,17))),2))

nl = 10
basis_param = [tt_iga.lagrange.LagrangeLeg(nl,[-var1,var1]), tt_iga.lagrange.LagrangeLeg(nl,[-var2,var2]), tt_iga.lagrange.LagrangeLeg(nl,[-var3,var3]), tt_iga.lagrange.LagrangeLeg(nl,[-var4,var4])]
geom = tt_iga.PatchNURBS.interpolate_parameter_dependent(control_points, weights, basis, basis_param, eps = 1e-13)

# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[0].numpy().squeeze())
# print(geom([tn.tensor([0.2]),tn.tensor([0.3])]+4*[tn.tensor([0.0])])[1].numpy().squeeze())
# 
# print(weights(np.zeros((4))))
# print(control_points(np.zeros((4)))[1,:,:])
# Out:
# 0.0002177263404511999

# %%
plt.figure()

for i in range(20):
    paramz = [tn.tensor([np.random.uniform()*2*var1-var1]),tn.tensor([np.random.uniform()*2*var2-var2]),tn.tensor([np.random.uniform()*2*var3-var3]),tn.tensor([np.random.uniform()*2*var4-var4])]
    line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

    # line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    # line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
    # plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)
    line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
    plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r', linewidth = 0.5)

paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_params.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,100),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0.4,0.6,100),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.linspace(0,1,100),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.linspace(0,1,100),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'r')

line = geom([tn.tensor([0.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([1.0]),tn.linspace(0,1,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'g')
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,100)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k')
plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
plt.text(0.03*1e3,0.035*1e3,r'$\Gamma_D$')
plt.text(0.014*1e3,0.0008*1e3,r'$\Gamma_N$')
plt.text(0.045*1e3,0.025*1e3,r'iron')
plt.text(0.041*1e3,0.005*1e3,r'Cu')
plt.text(0.015*1e3,0.005*1e3,r'air')
import tikzplotlib
# plt.savefig('quad_section.eps')
tikzplotlib.save('quad_section.tex')

plt.figure()
paramz = [tn.tensor([0]),tn.tensor([0]),tn.tensor([0]),tn.tensor([0])]
line = geom([tn.linspace(0,0.4,32),tn.tensor([0.3])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0.4,0.6,32),tn.tensor([0.5])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([1])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.linspace(0,1,32),tn.tensor([0.0])]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

line = geom([tn.tensor([0.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([1.0]),tn.linspace(0,1,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.4]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)
line = geom([tn.tensor([0.6]),tn.linspace(0,0.5,32)]+paramz)
plt.plot(line[0].numpy().squeeze()*1e3, line[1].numpy().squeeze()*1e3, 'k', linewidth = 2)

pts = control_points([0,0,0,0])

plt.scatter(pts[0,...]*1e3, pts[1,...]*1e3)

plt.plot(pts[0,:,1]*1e3, pts[1,:,1]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,2]*1e3, pts[1,:,2]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,:,3]*1e3, pts[1,:,3]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,1,:]*1e3, pts[1,1,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,2,:]*1e3, pts[1,2,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,3,:]*1e3, pts[1,3,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,4,:]*1e3, pts[1,4,:]*1e3,'gray',linewidth=0.5)
plt.plot(pts[0,5,:]*1e3, pts[1,5,:]*1e3,'gray',linewidth=0.5)

for i in range(5): 
    for j in range(7): 
        plt.text(pts[0,j,i]*1e3+1,pts[1,j,i]*1e3,'(%d,%d)'%(j+1,i+1), fontsize = 10)

plt.xlabel(r'$x_1$ [mm]')
plt.ylabel(r'$x_2$ [mm]')
tikzplotlib.save('quad_points.tex')

# %%
mu0 = 4*np.pi*1e-7
mur = 1500
mu_ref = lambda y: 1/mu0*((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))+1/(mu0*mur)*tn.logical_not((y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+(y[...,1]<0.3)*(y[...,0]<0.4))

tme = datetime.datetime.now()
Mass_tt = geom.mass_interp(basis_solution, eps = 1e-10)
tme = datetime.datetime.now() - tme
print('Time mass ', tme)
tme = datetime.datetime.now()
Stiff_tt = geom.stiffness_interp(basis_solution, eps = 1e-10, func_reference=mu_ref, qtt = True, verb = True, device = 'cuda:1')
tme = datetime.datetime.now() - tme
print('Time stiffness ', tme)

Jref = lambda y: 24*45/surface(y[...,2:])*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0
# Jref = lambda y: 5000000*(y[...,1]<0.5)*(y[...,0]<0.6)*(y[...,0]>0.4)+0.0

rhs_tt = geom.rhs_interp(basis_solution,Jref)

P1 = tn.eye(Mass_tt.N[0])
P2 = tn.eye(Mass_tt.N[1])
P2[-1,-1] = 0
P1[0,0] = 0
P1[-1,-1] = 0
Pin_tt = tntt.rank1TT([P1,P2]) ** tntt.eye([nl]*4)
Pbd_tt = (tntt.eye(Mass_tt.N) - Pin_tt) ** tntt.eye([nl]*4) / Mass_tt.N[0]

M_tt = (Pin_tt@Stiff_tt+Pbd_tt).round(1e-10)
rhs_tt = (Pin_tt @ rhs_tt + 0).round(1e-10)

print('System matrix... ',flush=True)

print('Rank Stiff', Stiff_tt.R, ' storage [MB] ',tntt.numel(Stiff_tt)*8/1e6)
print('Rank Mass', Mass_tt.R, ' storage [MB] ',tntt.numel(Mass_tt)*8/1e6)
print('Rank Mtt ',M_tt.R, ' storage [MB] ',tntt.numel(M_tt)*8/1e6)
print('Rank rhstt ',rhs_tt.R, ' storage [MB] ',tntt.numel(rhs_tt)*8/1e6)
# Out:
# Time mass  0:00:01.857122
# time omega 0:00:01.681015
# rank omega, [1, 18, 22, 11, 4, 2, 1]
# QTT enabled:
# [240, 236, 10, 10, 10, 10]
#   ||
#   \/
# [2, 2, 2, 2, 3, 5, 2, 2, 59, 2, 5, 2, 5, 2, 5, 2, 5]
# Sweep 1:
# 	LR supercore 1,2
# 		number evaluations 113280
# 		rank updated 2 -> 6, local error 1.000000e+00
# 	LR supercore 2,3
# 		number evaluations 28320
# 		rank updated 2 -> 4, local error 9.994338e-01
# 	LR supercore 3,4
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 1.181080e+00
# 	LR supercore 4,5
# 		number evaluations 800
# 		rank updated 2 -> 4, local error 1.277430e+00
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 2 -> 4, local error 9.362835e-01
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 4.765374e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 8.586975e-16
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 1.548741e-15
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 1.332355e-15
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 4.737387e-15
# Max error 1.27743
# Sweep 2:
# 	LR supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 4.735893e-15
# 	LR supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 3.347099e-15
# 	LR supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 3.459591e-15
# 	LR supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 2.668150e-15
# 	LR supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 5.746932e-15
# 	RL supercore 5,6
# 		number evaluations 400
# 		rank updated 4 -> 4, local error 2.636392e-16
# 	RL supercore 4,5
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 6.057715e-15
# 	RL supercore 3,4
# 		number evaluations 1600
# 		rank updated 4 -> 4, local error 6.440921e-15
# 	RL supercore 2,3
# 		number evaluations 56640
# 		rank updated 4 -> 4, local error 1.015369e-15
# 	RL supercore 1,2
# 		number evaluations 226560
# 		rank updated 6 -> 6, local error 2.700578e-15
# Max error 6.440921e-15 < 1.000000e-10  ---->  DONE
# number of function calls  1004000
#
# rank of Ftt is  [1, 3, 1, 1, 1, 1, 1]
# alpha, beta =  0 0
# 	time 1  0:00:00.595893
# 	time 2  0:00:05.229601  rank  [1, 4, 16, 64, 144, 384, 276, 436, 678, 99, 218, 87, 176, 77, 100, 10, 10, 1]
# 		time  0:00:00.120059
# 	time 4  0:00:00.126549
# alpha, beta =  0 1
# 	time 1  0:00:00.594537
# 	time 2  0:00:04.002790  rank  [1, 4, 16, 64, 144, 384, 300, 468, 756, 109, 234, 95, 194, 85, 100, 10, 10, 1]
# 		time  0:00:00.128735
# 	time 4  0:00:00.141936
# 	time ROUND  0:00:00.451509
# alpha, beta =  1 0
# 	time 1  0:00:00.616395
# 	time 2  0:00:03.944208  rank  [1, 4, 16, 64, 144, 384, 300, 468, 756, 109, 234, 95, 194, 85, 100, 10, 10, 1]
# 		time  0:00:00.138303
# 	time 4  0:00:00.138373
# alpha, beta =  1 1
# 	time 1  0:00:00.575367
# 	time 2  0:00:03.305639  rank  [1, 4, 16, 64, 144, 384, 264, 412, 696, 99, 212, 86, 176, 77, 100, 10, 10, 1]
# 		time  0:00:00.122753
# 	time 4  0:00:00.126467
# 	time ROUND  0:00:00.591054
# Time stiffness  0:00:26.509976
# System matrix...
# Rank Stiff [1, 92, 86, 61, 26, 7, 1]  storage [MB]  267.891872
# Rank Mass [1, 18, 22, 11, 4, 2, 1]  storage [MB]  13.802752
# Rank Mtt  [1, 90, 83, 59, 26, 7, 1]  storage [MB]  253.02208
# Rank rhstt  [1, 3, 6, 6, 10, 4, 1]  storage [MB]  0.021952

# %%
tme = datetime.datetime.now() 
dev_name = 'cuda:1'
# dofs_tt = tntt.solvers.amen_solve(M_tt.cuda(), rhs_tt.cuda(), x0 = tntt.ones(rhs_tt.N).cuda(), eps = eps_solver, nswp = 50, kickrank = 4, preconditioner = 'c', verbose = False).cpu()
# dofs_tt = tntt.reshape(tntt.solvers.amen_solve(tntt.reshape(M_tt,[(2,2)]*21).round(1e-12).cuda(), tntt.reshape(rhs_tt,[2]*21).round(1e-12).cuda(), x0 = tntt.reshape(tntt.ones(rhs_tt.N),[2]*21).cuda(), eps = 1e-6, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True),rhs_tt.N).round(1e-12)
# dofs_tt = tntt.solvers.amen_solve(M_tt, rhs_tt, x0 = tntt.ones(rhs_tt.N), eps = 1e-7, rmax = 400, nswp = 50, kickrank = 32, preconditioner = 'c', verbose = True).cpu()
dofs_tt = tntt.solvers.amen_solve(M_tt.to(dev_name), rhs_tt.to(dev_name), x0 = tntt.ones(rhs_tt.N).to(dev_name), rmax = 300, eps = 1e-6, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.solvers.amen_solve(tntt.reshape(M_tt,[(8,8)]*8).round(1e-10).cuda(), tntt.reshape(rhs_tt,[8]*8).round(1e-10).cuda(), x0 = tntt.reshape(dofs_tt,[8]*8).round(1e-8).cuda(), rmax = 600, eps = 1e-7, nswp = 50, kickrank = 8, preconditioner = 'c', verbose = True).cpu()
# dofs_tt = tntt.reshape(dofs_tt,M_tt.N)
tme = datetime.datetime.now() - tme
print('Time system solve ',tme,flush=True)
# Out:
# Starting sweep 0 ...
# 	Core 0
# 		Choosing direct solver (local size 64)....
# 		dx = 399.438, res_now = 1.27858e-13, res_old = 0.999715
# 	Core 1
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.0101659 (from 1.70482e-08)
# 		Time needed  0:00:00.287921
# 		dx = 0.349657, res_now = 0.0101659, res_old = 11.9734
# 	Core 2
# 		Choosing direct solver (local size 90)....
# 		dx = 0.033434, res_now = 2.12154e-16, res_old = 0.608279
# 	Core 3
# 		Choosing direct solver (local size 90)....
# 		dx = 0.0225796, res_now = 3.07297e-16, res_old = 1.58502
# 	Core 4
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00191867, res_now = 1.54119e-16, res_old = 0.271536
# 	Core 5
# 		Choosing direct solver (local size 90)....
# 		dx = 0.00204116, res_now = 1.69202e-16, res_old = 0.544611
# Solution rank is [1, 9, 9, 9, 9, 9, 1]
# Maxres  tensor(11.9734, device='cuda:1')
# Time  0:00:00.357134
#
# Starting sweep 1 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 576)....
# 		Finished with flag 0 after 80 iterations with relres 0.00348501 (from 3.89988e-08)
# 		Time needed  0:00:00.219823
# 		dx = 0.0727618, res_now = 0.00348501, res_old = 5.23412
# 	Core 1
# 		Choosing iterative solver GMRES (local size 9792)....
# 		Finished with flag 0 after 80 iterations with relres 0.00337524 (from 1.07842e-07)
# 		Time needed  0:00:00.422245
# 		dx = 0.0224182, res_now = 0.00337524, res_old = 1.89281
# 	Core 2
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 32 iterations with relres 1.75421e-07 (from 4.21707e-06)
# 		Time needed  0:00:00.083502
# 		dx = 0.000993426, res_now = 1.75421e-07, res_old = 0.0484043
# 	Core 3
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 55 iterations with relres 1.61688e-07 (from 8.69381e-06)
# 		Time needed  0:00:00.138066
# 		dx = 0.000207302, res_now = 1.61688e-07, res_old = 0.0234792
# 	Core 4
# 		Choosing iterative solver GMRES (local size 1530)....
# 		Finished with flag 1 after 26 iterations with relres 1.57309e-07 (from 2.8255e-05)
# 		Time needed  0:00:00.057237
# 		dx = 4.91239e-05, res_now = 1.57309e-07, res_old = 0.00722434
# 	Core 5
# 		Choosing direct solver (local size 170)....
# 		dx = 2.38522e-09, res_now = 2.06875e-16, res_old = 1.59769e-07
# Solution rank is [1, 17, 17, 17, 17, 17, 1]
# Maxres  tensor(5.2341, device='cuda:1')
# Time  0:00:01.013646
#
# Starting sweep 2 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1088)....
# 		Finished with flag 0 after 80 iterations with relres 0.000267498 (from 2.79516e-06)
# 		Time needed  0:00:00.252560
# 		dx = 0.00754169, res_now = 0.000267498, res_old = 0.0730277
# 	Core 1
# 		Choosing iterative solver GMRES (local size 27200)....
# 		Finished with flag 0 after 80 iterations with relres 0.000740694 (from 3.06802e-06)
# 		Time needed  0:00:00.770306
# 		dx = 0.00503313, res_now = 0.000740694, res_old = 0.0665329
# 	Core 2
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 0 after 80 iterations with relres 3.16308e-07 (from 8.89824e-05)
# 		Time needed  0:00:00.255550
# 		dx = 0.000303528, res_now = 3.16308e-07, res_old = 0.00229398
# 	Core 3
# 		Choosing iterative solver GMRES (local size 4250)....
# 		Finished with flag 1 after 60 iterations with relres 1.97317e-07 (from 0.00146812)
# 		Time needed  0:00:00.158636
# 		dx = 5.09082e-06, res_now = 1.97317e-07, res_old = 0.000139038
# 	Core 4
# 		Choosing iterative solver GMRES (local size 2500)....
# 		Finished with flag 1 after 8 iterations with relres 1.94621e-07 (from 0.0485999)
# 		Time needed  0:00:00.014738
# 		dx = 1.18347e-07, res_now = 1.94621e-07, res_old = 4.20009e-06
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.64684e-07, res_now = 1.89226e-16, res_old = 2.0098e-07
# Solution rank is [1, 25, 25, 25, 25, 18, 1]
# Maxres  tensor(0.0730, device='cuda:1')
# Time  0:00:01.576098
#
# Starting sweep 3 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 1600)....
# 		Finished with flag 0 after 80 iterations with relres 5.5849e-05 (from 3.07159e-05)
# 		Time needed  0:00:00.261214
# 		dx = 0.000399612, res_now = 5.5849e-05, res_old = 0.00664555
# 	Core 1
# 		Choosing iterative solver GMRES (local size 52800)....
# 		Finished with flag 0 after 80 iterations with relres 0.000261044 (from 2.05722e-05)
# 		Time needed  0:00:01.279406
# 		dx = 0.000820774, res_now = 0.000261044, res_old = 0.00992233
# 	Core 2
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 0 after 80 iterations with relres 5.38535e-07 (from 0.000622843)
# 		Time needed  0:00:00.233156
# 		dx = 0.000196348, res_now = 5.38535e-07, res_old = 0.00032773
# 	Core 3
# 		Choosing iterative solver GMRES (local size 8250)....
# 		Finished with flag 1 after 49 iterations with relres 1.89895e-07 (from 0.013989)
# 		Time needed  0:00:00.128198
# 		dx = 2.98768e-06, res_now = 1.89895e-07, res_old = 1.45918e-05
# 	Core 4
# 		Choosing iterative solver GMRES (local size 3300)....
# 		Finished with flag 1 after 5 iterations with relres 2.01175e-07 (from 0.767824)
# 		Time needed  0:00:00.009559
# 		dx = 6.59769e-08, res_now = 2.01175e-07, res_old = 2.65848e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 5.88156e-08, res_now = 1.60669e-16, res_old = 2.08957e-07
# Solution rank is [1, 33, 33, 33, 33, 18, 1]
# Maxres  tensor(0.0099, device='cuda:1')
# Time  0:00:02.051648
#
# Starting sweep 4 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2112)....
# 		Finished with flag 0 after 80 iterations with relres 2.64171e-05 (from 0.000117797)
# 		Time needed  0:00:00.229914
# 		dx = 0.000219325, res_now = 2.64171e-05, res_old = 0.00173285
# 	Core 1
# 		Choosing iterative solver GMRES (local size 86592)....
# 		Finished with flag 0 after 80 iterations with relres 0.000118843 (from 4.47205e-05)
# 		Time needed  0:00:01.996814
# 		dx = 0.00025969, res_now = 0.000118843, res_old = 0.00456444
# 	Core 2
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 0 after 80 iterations with relres 1.2662e-06 (from 0.00144221)
# 		Time needed  0:00:00.239536
# 		dx = 0.00010529, res_now = 1.2662e-06, res_old = 0.000141536
# 	Core 3
# 		Choosing iterative solver GMRES (local size 13530)....
# 		Finished with flag 1 after 62 iterations with relres 2.01129e-07 (from 0.0489189)
# 		Time needed  0:00:00.160899
# 		dx = 5.11755e-06, res_now = 2.01129e-07, res_old = 4.1727e-06
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4100)....
# 		Finished with flag 1 after 3 iterations with relres 2.02666e-07 (from 0.924116)
# 		Time needed  0:00:00.007054
# 		dx = 2.54769e-08, res_now = 2.02666e-07, res_old = 2.20886e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 8.16673e-08, res_now = 1.3233e-16, res_old = 2.14096e-07
# Solution rank is [1, 41, 41, 41, 41, 18, 1]
# Maxres  tensor(0.0046, device='cuda:1')
# Time  0:00:02.802811
#
# Starting sweep 5 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 2624)....
# 		Finished with flag 0 after 80 iterations with relres 1.9247e-05 (from 0.000586064)
# 		Time needed  0:00:00.230638
# 		dx = 0.000130292, res_now = 1.9247e-05, res_old = 0.000348297
# 	Core 1
# 		Choosing iterative solver GMRES (local size 128576)....
# 		Finished with flag 0 after 80 iterations with relres 6.18138e-05 (from 0.000120311)
# 		Time needed  0:00:02.793647
# 		dx = 0.000109055, res_now = 6.18138e-05, res_old = 0.00169663
# 	Core 2
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 0 after 80 iterations with relres 6.72179e-07 (from 0.00297319)
# 		Time needed  0:00:00.239375
# 		dx = 4.66902e-05, res_now = 6.72179e-07, res_old = 6.8655e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 20090)....
# 		Finished with flag 1 after 49 iterations with relres 1.97842e-07 (from 0.206221)
# 		Time needed  0:00:00.129675
# 		dx = 2.37643e-06, res_now = 1.97842e-07, res_old = 9.89834e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 4900)....
# 		Finished with flag 1 after 0 iterations with relres 1.99969e-07 (from 0.993232)
# 		Time needed  0:00:00.003960
# 		dx = 2.63786e-09, res_now = 1.99969e-07, res_old = 2.05515e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.58491e-08, res_now = 1.55351e-16, res_old = 2.10242e-07
# Solution rank is [1, 49, 49, 49, 49, 18, 1]
# Maxres  tensor(0.0017, device='cuda:1')
# Time  0:00:03.596635
#
# Starting sweep 6 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3136)....
# 		Finished with flag 0 after 80 iterations with relres 8.06525e-06 (from 0.00111993)
# 		Time needed  0:00:00.231251
# 		dx = 4.83704e-05, res_now = 8.06525e-06, res_old = 0.000182265
# 	Core 1
# 		Choosing iterative solver GMRES (local size 178752)....
# 		Finished with flag 0 after 80 iterations with relres 3.25844e-05 (from 0.000289559)
# 		Time needed  0:00:03.886553
# 		dx = 5.28217e-05, res_now = 3.25844e-05, res_old = 0.000704948
# 	Core 2
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 0 after 80 iterations with relres 6.30848e-07 (from 0.00601783)
# 		Time needed  0:00:00.247323
# 		dx = 1.63662e-05, res_now = 6.30848e-07, res_old = 3.39199e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 27930)....
# 		Finished with flag 1 after 48 iterations with relres 2.00458e-07 (from 0.310524)
# 		Time needed  0:00:00.131306
# 		dx = 1.90274e-06, res_now = 2.00458e-07, res_old = 6.57353e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 5700)....
# 		Finished with flag 1 after 0 iterations with relres 2.03956e-07 (from 0.983832)
# 		Time needed  0:00:00.003939
# 		dx = 2.54001e-09, res_now = 2.03956e-07, res_old = 2.07479e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 9.41331e-08, res_now = 1.69695e-16, res_old = 2.15109e-07
# Solution rank is [1, 57, 57, 57, 57, 18, 1]
# Maxres  tensor(0.0007, device='cuda:1')
# Time  0:00:04.738317
#
# Starting sweep 7 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 3648)....
# 		Finished with flag 0 after 80 iterations with relres 4.44492e-06 (from 0.00199127)
# 		Time needed  0:00:00.234690
# 		dx = 1.91995e-05, res_now = 4.44492e-06, res_old = 0.00010251
# 	Core 1
# 		Choosing iterative solver GMRES (local size 233472)....
# 		Finished with flag 0 after 80 iterations with relres 1.91773e-05 (from 0.000506243)
# 		Time needed  0:00:04.940484
# 		dx = 1.9243e-05, res_now = 1.91773e-05, res_old = 0.000403214
# 	Core 2
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 0 after 80 iterations with relres 4.55466e-07 (from 0.0102767)
# 		Time needed  0:00:00.259993
# 		dx = 7.27793e-06, res_now = 4.55466e-07, res_old = 1.98628e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 37050)....
# 		Finished with flag 1 after 37 iterations with relres 2.02064e-07 (from 0.433991)
# 		Time needed  0:00:00.104501
# 		dx = 9.81998e-07, res_now = 2.02064e-07, res_old = 4.70342e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 6500)....
# 		Finished with flag 1 after 3 iterations with relres 1.9965e-07 (from 0.9722)
# 		Time needed  0:00:00.007204
# 		dx = 2.44023e-08, res_now = 1.9965e-07, res_old = 2.09961e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.99546e-08, res_now = 1.73277e-16, res_old = 2.11629e-07
# Solution rank is [1, 64, 65, 65, 65, 18, 1]
# Maxres  tensor(0.0004, device='cuda:1')
# Time  0:00:05.826522
#
# Starting sweep 8 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 2.44902e-06 (from 0.00227241)
# 		Time needed  0:00:00.230174
# 		dx = 1.09054e-05, res_now = 2.44902e-06, res_old = 8.98273e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 266240)....
# 		Finished with flag 0 after 80 iterations with relres 1.20456e-05 (from 0.000779847)
# 		Time needed  0:00:05.664523
# 		dx = 1.18969e-05, res_now = 1.20456e-05, res_old = 0.000261749
# 	Core 2
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 0 after 80 iterations with relres 7.5765e-07 (from 0.0164678)
# 		Time needed  0:00:00.283512
# 		dx = 6.29794e-06, res_now = 7.5765e-07, res_old = 1.23954e-05
# 	Core 3
# 		Choosing iterative solver GMRES (local size 47450)....
# 		Finished with flag 1 after 68 iterations with relres 2.01059e-07 (from 0.263291)
# 		Time needed  0:00:00.189303
# 		dx = 1.19256e-06, res_now = 2.01059e-07, res_old = 7.75279e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 7300)....
# 		Finished with flag 1 after 0 iterations with relres 2.0336e-07 (from 0.977609)
# 		Time needed  0:00:00.003997
# 		dx = 2.05262e-09, res_now = 2.0336e-07, res_old = 2.08799e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.1592e-07, res_now = 1.80981e-16, res_old = 2.15965e-07
# Solution rank is [1, 64, 73, 73, 73, 18, 1]
# Maxres  tensor(0.0003, device='cuda:1')
# Time  0:00:06.686238
#
# Starting sweep 9 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 1.31005e-06 (from 0.00289857)
# 		Time needed  0:00:00.234897
# 		dx = 5.72101e-06, res_now = 1.31005e-06, res_old = 7.04223e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 299008)....
# 		Finished with flag 0 after 80 iterations with relres 7.71446e-06 (from 0.00140153)
# 		Time needed  0:00:06.325548
# 		dx = 8.29499e-06, res_now = 7.71446e-06, res_old = 0.000145644
# 	Core 2
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 0 after 80 iterations with relres 6.54899e-07 (from 0.0253573)
# 		Time needed  0:00:00.321334
# 		dx = 3.13591e-06, res_now = 6.54899e-07, res_old = 8.04991e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 59130)....
# 		Finished with flag 1 after 71 iterations with relres 2.00038e-07 (from 0.301845)
# 		Time needed  0:00:00.208523
# 		dx = 9.51641e-07, res_now = 2.00038e-07, res_old = 6.76256e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8100)....
# 		Finished with flag 1 after 0 iterations with relres 2.04e-07 (from 0.978401)
# 		Time needed  0:00:00.004151
# 		dx = 1.09246e-09, res_now = 2.04e-07, res_old = 2.0863e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 9.40062e-08, res_now = 1.65603e-16, res_old = 2.15487e-07
# Solution rank is [1, 64, 81, 81, 81, 18, 1]
# Maxres  tensor(0.0001, device='cuda:1')
# Time  0:00:07.434527
#
# Starting sweep 10 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 7.55371e-07 (from 0.00535956)
# 		Time needed  0:00:00.232296
# 		dx = 2.81761e-06, res_now = 7.55371e-07, res_old = 3.8086e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 331776)....
# 		Finished with flag 0 after 80 iterations with relres 5.31639e-06 (from 0.00251134)
# 		Time needed  0:00:06.983634
# 		dx = 3.65459e-06, res_now = 5.31639e-06, res_old = 8.12811e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 0 after 80 iterations with relres 5.3138e-07 (from 0.0315369)
# 		Time needed  0:00:00.372898
# 		dx = 1.76405e-06, res_now = 5.3138e-07, res_old = 6.47256e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 72090)....
# 		Finished with flag 1 after 80 iterations with relres 1.99408e-07 (from 0.37469)
# 		Time needed  0:00:00.281670
# 		dx = 1.00357e-06, res_now = 1.99408e-07, res_old = 5.44782e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 8900)....
# 		Finished with flag 1 after 0 iterations with relres 2.00691e-07 (from 0.988824)
# 		Time needed  0:00:00.004921
# 		dx = 9.93679e-10, res_now = 2.00691e-07, res_old = 2.06431e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 7.47548e-08, res_now = 1.54106e-16, res_old = 2.1399e-07
# Solution rank is [1, 64, 89, 89, 89, 18, 1]
# Maxres  tensor(8.1281e-05, device='cuda:1')
# Time  0:00:08.247423
#
# Starting sweep 11 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 0 after 80 iterations with relres 3.14725e-07 (from 0.00879771)
# 		Time needed  0:00:00.230073
# 		dx = 1.52984e-06, res_now = 3.14725e-07, res_old = 2.3202e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 364544)....
# 		Finished with flag 0 after 80 iterations with relres 3.81657e-06 (from 0.00443388)
# 		Time needed  0:00:07.654499
# 		dx = 2.96405e-06, res_now = 3.81657e-06, res_old = 4.60373e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 0 after 80 iterations with relres 4.31481e-07 (from 0.0356247)
# 		Time needed  0:00:00.435130
# 		dx = 1.18669e-06, res_now = 4.31481e-07, res_old = 5.72985e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 86330)....
# 		Finished with flag 1 after 77 iterations with relres 2.04114e-07 (from 0.452887)
# 		Time needed  0:00:00.262047
# 		dx = 6.95576e-07, res_now = 2.04114e-07, res_old = 4.50718e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 9700)....
# 		Finished with flag 1 after 2 iterations with relres 1.97712e-07 (from 0.961138)
# 		Time needed  0:00:00.006191
# 		dx = 4.55688e-09, res_now = 1.97712e-07, res_old = 2.12378e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 3.11949e-08, res_now = 1.70259e-16, res_old = 2.10784e-07
# Solution rank is [1, 64, 97, 97, 97, 18, 1]
# Maxres  tensor(4.6037e-05, device='cuda:1')
# Time  0:00:08.983747
#
# Starting sweep 12 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 72 iterations with relres 2.01863e-07 (from 0.0141773)
# 		Time needed  0:00:00.196613
# 		dx = 1.07359e-06, res_now = 2.01863e-07, res_old = 1.43979e-05
# 	Core 1
# 		Choosing iterative solver GMRES (local size 397312)....
# 		Finished with flag 0 after 80 iterations with relres 2.78121e-06 (from 0.00748393)
# 		Time needed  0:00:08.319656
# 		dx = 1.65197e-06, res_now = 2.78121e-06, res_old = 2.7275e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 0 after 80 iterations with relres 3.25438e-07 (from 0.0456248)
# 		Time needed  0:00:00.509354
# 		dx = 7.87193e-07, res_now = 3.25438e-07, res_old = 4.47397e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 101850)....
# 		Finished with flag 1 after 32 iterations with relres 2.02918e-07 (from 0.598944)
# 		Time needed  0:00:00.125356
# 		dx = 9.85349e-08, res_now = 2.02918e-07, res_old = 3.40807e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10500)....
# 		Finished with flag 1 after 2 iterations with relres 2.00809e-07 (from 0.978094)
# 		Time needed  0:00:00.006211
# 		dx = 2.16168e-09, res_now = 2.00809e-07, res_old = 2.08696e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.68807e-08, res_now = 1.58343e-16, res_old = 2.16925e-07
# Solution rank is [1, 64, 105, 105, 105, 18, 1]
# Maxres  tensor(2.7275e-05, device='cuda:1')
# Time  0:00:09.576486
#
# Starting sweep 13 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 45 iterations with relres 2.01975e-07 (from 0.0216103)
# 		Time needed  0:00:00.121965
# 		dx = 5.68411e-07, res_now = 2.01975e-07, res_old = 9.4457e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 430080)....
# 		Finished with flag 0 after 80 iterations with relres 1.97325e-06 (from 0.0150152)
# 		Time needed  0:00:08.972810
# 		dx = 1.28154e-06, res_now = 1.97325e-06, res_old = 1.35945e-05
# 	Core 2
# 		Choosing iterative solver GMRES (local size 118650)....
# 		Finished with flag 0 after 80 iterations with relres 2.71243e-07 (from 0.0836934)
# 		Time needed  0:00:00.574764
# 		dx = 5.36751e-07, res_now = 2.71243e-07, res_old = 2.43895e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 113000)....
# 		Finished with flag 1 after 15 iterations with relres 2.03753e-07 (from 0.729339)
# 		Time needed  0:00:00.067929
# 		dx = 1.61925e-08, res_now = 2.03753e-07, res_old = 2.79875e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 1 iterations with relres 2.03114e-07 (from 0.959391)
# 		Time needed  0:00:00.004969
# 		dx = 1.39208e-09, res_now = 2.03114e-07, res_old = 2.12764e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.40251e-08, res_now = 1.8268e-16, res_old = 2.17513e-07
# Solution rank is [1, 64, 113, 113, 108, 18, 1]
# Maxres  tensor(1.3595e-05, device='cuda:1')
# Time  0:00:10.187163
#
# Starting sweep 14 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 34 iterations with relres 2.02555e-07 (from 0.0242847)
# 		Time needed  0:00:00.086964
# 		dx = 3.92034e-07, res_now = 2.02555e-07, res_old = 8.40546e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 462848)....
# 		Finished with flag 0 after 80 iterations with relres 1.41839e-06 (from 0.0210525)
# 		Time needed  0:00:09.649967
# 		dx = 8.09531e-07, res_now = 1.41839e-06, res_old = 9.69597e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 136730)....
# 		Finished with flag 1 after 79 iterations with relres 2.0113e-07 (from 0.135372)
# 		Time needed  0:00:00.633499
# 		dx = 3.35636e-07, res_now = 2.0113e-07, res_old = 1.50787e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 121000)....
# 		Finished with flag 1 after 0 iterations with relres 1.98899e-07 (from 0.988651)
# 		Time needed  0:00:00.020417
# 		dx = 8.24614e-11, res_now = 1.98899e-07, res_old = 2.06467e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.96507e-07 (from 0.98071)
# 		Time needed  0:00:00.004095
# 		dx = 7.17919e-10, res_now = 1.96507e-07, res_old = 2.08139e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.27997e-08, res_now = 1.89926e-16, res_old = 2.09492e-07
# Solution rank is [1, 64, 121, 121, 108, 18, 1]
# Maxres  tensor(9.6960e-06, device='cuda:1')
# Time  0:00:10.866533
#
# Starting sweep 15 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 22 iterations with relres 1.99466e-07 (from 0.026744)
# 		Time needed  0:00:00.050148
# 		dx = 2.09091e-07, res_now = 1.99466e-07, res_old = 7.63252e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 495616)....
# 		Finished with flag 0 after 80 iterations with relres 1.1272e-06 (from 0.0311207)
# 		Time needed  0:00:10.313679
# 		dx = 2.36524e-07, res_now = 1.1272e-06, res_old = 6.55911e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 156090)....
# 		Finished with flag 1 after 51 iterations with relres 2.03543e-07 (from 0.176028)
# 		Time needed  0:00:00.478276
# 		dx = 9.22714e-08, res_now = 2.03543e-07, res_old = 1.15961e-06
# 	Core 3
# 		Choosing iterative solver GMRES (local size 129000)....
# 		Finished with flag 1 after 0 iterations with relres 2.03927e-07 (from 0.981394)
# 		Time needed  0:00:00.021819
# 		dx = 9.91377e-11, res_now = 2.03927e-07, res_old = 2.07994e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 1 iterations with relres 1.86413e-07 (from 0.955992)
# 		Time needed  0:00:00.004967
# 		dx = 2.37242e-09, res_now = 1.86413e-07, res_old = 2.13521e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.44143e-08, res_now = 1.62919e-16, res_old = 1.98679e-07
# Solution rank is [1, 64, 129, 129, 108, 18, 1]
# Maxres  tensor(7.6325e-06, device='cuda:1')
# Time  0:00:11.367266
#
# Starting sweep 16 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 21 iterations with relres 1.79415e-07 (from 0.0318863)
# 		Time needed  0:00:00.045125
# 		dx = 2.30492e-07, res_now = 1.79415e-07, res_old = 6.40162e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 528384)....
# 		Finished with flag 0 after 80 iterations with relres 7.43093e-07 (from 0.0407492)
# 		Time needed  0:00:11.083459
# 		dx = 2.97677e-07, res_now = 7.43093e-07, res_old = 5.00928e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 176730)....
# 		Finished with flag 1 after 46 iterations with relres 2.03401e-07 (from 0.255969)
# 		Time needed  0:00:00.512347
# 		dx = 1.30633e-07, res_now = 2.03401e-07, res_old = 7.97456e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 137000)....
# 		Finished with flag 1 after 0 iterations with relres 2.02474e-07 (from 0.976453)
# 		Time needed  0:00:00.022612
# 		dx = 9.42415e-11, res_now = 2.02474e-07, res_old = 2.09046e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 2.0309e-07 (from 0.965387)
# 		Time needed  0:00:00.004152
# 		dx = 4.85245e-10, res_now = 2.0309e-07, res_old = 2.11443e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 2.03093e-08, res_now = 1.8453e-16, res_old = 2.16443e-07
# Solution rank is [1, 64, 137, 137, 108, 18, 1]
# Maxres  tensor(6.4016e-06, device='cuda:1')
# Time  0:00:12.200929
#
# Starting sweep 17 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 13 iterations with relres 2.00175e-07 (from 0.0629074)
# 		Time needed  0:00:00.027037
# 		dx = 6.81135e-08, res_now = 2.00175e-07, res_old = 3.24484e-06
# 	Core 1
# 		Choosing iterative solver GMRES (local size 561152)....
# 		Finished with flag 0 after 80 iterations with relres 4.96845e-07 (from 0.0554329)
# 		Time needed  0:00:11.763814
# 		dx = 3.45776e-07, res_now = 4.96845e-07, res_old = 3.68237e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 198650)....
# 		Finished with flag 1 after 6 iterations with relres 1.9972e-07 (from 0.390294)
# 		Time needed  0:00:00.117646
# 		dx = 3.22995e-09, res_now = 1.9972e-07, res_old = 5.23001e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 145000)....
# 		Finished with flag 1 after 0 iterations with relres 1.94069e-07 (from 1.00282)
# 		Time needed  0:00:00.024333
# 		dx = 1.27774e-10, res_now = 1.94069e-07, res_old = 2.03551e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.84882e-07 (from 1.00018)
# 		Time needed  0:00:00.004106
# 		dx = 8.80664e-10, res_now = 1.84882e-07, res_old = 2.04087e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.50677e-08, res_now = 1.75527e-16, res_old = 1.95244e-07
# Solution rank is [1, 64, 145, 145, 108, 18, 1]
# Maxres  tensor(3.6824e-06, device='cuda:1')
# Time  0:00:12.498337
#
# Starting sweep 18 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 5 iterations with relres 1.7621e-07 (from 0.219225)
# 		Time needed  0:00:00.016076
# 		dx = 4.38917e-08, res_now = 1.7621e-07, res_old = 9.31116e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 593920)....
# 		Finished with flag 0 after 80 iterations with relres 3.56019e-07 (from 0.118347)
# 		Time needed  0:00:12.438895
# 		dx = 3.06913e-07, res_now = 3.56019e-07, res_old = 1.7248e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 221850)....
# 		Finished with flag 1 after 3 iterations with relres 1.99652e-07 (from 0.559061)
# 		Time needed  0:00:00.099851
# 		dx = 1.37274e-09, res_now = 1.99652e-07, res_old = 3.6512e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 153000)....
# 		Finished with flag 1 after 0 iterations with relres 1.89594e-07 (from 1.0148)
# 		Time needed  0:00:00.028142
# 		dx = 1.06507e-10, res_now = 1.89594e-07, res_old = 2.01147e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.8839e-07 (from 1.0275)
# 		Time needed  0:00:00.004172
# 		dx = 3.35224e-10, res_now = 1.8839e-07, res_old = 1.98661e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.18155e-08, res_now = 2.43216e-16, res_old = 2.00453e-07
# Solution rank is [1, 64, 153, 153, 108, 18, 1]
# Maxres  tensor(1.7248e-06, device='cuda:1')
# Time  0:00:13.176790
#
# Starting sweep 19 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 2 iterations with relres 1.90301e-07 (from 0.454792)
# 		Time needed  0:00:00.011098
# 		dx = 2.87468e-08, res_now = 1.90301e-07, res_old = 4.4883e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 626688)....
# 		Finished with flag 0 after 80 iterations with relres 2.53897e-07 (from 0.165901)
# 		Time needed  0:00:13.117967
# 		dx = 2.37913e-07, res_now = 2.53897e-07, res_old = 1.2304e-06
# 	Core 2
# 		Choosing iterative solver GMRES (local size 246330)....
# 		Finished with flag 1 after 1 iterations with relres 1.79015e-07 (from 0.79181)
# 		Time needed  0:00:00.086622
# 		dx = 6.37877e-10, res_now = 1.79015e-07, res_old = 2.57794e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 161000)....
# 		Finished with flag 1 after 0 iterations with relres 1.55249e-07 (from 1.13719)
# 		Time needed  0:00:00.027123
# 		dx = 1.15271e-10, res_now = 1.55249e-07, res_old = 1.79499e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.46666e-07 (from 1.25572)
# 		Time needed  0:00:00.004075
# 		dx = 2.9656e-10, res_now = 1.46666e-07, res_old = 1.62556e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 1.06035e-08, res_now = 2.27159e-16, res_old = 1.55598e-07
# Solution rank is [1, 64, 161, 161, 108, 18, 1]
# Maxres  tensor(1.2304e-06, device='cuda:1')
# Time  0:00:13.864853
#
# Starting sweep 20 ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.8891e-07 (from 0.763079)
# 		Time needed  0:00:00.008185
# 		dx = 4.28165e-09, res_now = 1.8891e-07, res_old = 2.67501e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 659456)....
# 		Finished with flag 1 after 62 iterations with relres 2.03588e-07 (from 0.241083)
# 		Time needed  0:00:10.895389
# 		dx = 5.73725e-08, res_now = 2.03588e-07, res_old = 8.46697e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 272090)....
# 		Finished with flag 1 after 0 iterations with relres 1.94012e-07 (from 0.968057)
# 		Time needed  0:00:00.081840
# 		dx = 1.3434e-10, res_now = 1.94012e-07, res_old = 2.1086e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 169000)....
# 		Finished with flag 1 after 0 iterations with relres 1.77262e-07 (from 1.04428)
# 		Time needed  0:00:00.028110
# 		dx = 1.09495e-10, res_now = 1.77262e-07, res_old = 1.95468e-07
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10800)....
# 		Finished with flag 1 after 0 iterations with relres 1.61722e-07 (from 1.10276)
# 		Time needed  0:00:00.004128
# 		dx = 3.74039e-10, res_now = 1.61722e-07, res_old = 1.85103e-07
# 	Core 5
# 		Choosing direct solver (local size 180)....
# 		dx = 4.10737e-09, res_now = 1.82664e-16, res_old = 1.7194e-07
# Solution rank is [1, 64, 169, 169, 108, 18, 1]
# Maxres  tensor(8.4670e-07, device='cuda:1')
# Time  0:00:11.663277
#
# Starting sweep 21 (last one) ...
# 	Core 0
# 		Choosing iterative solver GMRES (local size 4096)....
# 		Finished with flag 1 after 0 iterations with relres 1.37893e-07 (from 1.09659)
# 		Time needed  0:00:00.004682
# 		dx = 2.78635e-09, res_now = 1.37893e-07, res_old = 1.86144e-07
# 	Core 1
# 		Choosing iterative solver GMRES (local size 692224)....
# 		Finished with flag 1 after 5 iterations with relres 2.02879e-07 (from 0.210528)
# 		Time needed  0:00:01.663787
# 		dx = 2.00193e-09, res_now = 2.02879e-07, res_old = 9.69581e-07
# 	Core 2
# 		Choosing iterative solver GMRES (local size 285610)....
# 		Finished with flag 1 after 0 iterations with relres 1.27429e-07 (from 1.43055)
# 		Time needed  0:00:00.078886
# 		dx = 6.69529e-11, res_now = 1.27429e-07, res_old = 1.42689e-07
# 	Core 3
# 		Choosing iterative solver GMRES (local size 169000)....
# 		Finished with flag 1 after 0 iterations with relres 8.68425e-08 (from 2.24497)
# 		Time needed  0:00:00.028442
# 		dx = 5.12958e-11, res_now = 8.68425e-08, res_old = 9.09249e-08
# 	Core 4
# 		Choosing iterative solver GMRES (local size 10000)....
# 		Finished with flag 1 after 0 iterations with relres 4.86783e-08 (from 4.14047)
# 		Time needed  0:00:00.004112
# 		dx = 1.02816e-10, res_now = 4.86783e-08, res_old = 4.92997e-08
# 	Core 5
# 		Choosing direct solver (local size 100)....
# 		dx = 1.06685e-09, res_now = 1.63858e-16, res_old = 9.15972e-09
# Solution rank is [1, 64, 169, 169, 100, 10, 1]
# Maxres  tensor(9.6958e-07, device='cuda:1')
# Time  0:00:02.370086
#
# Finished after 21  sweeps and  0:02:41.095341
#
# Time system solve  0:02:41.227517

# %%
fspace = tt_iga.Function(basis_solution+basis_param)
fspace.dofs = dofs_tt.round(1e-10)

plt.figure()
y1, y2 = basis_solution[0].collocation_points(3)[0], basis_solution[1].collocation_points(3)[0]
w1, w2 = basis_solution[0].collocation_points(3)[1], basis_solution[1].collocation_points(3)[1]
ws = np.einsum('i,j->ij',w1,w2)
X1,X2 = geom([y1,y2]+[tn.tensor([0.0])]*4)
u = fspace([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
plt.contourf(X1.numpy().squeeze(), X2.numpy().squeeze(),u.numpy().squeeze(),levels=32)
plt.colorbar()

import pickle
dct = {'x1' : X1.numpy().squeeze(), 'x2' : X2.numpy().squeeze(), 'u' : u.numpy().squeeze(), 'ws' : ws}

    
u = fspace([tn.tensor([0.05]),tn.tensor([0.0]), tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10),tn.linspace(-0.001,0.001,10), tn.linspace(-0.001,0.001,10)])

def get_in_reference(x, param1):
    return 0.4*x/(3.27640e-2+param1)
    # return 0.1*x/(geom([tn.tensor([0.1]),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([param1]), tn.tensor([0.0])])[0].numpy().squeeze())

# %%
# y1, y2 = np.linspace(0,1,32), np.linspace(0.,1,32)
# 
# grad1, grad2 = geom.gradient_physical(basis_solution, fspace)
# 
# g2 = -grad1([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# g1 = grad2([tn.tensor(y1),tn.tensor(y2),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0])])
# x1,x2 = geom([tn.tensor(y1),tn.tensor(y2)]+[tn.tensor([0.0])]*4)
# 
# plt.figure()
# plt.quiver(x1.numpy().flatten(),x2.numpy().flatten(),g1.numpy().flatten(),g2.numpy().flatten(),np.sqrt(g1.numpy().flatten()**2+g2.numpy().flatten()**2))
# plt.colorbar()
# 
# x1B, x2B = geom([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0])])
# 
# dct['x1B'] = x1B.numpy().squeeze()
# dct['x2B'] = x2B.numpy().squeeze()
# 
# g2 = -grad1([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# g1 = grad2([get_in_reference(tn.linspace(0,0.01,8),0),tn.tensor([0.0]), tn.tensor([0.0]), tn.tensor([0.0]),tn.tensor([0.0]), tn.tensor([0.0])]).numpy().flatten()
# 
# dct['B1'] = g1
# dct['B2'] = g2
# 
# with open('quad_nominal.pkl','wb') as f:
#     pickle.dump(dct, f)

# %%
import pickle
with open(r"measurements2.pkl", "rb") as input_file:
    data = pickle.load(input_file)
x_positions = tn.tensor(data['x_positions'])

np.random.seed(874214789)

print(x_positions)
print(data['A'])
A_noise = data['A'] + np.random.normal(0,1e-7,size = data['A'].shape)
print(A_noise)

#A_noise = A_noise[-4:]
#x_positions = x_positions[-4:]
print(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten())
print('err',np.abs(fspace([get_in_reference(x_positions,0)] +5*[tn.tensor([0])]).numpy().flatten() - data['A'])/np.max(np.abs(data['A'])) )
# Out:
# tensor([0.0000, 0.0015, 0.0030, 0.0045, 0.0060, 0.0075, 0.0090, 0.0105, 0.0120,
#         0.0135, 0.0150])
# [5.15419382e-16 7.61105954e-06 3.04442879e-05 6.84996613e-05
#  1.21777168e-04 1.90276690e-04 2.73997576e-04 3.72937441e-04
#  4.87088973e-04 6.16432703e-04 7.60925385e-04]
# [2.57359182e-07 7.77683184e-06 3.05278400e-05 6.84649437e-05
#  1.21769495e-04 1.90276299e-04 2.73820649e-04 3.72793065e-04
#  4.86950421e-04 6.16361147e-04 7.60935283e-04]
# [-8.36214405e-13  7.61097649e-06  3.04442161e-05  6.84995905e-05
#   1.21777074e-04  1.90276558e-04  2.73997405e-04  3.72937244e-04
#   4.87088824e-04  6.16433126e-04  7.60926016e-04]
# err [1.09962138e-09 1.09136913e-07 9.43342835e-08 9.31363282e-08
#  1.24020980e-07 1.72601631e-07 2.24984954e-07 2.59127891e-07
#  1.95475874e-07 5.55316721e-07 8.30026053e-07]

# %%
sigma_noise = 1e-7

fspace_mod = fspace[:,0,:,:,:,:]
fspace_mod.dofs = fspace_mod.dofs.round(1e-10)

def likelihood_handle(params):

    s = tn.zeros((params.shape[0],))

    for k in range(len(x_positions)):
        #argz = tn.hstack((tn.reshape(get_in_reference(x_positions[k],params[:,1]),[-1,1]) ,tn.zeros((params.shape[0],1)), params))
        #A = fspace(argz)

        argz = tn.hstack((tn.reshape(get_in_reference(x_positions[k],params[:,1]),[-1,1]) , params))
        A = fspace_mod(argz)

        s = s + (A - A_noise[k])**2
    return tn.exp(-0.5/sigma_noise**2 * s)
        




def prior_handle(params):
    # return tn.ones((params.shape[0],))
    alpha = 5
    beta = 5
    scale = lambda p,v: (p+v)/2/v
    p1 = scale(params[:,0], var1)**(alpha-1)*(1-scale(params[:,0], var1))**(beta-1)
    p2 = scale(params[:,1], var2)**(alpha-1)*(1-scale(params[:,1], var2))**(beta-1)
    p3 = scale(params[:,2], var3)**(alpha-1)*(1-scale(params[:,2], var3))**(beta-1)
    p4 = scale(params[:,3], var4)**(alpha-1)*(1-scale(params[:,3], var4))**(beta-1)
    return p1*p2*p3*p4
    #return tn.exp(-1/(2*var*var)*(params[:,0]**2+params[:,1]**2+params[:,2]**2+params[:,3]**2))

def posterior_handle(params):
    print(params.shape)
    return prior_handle(params)* likelihood_handle(params)#+1e-101*(params[...,0]+params[...,1]+params[...,2]+params[...,3])
    # return tn.tensor(list(map((post), list(params))))

# %%
import TTCME

basis = [TTCME.basis.BSplineBasis(64,[-var1,var1],2), TTCME.basis.BSplineBasis(40,[-var2,var2],2), TTCME.basis.BSplineBasis(40,[-var3,var3],2), TTCME.basis.BSplineBasis(40,[-var4,var4],2)]
xs = tntt.meshgrid([tn.tensor(b.interpolation_pts[0]) for b in basis])
Ms = tntt.rank1TT([tn.tensor(np.linalg.inv(b.interpolation_pts[1])) for b in basis])

paramz = tn.hstack(( tn.reshape(xs[0].full(),[-1,1]) , tn.reshape(xs[1].full(),[-1,1]) , tn.reshape(xs[2].full(),[-1,1]) , tn.reshape(xs[3].full(),[-1,1]) ))

# vals = tn.reshape(posterior_handle(paramz),[b.dim for b in basis])

#posterior_pdf = TTCME.pdfTT(basis, variable_names= ['theta1', 'theta2', 'theta3', 'theta4'], dofs = Ms @ tntt.TT(vals,eps = 1e-12))
posterior_pdf = TTCME.pdfTT.interpoalte(posterior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
print(posterior_pdf)
# 
prior_pdf = TTCME.pdfTT.interpoalte(prior_handle, basis, variable_names=['theta1', 'theta2', 'theta3', 'theta4'])
# Out:
# torch.Size([5120, 4])
# torch.Size([16000, 4])
# torch.Size([19200, 4])
# torch.Size([19200, 4])
# torch.Size([120000, 4])
# torch.Size([35840, 4])
# torch.Size([35840, 4])
# torch.Size([120000, 4])
# torch.Size([22400, 4])
# torch.Size([22400, 4])
# torch.Size([120000, 4])
# torch.Size([35840, 4])
# Probability density function:
# p(theta1,theta2,theta3,theta4)
#
# Basis:
# B-spline basis defined on [-0.00075, 0.00075] and dimension 64
# B-spline basis defined on [-0.00075, 0.00075] and dimension 40
# B-spline basis defined on [-0.00075, 0.00075] and dimension 40
# B-spline basis defined on [-0.00075, 0.00075] and dimension 40
#
# DoF:
# TT with sizes and ranks:
# N = [64, 40, 40, 40]
# R = [1, 5, 14, 15, 1]
#
# Device: cpu, dtype: torch.float64
# #entries 12120 compression 0.002958984375

# %%
posterior_pdf.normalize()

E = posterior_pdf.expected_value()
C = posterior_pdf.covariance_matrix()
V = np.diag(C)

print()
print('Exact parameters:                 ',[0,0,0,0])
print('')
print('Expected value computed posterior ' ,E)
print('Coariance computed posterior      ' ,C)

E = prior_pdf.expected_value()
C = prior_pdf.covariance_matrix()
V = np.diag(C)

print('')
print('Expected value prior              ' ,E)
print('Variance prior                    ' ,V)
# Out:
# Exact parameters:                  [0, 0, 0, 0]
#
# Expected value computed posterior  [tensor(1.2097e-05), tensor(0.0006), tensor(-0.0003), tensor(-0.0003)]
# Coariance computed posterior       tensor([[ 2.4380e-19,  1.3209e-17, -7.0233e-18, -8.1530e-18],
#         [ 1.3209e-17,  1.8138e-09,  1.3701e-09,  1.4325e-09],
#         [-7.0233e-18,  1.3701e-09,  3.3245e-08, -2.9223e-09],
#         [-8.1530e-18,  1.4325e-09, -2.9223e-09,  2.6956e-08]])
#
# Expected value prior               [tensor(-6.2480e-21), tensor(-1.6256e-20), tensor(-1.1884e-20), tensor(-4.1081e-20)]
# Variance prior                     [5.11363789e-08 5.11365367e-08 5.11365367e-08 5.11365367e-08]

# %%
plt.figure(figsize = [6,6])
true_parameters = [0.0]*4
k = 0
for i in range(4):
    for j in range(4):
        k += 1
        if i==j:
            plt.subplot(4, 4, k)
            
            theta = np.linspace(basis[i].domain[0], basis[i].domain[1],1000)
            pr = prior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
            po = posterior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
           
            plt.plot(1e3*theta,1e3*(po/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)))
            plt.axvline(true_parameters[i],c='r',linestyle=':')
            plt.plot(1e3*theta,1e3*(pr/np.max(po)*(np.max(theta)-np.min(theta))+np.min(theta)),'g:')
            
        else:
            plt.subplot(4, 4, k)
             
            if j<i: 
                theta1 = np.linspace(basis[j].domain[0], basis[j].domain[1], 127)
                theta2 = np.linspace(basis[i].domain[0], basis[i].domain[1], 128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T1, 1e3*T2, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
            else: 
                theta1 = np.linspace(basis[i].domain[0],basis[i].domain[1],127)
                theta2 = np.linspace(basis[j].domain[0],basis[j].domain[1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                plt.contourf(1e3*T2, 1e3*T1, po, cmap='gray_r', levels =64)
                plt.axvline(1e3*true_parameters[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(1e3*true_parameters[i],c='r',linestyle=':',linewidth=1)
        
        if i==3: plt.xlabel(r'$\theta_'+str(j+1)+'$ [mm]')
        if j==0: plt.ylabel(r'$\theta_'+str(i+1)+'$ [mm]')
        
        if j>0: plt.yticks([])
        if i<3: plt.xticks([])

plt.savefig('quad_posterior1.eps')

# %%
print('Rank solution ', dofs_tt.round(1e-10).R)
print('Storage solution ', tntt.numel(dofs_tt.round(1e-10))*8/1e6)
# Out:
# Rank solution  [1, 62, 136, 106, 41, 8, 1]
# Storage solution  5.876768

# %%
Dc = 3.27640e-2                                                           
# Dc = 32e-3
# hc = 7e-3
hc = 7.55176e-3                                                           
ri = 20e-3                                                           
                                                         
rm = ((Dc+var2)**2+hc*hc-(ri+var1)**2)/((Dc+var2)*np.sqrt(2)+hc*np.sqrt(2)-2*(ri+var1))                 


O = np.array([rm/np.sqrt(2),rm/np.sqrt(2)])

xc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[0].numpy().squeeze()
yc = geom([tn.linspace(0,0.4,10000),tn.tensor([0.3]), tn.tensor([var1]), tn.tensor([var2]), tn.tensor([var3]), tn.tensor([-var4])])[1].numpy().squeeze()
print(np.std(np.sqrt((xc-O[0])**2+(yc-O[1])**2)))
# Out:
# 7.2773955164115e-17
